# %%
# %matplotlib inline
import matplotlib
import seaborn as sns
matplotlib.rcParams['savefig.dpi'] = 144

# %%
import expectexception

# %% [markdown]
# # Pandas
#
# <!-- requirement: data/yelp.json.gz -->
# <!-- requirement: data/PEP_2016_PEPANNRES.csv -->

# %%
import pandas as pd

# %% [markdown]
# We introduced the Pandas module and the DataFrame object in the lesson on [basic data science modules](DS_Basic_DS_Modules.ipynb). We learned how to construct a DataFrame, add data, retrieve data, and [basic reading and writing to disk](DS_IO.ipynb). Now we'll explore the DataFrame object and its powerful analysis methods in more depth.
#
# We'll work with a data set from the online review site, Yelp. The file is stored as a compressed JSON file.

# %%
# !ls -lh ./data/yelp.json.gz
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import gzip
import simplejson as json

with gzip.open('./data/yelp.json.gz', 'r') as f:
    yelp_data = [json.loads(line) for line in f]
    
yelp_data
# Out:
# [{'business_id': 'vcNAWiLM4dR7D2nwwJ7nCA',
#   'full_address': '4840 E Indian School Rd\nSte 101\nPhoenix, AZ 85018',
#   'hours': {'Tuesday': {'close': '17:00', 'open': '08:00'},
#    'Friday': {'close': '17:00', 'open': '08:00'},
#    'Monday': {'close': '17:00', 'open': '08:00'},
#    'Wednesday': {'close': '17:00', 'open': '08:00'},
#    'Thursday': {'close': '17:00', 'open': '08:00'}},
#   'open': True,
#   'categories': ['Doctors', 'Health & Medical'],
#   'city': 'Phoenix',
#   'review_count': 7,
#   'name': 'Eric Goldberg, MD',
#   'neighborhoods': [],
#   'longitude': -111.983758,
#   'state': 'AZ',
#   'stars': 3.5,
#   'latitude': 33.499313,
#   'attributes': {'By Appointment Only': True},
#   'type': 'business'},
#  {'business_id': 'JwUE5GmEO-sH1FuwJgKBlQ',
#   'full_address': '6162 US Highway 51\nDe Forest, WI 53532',
#   'hours': {},
#   'open': True,
#   'categories': ['Restaurants'],
#   'city': 'De Forest',
#   'review_count': 26,
#   'name': 'Pine Cone Restaurant',
#   'neighborhoods': [],
#   'longitude': -89.335844,
#   'state': 'WI',
#   'stars': 4.0,
#   'latitude': 43.238893,
#   'attributes': {'Take-out': True,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': True,
#     'dinner': False,
#     'breakfast': False,
#     'brunch': False},
#    'Caters': False,
#    'Noise Level': 'average',
#    'Takes Reservations': False,
#    'Delivery': False,
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False},
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Has TV': True,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Alcohol': 'none',
#    'Waiter Service': True,
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': 'uGykseHzyS5xAMWoN6YUqA',
#   'full_address': '505 W North St\nDe Forest, WI 53532',
#   'hours': {'Monday': {'close': '22:00', 'open': '06:00'},
#    'Tuesday': {'close': '22:00', 'open': '06:00'},
#    'Friday': {'close': '22:00', 'open': '06:00'},
#    'Wednesday': {'close': '22:00', 'open': '06:00'},
#    'Thursday': {'close': '22:00', 'open': '06:00'},
#    'Sunday': {'close': '21:00', 'open': '06:00'},
#    'Saturday': {'close': '22:00', 'open': '06:00'}},
#   'open': True,
#   'categories': ['American (Traditional)', 'Restaurants'],
#   'city': 'De Forest',
#   'review_count': 16,
#   'name': 'Deforest Family Restaurant',
#   'neighborhoods': [],
#   'longitude': -89.353437,
#   'state': 'WI',
#   'stars': 4.0,
#   'latitude': 43.252267,
#   'attributes': {'Take-out': True,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': False,
#     'breakfast': False,
#     'brunch': True},
#    'Caters': False,
#    'Noise Level': 'quiet',
#    'Takes Reservations': False,
#    'Delivery': False,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Has TV': True,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': True},
#    'Waiter Service': True,
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': 'LRKJF43s9-3jG9Lgx4zODg',
#   'full_address': '4910 County Rd V\nDe Forest, WI 53532',
#   'hours': {'Monday': {'close': '22:00', 'open': '10:30'},
#    'Tuesday': {'close': '22:00', 'open': '10:30'},
#    'Friday': {'close': '22:00', 'open': '10:30'},
#    'Wednesday': {'close': '22:00', 'open': '10:30'},
#    'Thursday': {'close': '22:00', 'open': '10:30'},
#    'Sunday': {'close': '22:00', 'open': '10:30'},
#    'Saturday': {'close': '22:00', 'open': '10:30'}},
#   'open': True,
#   'categories': ['Food',
#    'Ice Cream & Frozen Yogurt',
#    'Fast Food',
#    'Restaurants'],
#   'city': 'De Forest',
#   'review_count': 7,
#   'name': "Culver's",
#   'neighborhoods': [],
#   'longitude': -89.374983,
#   'state': 'WI',
#   'stars': 4.5,
#   'latitude': 43.251045,
#   'attributes': {'Take-out': True,
#    'Wi-Fi': 'free',
#    'Takes Reservations': False,
#    'Delivery': False,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Wheelchair Accessible': True,
#    'Attire': 'casual',
#    'Accepts Credit Cards': True,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': 'RgDg-k9S5YD_BaxMckifkg',
#   'full_address': '631 S Main St\nDe Forest, WI 53532',
#   'hours': {'Monday': {'close': '22:00', 'open': '11:00'},
#    'Tuesday': {'close': '22:00', 'open': '11:00'},
#    'Friday': {'close': '22:30', 'open': '11:00'},
#    'Wednesday': {'close': '22:00', 'open': '11:00'},
#    'Thursday': {'close': '22:00', 'open': '11:00'},
#    'Sunday': {'close': '21:00', 'open': '16:00'},
#    'Saturday': {'close': '22:30', 'open': '11:00'}},
#   'open': True,
#   'categories': ['Chinese', 'Restaurants'],
#   'city': 'De Forest',
#   'review_count': 3,
#   'name': 'Chang Jiang Chinese Kitchen',
#   'neighborhoods': [],
#   'longitude': -89.3437217,
#   'state': 'WI',
#   'stars': 4.0,
#   'latitude': 43.2408748,
#   'attributes': {'Take-out': True,
#    'Has TV': False,
#    'Outdoor Seating': False,
#    'Attire': 'casual'},
#   'type': 'business'},
#  {'business_id': 'oLctHIA1AxmsgOuu4dM6Vw',
#   'full_address': '4156 County Rd B\nMc Farland, WI 53558',
#   'hours': {},
#   'open': False,
#   'categories': ['Television Stations', 'Mass Media'],
#   'city': 'Mc Farland',
#   'review_count': 10,
#   'name': 'Charter Communications',
#   'neighborhoods': [],
#   'longitude': -89.3229199,
#   'state': 'WI',
#   'stars': 1.5,
#   'latitude': 42.9685074,
#   'attributes': {},
#   'type': 'business'},
#  {'business_id': 'ZW2WeP2Hp20tq0RG1NFkoQ',
#   'full_address': '4709 Triangle St\nMc Farland, WI 53558',
#   'hours': {},
#   'open': True,
#   'categories': ['Home Services', 'Heating & Air Conditioning/HVAC'],
#   'city': 'Mc Farland',
#   'review_count': 4,
#   'name': 'Air Quality Systems',
#   'neighborhoods': [],
#   'longitude': -89.2985442,
#   'state': 'WI',
#   'stars': 2.0,
#   'latitude': 43.0303561,
#   'attributes': {},
#   'type': 'business'},
#  {'business_id': '95p9Xg358BezJyk1wqzzyg',
#   'full_address': '5114 Farwell St\nMc Farland, WI 53558',
#   'hours': {'Monday': {'close': '20:00', 'open': '09:00'},
#    'Tuesday': {'close': '20:00', 'open': '09:00'},
#    'Friday': {'close': '17:30', 'open': '09:00'},
#    'Wednesday': {'close': '20:00', 'open': '09:00'},
#    'Thursday': {'close': '20:00', 'open': '09:00'},
#    'Sunday': {'close': '15:00', 'open': '12:00'},
#    'Saturday': {'close': '17:30', 'open': '09:00'}},
#   'open': True,
#   'categories': ['Libraries', 'Public Services & Government'],
#   'city': 'Mc Farland',
#   'review_count': 4,
#   'name': 'McFarland Public Library',
#   'neighborhoods': [],
#   'longitude': -89.294175,
#   'state': 'WI',
#   'stars': 2.5,
#   'latitude': 43.014093,
#   'attributes': {'Wi-Fi': 'free'},
#   'type': 'business'},
#  {'business_id': 'ZlhAvs_6ryi4_efZ1SpMbg',
#   'full_address': '4811 Larson Beach Rd\nMc Farland, WI 53558',
#   'hours': {'Monday': {'close': '18:00', 'open': '07:30'},
#    'Tuesday': {'close': '18:00', 'open': '07:30'},
#    'Friday': {'close': '18:00', 'open': '07:30'},
#    'Wednesday': {'close': '18:00', 'open': '07:30'},
#    'Thursday': {'close': '18:00', 'open': '07:30'},
#    'Saturday': {'close': '12:00', 'open': '08:00'}},
#   'open': True,
#   'categories': ['Veterinarians', 'Pets'],
#   'city': 'Mc Farland',
#   'review_count': 3,
#   'name': 'Spartan Animal Hospital',
#   'neighborhoods': [],
#   'longitude': -89.299119,
#   'state': 'WI',
#   'stars': 4.5,
#   'latitude': 43.017124,
#   'attributes': {},
#   'type': 'business'},
#  {'business_id': '_wZTYYL7cutanzAnJUTGMA',
#   'full_address': '4506 Larson Beach Rd\nMc Farland, WI 53558',
#   'hours': {},
#   'open': True,
#   'categories': ['Bars',
#    'American (Traditional)',
#    'Nightlife',
#    'Lounges',
#    'Restaurants'],
#   'city': 'Mc Farland',
#   'review_count': 31,
#   'name': 'Beach House Restaurant & Lounge',
#   'neighborhoods': [],
#   'longitude': -89.303789,
#   'state': 'WI',
#   'stars': 3.5,
#   'latitude': 43.017701,
#   'attributes': {'Alcohol': 'full_bar',
#    'Noise Level': 'loud',
#    'Music': {},
#    'Attire': 'casual',
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': True},
#    'Good for Kids': True,
#    'Wheelchair Accessible': True,
#    'Good For Dancing': False,
#    'Delivery': False,
#    'Coat Check': False,
#    'Smoking': 'outdoor',
#    'Accepts Credit Cards': True,
#    'Take-out': True,
#    'Price Range': 2,
#    'Happy Hour': True,
#    'Outdoor Seating': True,
#    'Takes Reservations': True,
#    'Waiter Service': True,
#    'Wi-Fi': 'no',
#    'Caters': False,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': True,
#     'breakfast': False,
#     'brunch': False},
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Has TV': True,
#    'Good For Groups': True},
#   'type': 'business'},
#  {'business_id': 'XrzTVrJAjs0yYLvhFI9vkQ',
#   'full_address': '5508 Broadhead St\nMc Farland, WI 53558',
#   'hours': {},
#   'open': True,
#   'categories': ['Hotels & Travel',
#    'Bed & Breakfast',
#    'Event Planning & Services',
#    'Hotels'],
#   'city': 'Mc Farland',
#   'review_count': 9,
#   'name': 'Parsonage Bed & Breakfast the',
#   'neighborhoods': [],
#   'longitude': -89.285206,
#   'state': 'WI',
#   'stars': 5.0,
#   'latitude': 43.015931,
#   'attributes': {'Accepts Credit Cards': True,
#    'Wi-Fi': 'free',
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': '1tkeiIa-daD8LbM6mHm_9A',
#   'full_address': '4711 Farwell St\nMc Farland, WI 53558',
#   'hours': {'Monday': {'close': '02:00', 'open': '11:00'},
#    'Tuesday': {'close': '02:00', 'open': '11:00'},
#    'Friday': {'close': '02:30', 'open': '11:00'},
#    'Wednesday': {'close': '02:00', 'open': '11:00'},
#    'Thursday': {'close': '02:00', 'open': '11:00'},
#    'Sunday': {'close': '01:00', 'open': '08:00'},
#    'Saturday': {'close': '02:30', 'open': '11:00'}},
#   'open': True,
#   'categories': ['Active Life', 'Bowling'],
#   'city': 'Mc Farland',
#   'review_count': 3,
#   'name': 'Spartan Bowl',
#   'neighborhoods': [],
#   'longitude': -89.3021641,
#   'state': 'WI',
#   'stars': 1.5,
#   'latitude': 43.0131557,
#   'attributes': {'Good for Kids': True},
#   'type': 'business'},
#  {'business_id': 'zOc8lbjViUZajbY7M0aUCQ',
#   'full_address': '5813 Main St\nMc Farland, WI 53558',
#   'hours': {'Tuesday': {'close': '22:00', 'open': '16:30'},
#    'Sunday': {'close': '20:00', 'open': '12:00'},
#    'Thursday': {'close': '22:00', 'open': '16:30'},
#    'Monday': {'close': '21:00', 'open': '16:30'},
#    'Wednesday': {'close': '22:00', 'open': '16:30'}},
#   'open': True,
#   'categories': ['Pizza', 'Restaurants'],
#   'city': 'Mc Farland',
#   'review_count': 4,
#   'name': 'Spartan Pizza',
#   'neighborhoods': [],
#   'longitude': -89.288567,
#   'state': 'WI',
#   'stars': 3.5,
#   'latitude': 43.014164,
#   'attributes': {'Take-out': True,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': False,
#     'brunch': False,
#     'breakfast': False},
#    'Caters': False,
#    'Takes Reservations': False,
#    'Delivery': False,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': False,
#     'valet': False},
#    'Wheelchair Accessible': False,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Alcohol': 'full_bar',
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': False,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': 'UgjVZTSOaYoEvws_lAP_Dw',
#   'full_address': '4850 Larson Beach Rd\nMc Farland, WI 53558',
#   'hours': {},
#   'open': True,
#   'categories': ['Chinese', 'Restaurants'],
#   'city': 'Mc Farland',
#   'review_count': 8,
#   'name': 'Main Moon Chinese Restaurant',
#   'neighborhoods': [],
#   'longitude': -89.2986278,
#   'state': 'WI',
#   'stars': 3.5,
#   'latitude': 43.0179387,
#   'attributes': {'Take-out': True,
#    'Wi-Fi': 'no',
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': False,
#     'brunch': False,
#     'breakfast': False},
#    'Caters': False,
#    'Noise Level': 'average',
#    'Takes Reservations': False,
#    'Has TV': False,
#    'Delivery': False,
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'classy': False,
#     'hipster': False,
#     'divey': False,
#     'touristy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False},
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': False,
#     'valet': False},
#    'Wheelchair Accessible': True,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Alcohol': 'none',
#    'Waiter Service': False,
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': 'HxPpZSY6Q1eARuiahhra6A',
#   'full_address': '6401 University Ave\nMiddleton, WI 53562',
#   'hours': {},
#   'open': False,
#   'categories': ['Event Planning & Services',
#    'Party & Event Planning',
#    'Caterers'],
#   'city': 'Middleton',
#   'review_count': 5,
#   'name': 'Crandalls Carryout & Catering',
#   'neighborhoods': [],
#   'longitude': -89.4918,
#   'state': 'WI',
#   'stars': 4.0,
#   'latitude': 43.093265,
#   'attributes': {'Take-out': True,
#    'Caters': True,
#    'Attire': 'casual',
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': False,
#     'brunch': False,
#     'breakfast': False},
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': False,
#     'valet': False},
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False},
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': False,
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'SKLw05kEIlZcpTD5pqma8Q',
#   'full_address': '2039 Allen Blvd\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '14:00', 'open': '11:00'},
#    'Tuesday': {'close': '14:00', 'open': '11:00'},
#    'Friday': {'close': '21:30', 'open': '16:00'},
#    'Wednesday': {'close': '21:30', 'open': '16:00'},
#    'Thursday': {'close': '21:30', 'open': '16:00'},
#    'Sunday': {'close': '21:00', 'open': '16:00'},
#    'Saturday': {'close': '21:00', 'open': '16:00'}},
#   'open': True,
#   'categories': ['Party & Event Planning',
#    'Asian Fusion',
#    'Event Planning & Services',
#    'Venues & Event Spaces',
#    'Restaurants'],
#   'city': 'Middleton',
#   'review_count': 41,
#   'name': 'Imperial Garden Chinese Restaurant',
#   'neighborhoods': [],
#   'longitude': -89.485169,
#   'state': 'WI',
#   'stars': 3.0,
#   'latitude': 43.090642,
#   'attributes': {'Take-out': True,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': True,
#     'brunch': False,
#     'breakfast': False},
#    'Noise Level': 'average',
#    'Takes Reservations': True,
#    'Has TV': False,
#    'Delivery': False,
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'classy': False,
#     'hipster': False,
#     'divey': False,
#     'touristy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False},
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Wheelchair Accessible': True,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Alcohol': 'full_bar',
#    'Waiter Service': True,
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': '77ESrCo7hQ96VpCWWdvoxg',
#   'full_address': '6230 University Ave\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '21:00', 'open': '06:00'},
#    'Tuesday': {'close': '21:00', 'open': '06:00'},
#    'Friday': {'close': '21:00', 'open': '06:00'},
#    'Wednesday': {'close': '21:00', 'open': '06:00'},
#    'Thursday': {'close': '21:00', 'open': '06:00'},
#    'Sunday': {'close': '14:00', 'open': '08:00'},
#    'Saturday': {'close': '21:00', 'open': '06:00'}},
#   'open': False,
#   'categories': ['Mexican', 'Restaurants'],
#   'city': 'Middleton',
#   'review_count': 17,
#   'name': 'Mi Cocina',
#   'neighborhoods': [],
#   'longitude': -89.4874867,
#   'state': 'WI',
#   'stars': 3.0,
#   'latitude': 43.0910607,
#   'attributes': {'Take-out': True,
#    'Wi-Fi': 'no',
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': True,
#     'brunch': False,
#     'breakfast': False},
#    'Noise Level': 'average',
#    'Good for Kids': True,
#    'Takes Reservations': False,
#    'Has TV': True,
#    'Delivery': False,
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': True},
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Wheelchair Accessible': True,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Alcohol': 'full_bar',
#    'Waiter Service': True,
#    'Accepts Credit Cards': True,
#    'Good For Kids': True,
#    'Good For Groups': True,
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': '368m5-RtrrYWf4hPM_bMlg',
#   'full_address': '8312 Forsythia St\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '21:00', 'open': '09:00'},
#    'Tuesday': {'close': '21:00', 'open': '09:00'},
#    'Friday': {'close': '21:00', 'open': '09:00'},
#    'Wednesday': {'close': '21:00', 'open': '09:00'},
#    'Thursday': {'close': '21:00', 'open': '09:00'},
#    'Sunday': {'close': '21:00', 'open': '12:00'},
#    'Saturday': {'close': '21:00', 'open': '09:00'}},
#   'open': True,
#   'categories': ['Active Life', 'Arts & Entertainment', 'Stadiums & Arenas'],
#   'city': 'Middleton',
#   'review_count': 3,
#   'name': 'Keva Sports Center',
#   'neighborhoods': [],
#   'longitude': -89.5264281,
#   'state': 'WI',
#   'stars': 3.5,
#   'latitude': 43.1101571,
#   'attributes': {'Good for Kids': True},
#   'type': 'business'},
#  {'business_id': 'YjoSdr8uJslIebsQP6c18w',
#   'full_address': '8402 Old Sauk Rd\nMiddleton, WI 53562',
#   'hours': {},
#   'open': True,
#   'categories': ['Pet Services', 'Pets'],
#   'city': 'Middleton',
#   'review_count': 3,
#   'name': 'Wild Birds Unlimited',
#   'neighborhoods': [],
#   'longitude': -89.527273,
#   'state': 'WI',
#   'stars': 4.5,
#   'latitude': 43.077415,
#   'attributes': {'Accepts Credit Cards': True, 'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'rKNtd_M2kWDW8sQKYzetKA',
#   'full_address': '7790 Elmwood Ave\nMiddleton, WI 53562',
#   'hours': {},
#   'open': True,
#   'categories': ['Hotels & Travel',
#    'Event Planning & Services',
#    'Venues & Event Spaces',
#    'Hotels'],
#   'city': 'Middleton',
#   'review_count': 6,
#   'name': 'Staybridge Suites Extended Stay Hotel Middleton/Madison-West',
#   'neighborhoods': [],
#   'longitude': -89.516038,
#   'state': 'WI',
#   'stars': 4.5,
#   'latitude': 43.096271,
#   'attributes': {'Accepts Credit Cards': True,
#    'Wi-Fi': 'free',
#    'Price Range': 3},
#   'type': 'business'},
#  {'business_id': 'x7xS2DJvu8klyNzcpN8QHg',
#   'full_address': '2529 Allen Blvd\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '00:00', 'open': '00:00'},
#    'Tuesday': {'close': '00:00', 'open': '00:00'},
#    'Friday': {'close': '00:00', 'open': '00:00'},
#    'Wednesday': {'close': '00:00', 'open': '00:00'},
#    'Thursday': {'close': '00:00', 'open': '00:00'},
#    'Sunday': {'close': '00:00', 'open': '00:00'},
#    'Saturday': {'close': '00:00', 'open': '00:00'}},
#   'open': True,
#   'categories': ['Pilates',
#    'Yoga',
#    'Weight Loss Centers',
#    'Health & Medical',
#    'Fitness & Instruction',
#    'Active Life'],
#   'city': 'Middleton',
#   'review_count': 5,
#   'name': 'Harbor Athletic Club',
#   'neighborhoods': [],
#   'longitude': -89.4860822,
#   'state': 'WI',
#   'stars': 5.0,
#   'latitude': 43.1030719,
#   'attributes': {'By Appointment Only': False, 'Good for Kids': True},
#   'type': 'business'},
#  {'business_id': 'KTqNU4plO23583DYAMGXYg',
#   'full_address': '2411 Allen Blvd\nMiddleton, WI 53562',
#   'hours': {},
#   'open': True,
#   'categories': ['Sandwiches', 'Pizza', 'Chicken Wings', 'Restaurants'],
#   'city': 'Middleton',
#   'review_count': 3,
#   'name': "Domino's Pizza",
#   'neighborhoods': [],
#   'longitude': -89.4862189,
#   'state': 'WI',
#   'stars': 3.0,
#   'latitude': 43.1003841,
#   'attributes': {'Take-out': True,
#    'Takes Reservations': False,
#    'Delivery': True,
#    'Outdoor Seating': False,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': False,
#     'valet': False},
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'classy': False,
#     'hipster': False,
#     'divey': False,
#     'touristy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False}},
#   'type': 'business'},
#  {'business_id': 'cgCqxPhadIAlsqnD1MoWuQ',
#   'full_address': '1661 Deming Way\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '21:00', 'open': '09:30'},
#    'Tuesday': {'close': '21:00', 'open': '09:30'},
#    'Friday': {'close': '21:00', 'open': '09:30'},
#    'Wednesday': {'close': '21:00', 'open': '09:30'},
#    'Thursday': {'close': '21:00', 'open': '09:30'},
#    'Sunday': {'close': '18:00', 'open': '11:00'},
#    'Saturday': {'close': '21:00', 'open': '09:30'}},
#   'open': True,
#   'categories': ['Shopping',
#    'Arts & Crafts',
#    'Event Planning & Services',
#    'Cards & Stationery',
#    'Art Supplies',
#    'Flowers & Gifts'],
#   'city': 'Middleton',
#   'review_count': 4,
#   'name': 'Archivers',
#   'neighborhoods': [],
#   'longitude': -89.5235246,
#   'state': 'WI',
#   'stars': 3.0,
#   'latitude': 43.0954975,
#   'attributes': {'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': False,
#     'valet': False},
#    'Accepts Credit Cards': True,
#    'Price Range': 3},
#   'type': 'business'},
#  {'business_id': 'YDUB7-NgjKEFn8CERLoKXQ',
#   'full_address': '1700 Deming Way\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '21:00', 'open': '09:00'},
#    'Tuesday': {'close': '21:00', 'open': '09:00'},
#    'Friday': {'close': '21:00', 'open': '09:00'},
#    'Wednesday': {'close': '21:00', 'open': '09:00'},
#    'Thursday': {'close': '21:00', 'open': '09:00'},
#    'Sunday': {'close': '19:00', 'open': '10:00'},
#    'Saturday': {'close': '21:00', 'open': '09:00'}},
#   'open': True,
#   'categories': ['Arts & Crafts',
#    'Shopping',
#    'Knitting Supplies',
#    'Hobby Shops'],
#   'city': 'Middleton',
#   'review_count': 3,
#   'name': 'Michaels',
#   'neighborhoods': [],
#   'longitude': -89.5277025,
#   'state': 'WI',
#   'stars': 4.0,
#   'latitude': 43.0929029,
#   'attributes': {'Parking': {'garage': False,
#     'street': True,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Accepts Credit Cards': True,
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'x7pStpT09Tdc8d7oRU0Tmw',
#   'full_address': '1620 Deming Way\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '20:00', 'open': '10:00'},
#    'Tuesday': {'close': '20:00', 'open': '10:00'},
#    'Friday': {'close': '20:00', 'open': '10:00'},
#    'Wednesday': {'close': '20:00', 'open': '10:00'},
#    'Thursday': {'close': '20:00', 'open': '10:00'},
#    'Sunday': {'close': '17:00', 'open': '12:00'},
#    'Saturday': {'close': '20:00', 'open': '10:00'}},
#   'open': True,
#   'categories': ["Women's Clothing",
#    'Shopping Centers',
#    'Fashion',
#    'Shopping'],
#   'city': 'Middleton',
#   'review_count': 7,
#   'name': 'Greenway Station Shopping Center',
#   'neighborhoods': [],
#   'longitude': -89.52845,
#   'state': 'WI',
#   'stars': 3.5,
#   'latitude': 43.091816,
#   'attributes': {'Parking': {'garage': False,
#     'street': True,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Accepts Credit Cards': True,
#    'Wheelchair Accessible': True,
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': '1-EIdeHewfEVcpoZm38N8A',
#   'full_address': '1901 Cayuga St\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '21:00', 'open': '06:00'},
#    'Tuesday': {'close': '21:00', 'open': '06:00'},
#    'Friday': {'close': '21:00', 'open': '06:00'},
#    'Wednesday': {'close': '21:00', 'open': '06:00'},
#    'Thursday': {'close': '21:00', 'open': '06:00'},
#    'Sunday': {'close': '19:00', 'open': '07:00'},
#    'Saturday': {'close': '21:00', 'open': '06:30'}},
#   'open': True,
#   'categories': ['Food', 'Beer, Wine & Spirits', 'Coffee & Tea'],
#   'city': 'Middleton',
#   'review_count': 22,
#   'name': 'Barriques Wine & Spirits',
#   'neighborhoods': [],
#   'longitude': -89.513737,
#   'state': 'WI',
#   'stars': 4.0,
#   'latitude': 43.096359,
#   'attributes': {'Wi-Fi': 'free',
#    'Price Range': 1,
#    'Outdoor Seating': True,
#    'Parking': {'garage': False,
#     'street': True,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Accepts Credit Cards': True,
#    'Wheelchair Accessible': True},
#   'type': 'business'},
#  {'business_id': 'ShEYKerTwb2LSORE5o_s7A',
#   'full_address': '6720 Frank Lloyd Wright Ave\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '15:00', 'open': '07:00'},
#    'Tuesday': {'close': '15:00', 'open': '07:00'},
#    'Friday': {'close': '15:00', 'open': '07:00'},
#    'Wednesday': {'close': '15:00', 'open': '07:00'},
#    'Thursday': {'close': '15:00', 'open': '07:00'},
#    'Sunday': {'close': '14:00', 'open': '07:00'},
#    'Saturday': {'close': '14:00', 'open': '07:00'}},
#   'open': True,
#   'categories': ['Bakeries',
#    'Food',
#    'Breakfast & Brunch',
#    'Coffee & Tea',
#    'Restaurants'],
#   'city': 'Middleton',
#   'review_count': 38,
#   'name': 'Prairie Cafe & Bakery',
#   'neighborhoods': [],
#   'longitude': -89.496995,
#   'state': 'WI',
#   'stars': 3.5,
#   'latitude': 43.107227,
#   'attributes': {'Take-out': True,
#    'Wi-Fi': 'free',
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': True,
#     'dinner': False,
#     'brunch': False,
#     'breakfast': True},
#    'Caters': False,
#    'Noise Level': 'average',
#    'Takes Reservations': False,
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': True},
#    'Has TV': False,
#    'Delivery': False,
#    'Dogs Allowed': False,
#    'Parking': {'garage': False,
#     'street': True,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Wheelchair Accessible': True,
#    'Outdoor Seating': True,
#    'Attire': 'casual',
#    'Alcohol': 'none',
#    'Waiter Service': False,
#    'Accepts Credit Cards': False,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': 'HaBkx5PwvbBpQ2iNCgHnVQ',
#   'full_address': '2401 Parmenter St\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '11:00', 'open': '07:00'},
#    'Tuesday': {'close': '11:00', 'open': '07:00'},
#    'Friday': {'close': '11:00', 'open': '07:00'},
#    'Wednesday': {'close': '11:00', 'open': '07:00'},
#    'Thursday': {'close': '13:00', 'open': '11:00'},
#    'Sunday': {'close': '11:00', 'open': '08:00'},
#    'Saturday': {'close': '11:00', 'open': '08:00'}},
#   'open': True,
#   'categories': ['Bars', 'American (New)', 'Nightlife', 'Restaurants'],
#   'city': 'Middleton',
#   'review_count': 11,
#   'name': "Paul's Neighborhood Bar",
#   'neighborhoods': [],
#   'longitude': -89.5111616,
#   'state': 'WI',
#   'stars': 3.5,
#   'latitude': 43.1014598,
#   'attributes': {'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': False,
#     'brunch': False,
#     'breakfast': False},
#    'Noise Level': 'average',
#    'Attire': 'casual',
#    'Happy Hour': True,
#    'Music': {'video': False, 'live': False, 'dj': False, 'jukebox': True},
#    'Outdoor Seating': True,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': False,
#     'valet': False},
#    'Alcohol': 'full_bar',
#    'Smoking': 'no',
#    'Takes Reservations': False,
#    'Accepts Credit Cards': True,
#    'Good for Kids': False,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': 'KW6HejC-67KSL9J8Cz1dSw',
#   'full_address': '8414 Old Sauk Rd\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '21:00', 'open': '11:00'},
#    'Tuesday': {'close': '21:00', 'open': '11:00'},
#    'Friday': {'close': '21:00', 'open': '11:00'},
#    'Wednesday': {'close': '21:00', 'open': '11:00'},
#    'Thursday': {'close': '21:00', 'open': '11:00'},
#    'Sunday': {'close': '21:00', 'open': '11:00'},
#    'Saturday': {'close': '21:00', 'open': '11:00'}},
#   'open': True,
#   'categories': ['Chinese', 'Restaurants'],
#   'city': 'Middleton',
#   'review_count': 28,
#   'name': "Chin's Asia Fresh",
#   'neighborhoods': [],
#   'longitude': -89.528480180844,
#   'state': 'WI',
#   'stars': 3.0,
#   'latitude': 43.075345267736,
#   'attributes': {'Take-out': True,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': False,
#     'brunch': False,
#     'breakfast': False},
#    'Noise Level': 'quiet',
#    'Takes Reservations': False,
#    'Delivery': False,
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False},
#    'Has TV': False,
#    'Outdoor Seating': True,
#    'Attire': 'casual',
#    'Alcohol': 'none',
#    'Waiter Service': False,
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'wl-7A4jC0f27MOEmW-XTbQ',
#   'full_address': '2608 Allen Blvd\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '22:00', 'open': '11:00'},
#    'Tuesday': {'close': '22:00', 'open': '11:00'},
#    'Friday': {'close': '23:00', 'open': '11:00'},
#    'Wednesday': {'close': '22:00', 'open': '11:00'},
#    'Thursday': {'close': '22:00', 'open': '11:00'},
#    'Sunday': {'close': '22:00', 'open': '12:00'},
#    'Saturday': {'close': '23:00', 'open': '11:00'}},
#   'open': True,
#   'categories': ['Chinese', 'Restaurants'],
#   'city': 'Middleton',
#   'review_count': 6,
#   'name': 'Grand China Restaurant',
#   'neighborhoods': [],
#   'longitude': -89.4864907,
#   'state': 'WI',
#   'stars': 3.0,
#   'latitude': 43.1036633,
#   'attributes': {'Take-out': True,
#    'Takes Reservations': False,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': False,
#     'valet': False},
#    'Wheelchair Accessible': True,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': False,
#     'brunch': False,
#     'breakfast': False},
#    'Attire': 'casual',
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': 'NGj-_5pkHc_DbH5bKUH2Xw',
#   'full_address': '2313 Parmenter St\nMiddleton, WI 53562',
#   'hours': {},
#   'open': True,
#   'categories': ['Pet Services', 'Pet Boarding/Pet Sitting', 'Pets'],
#   'city': 'Middleton',
#   'review_count': 3,
#   'name': "Lori's Pet-Agree Salon Llc",
#   'neighborhoods': [],
#   'longitude': -89.511068,
#   'state': 'WI',
#   'stars': 5.0,
#   'latitude': 43.100808,
#   'attributes': {},
#   'type': 'business'},
#  {'business_id': 'suQyHycqv8nA7EualcUB3g',
#   'full_address': '8302 Greenway Blvd\nMiddleton, WI 53562',
#   'hours': {},
#   'open': True,
#   'categories': ['Diners', 'Restaurants'],
#   'city': 'Middleton',
#   'review_count': 5,
#   'name': 'Dennys',
#   'neighborhoods': [],
#   'longitude': -89.5241674,
#   'state': 'WI',
#   'stars': 3.0,
#   'latitude': 43.0905631,
#   'attributes': {'Take-out': True,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': False,
#     'breakfast': False,
#     'brunch': False},
#    'Noise Level': 'quiet',
#    'Takes Reservations': False,
#    'Delivery': False,
#    'Has TV': False,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': '3jpKGDkFrCHpjEYVEgcG0A',
#   'full_address': '8310 Greenway Blvd\nMiddleton, WI 53562',
#   'hours': {},
#   'open': True,
#   'categories': ['Food', 'Coffee & Tea'],
#   'city': 'Middleton',
#   'review_count': 6,
#   'name': 'Starbucks',
#   'neighborhoods': [],
#   'longitude': -89.5256818,
#   'state': 'WI',
#   'stars': 3.0,
#   'latitude': 43.0904559,
#   'attributes': {'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Accepts Credit Cards': True,
#    'Wi-Fi': 'free',
#    'Outdoor Seating': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': 'AYoLKzRFajucKnjIFxc__A',
#   'full_address': '1650 Deming Way\nMiddleton, WI 53562',
#   'hours': {},
#   'open': True,
#   'categories': ['Food', 'Ice Cream & Frozen Yogurt'],
#   'city': 'Middleton',
#   'review_count': 6,
#   'name': 'Cold Stone Creamery',
#   'neighborhoods': [],
#   'longitude': -89.5235823,
#   'state': 'WI',
#   'stars': 2.5,
#   'latitude': 43.0954855,
#   'attributes': {'Take-out': True,
#    'Wi-Fi': 'no',
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': False,
#     'brunch': False,
#     'breakfast': False},
#    'Takes Reservations': False,
#    'Has TV': False,
#    'Delivery': False,
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False},
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Wheelchair Accessible': True,
#    'Outdoor Seating': True,
#    'Attire': 'casual',
#    'Alcohol': 'none',
#    'Waiter Service': False,
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 4},
#   'type': 'business'},
#  {'business_id': 'c5awCF5eu0ZkxUf_i94uPA',
#   'full_address': '2611 Branch St\nMiddleton, WI 53562',
#   'hours': {},
#   'open': True,
#   'categories': ['Nightlife'],
#   'city': 'Middleton',
#   'review_count': 16,
#   'name': 'Bristled Boar Saloon & Grill',
#   'neighborhoods': [],
#   'longitude': -89.491807,
#   'state': 'WI',
#   'stars': 3.5,
#   'latitude': 43.103427,
#   'attributes': {'Price Range': 1,
#    'Alcohol': 'full_bar',
#    'Good For Dancing': True,
#    'Noise Level': 'average',
#    'Coat Check': False,
#    'Has TV': True,
#    'Happy Hour': True,
#    'Music': {'video': False, 'live': False, 'dj': False, 'jukebox': True},
#    'Outdoor Seating': True,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False},
#    'Smoking': 'outdoor',
#    'Accepts Credit Cards': True,
#    'Good For Groups': True,
#    'Wheelchair Accessible': True},
#   'type': 'business'},
#  {'business_id': 'uga5g16PncJOtY7Sc3A05w',
#   'full_address': '8308 Greenway Blvd\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '23:00', 'open': '05:00'},
#    'Tuesday': {'close': '23:00', 'open': '05:00'},
#    'Friday': {'close': '00:00', 'open': '05:00'},
#    'Wednesday': {'close': '23:00', 'open': '05:00'},
#    'Thursday': {'close': '23:00', 'open': '05:00'},
#    'Sunday': {'close': '23:00', 'open': '06:00'},
#    'Saturday': {'close': '00:00', 'open': '06:00'}},
#   'open': True,
#   'categories': ['Burgers', 'Fast Food', 'Restaurants'],
#   'city': 'Middleton',
#   'review_count': 6,
#   'name': "McDonald's",
#   'neighborhoods': [],
#   'longitude': -89.5250779,
#   'state': 'WI',
#   'stars': 4.0,
#   'latitude': 43.090653,
#   'attributes': {'Take-out': True,
#    'Wi-Fi': 'free',
#    'Alcohol': 'none',
#    'Caters': False,
#    'Noise Level': 'average',
#    'Takes Reservations': False,
#    'Delivery': False,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': False,
#     'valet': False},
#    'Has TV': True,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': True,
#     'brunch': False,
#     'breakfast': False},
#    'Attire': 'casual',
#    'Waiter Service': False,
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': '9874O-3GjXPotxYKNNAz5Q',
#   'full_address': '1009 N Gammon Rd\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '18:00', 'open': '08:00'},
#    'Tuesday': {'close': '18:00', 'open': '08:00'},
#    'Friday': {'close': '18:00', 'open': '08:00'},
#    'Wednesday': {'close': '18:00', 'open': '08:00'},
#    'Thursday': {'close': '18:00', 'open': '08:00'},
#    'Saturday': {'close': '12:00', 'open': '08:00'}},
#   'open': True,
#   'categories': ['Veterinarians', 'Pets'],
#   'city': 'Middleton',
#   'review_count': 5,
#   'name': 'All Pets Veterinary Clinic',
#   'neighborhoods': [],
#   'longitude': -89.5022518,
#   'state': 'WI',
#   'stars': 5.0,
#   'latitude': 43.082611,
#   'attributes': {},
#   'type': 'business'},
#  {'business_id': 'naqkXvhoqljvA7kuo15gEw',
#   'full_address': '8212 Greenway Blvd\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '00:00', 'open': '00:00'},
#    'Tuesday': {'close': '00:00', 'open': '00:00'},
#    'Friday': {'close': '00:00', 'open': '00:00'},
#    'Wednesday': {'close': '00:00', 'open': '00:00'},
#    'Thursday': {'close': '00:00', 'open': '00:00'},
#    'Sunday': {'close': '00:00', 'open': '00:00'},
#    'Saturday': {'close': '00:00', 'open': '00:00'}},
#   'open': True,
#   'categories': ['Hotels & Travel', 'Event Planning & Services', 'Hotels'],
#   'city': 'Middleton',
#   'review_count': 8,
#   'name': 'Fairfield Inn & Suites Madison West',
#   'neighborhoods': [],
#   'longitude': -89.5233883,
#   'state': 'WI',
#   'stars': 3.5,
#   'latitude': 43.0901268,
#   'attributes': {'Dogs Allowed': False,
#    'Accepts Credit Cards': True,
#    'Wi-Fi': 'free',
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'xbJ9tdGbcVJIUkNgHSCwZQ',
#   'full_address': '1914 Aurora St\nMiddleton, WI 53562',
#   'hours': {},
#   'open': True,
#   'categories': ['Bars', 'Nightlife', 'Restaurants'],
#   'city': 'Middleton',
#   'review_count': 10,
#   'name': 'Hody Bar & Grill',
#   'neighborhoods': [],
#   'longitude': -89.5128222,
#   'state': 'WI',
#   'stars': 2.5,
#   'latitude': 43.095696,
#   'attributes': {'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': False,
#     'brunch': False,
#     'breakfast': False},
#    'Good For Dancing': True,
#    'Noise Level': 'quiet',
#    'Takes Reservations': False,
#    'Has TV': True,
#    'Smoking': 'no',
#    'Delivery': False,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': False,
#     'valet': False},
#    'Wheelchair Accessible': True,
#    'Outdoor Seating': True,
#    'Attire': 'casual',
#    'Alcohol': 'full_bar',
#    'Waiter Service': True,
#    'Accepts Credit Cards': True,
#    'Good for Kids': False,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': 'koRLvzIl-4fCybOIdk56jA',
#   'full_address': '7464 Hubbard Ave\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '23:00', 'open': '17:00'},
#    'Tuesday': {'close': '23:00', 'open': '17:00'},
#    'Friday': {'close': '23:00', 'open': '17:00'},
#    'Wednesday': {'close': '23:00', 'open': '17:00'},
#    'Thursday': {'close': '23:00', 'open': '17:00'},
#    'Saturday': {'close': '23:00', 'open': '17:00'}},
#   'open': True,
#   'categories': ['Cajun/Creole', 'Restaurants'],
#   'city': 'Middleton',
#   'review_count': 56,
#   'name': "Louisianne's Etc",
#   'neighborhoods': [],
#   'longitude': -89.5110574,
#   'state': 'WI',
#   'stars': 4.0,
#   'latitude': 43.0955526,
#   'attributes': {'Take-out': False,
#    'Wi-Fi': 'no',
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': True,
#     'brunch': False,
#     'breakfast': False},
#    'Noise Level': 'average',
#    'Good for Kids': False,
#    'Takes Reservations': True,
#    'Has TV': False,
#    'Delivery': False,
#    'Ambience': {'romantic': True,
#     'intimate': False,
#     'classy': False,
#     'hipster': False,
#     'divey': False,
#     'touristy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False},
#    'Parking': {'garage': False,
#     'street': True,
#     'validated': False,
#     'lot': False,
#     'valet': False},
#    'Wheelchair Accessible': False,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Alcohol': 'full_bar',
#    'Waiter Service': True,
#    'Accepts Credit Cards': True,
#    'Good For Kids': False,
#    'Good For Groups': True,
#    'Price Range': 3},
#   'type': 'business'},
#  {'business_id': 'ckLRf3lYn9DxmNxd-mu2yA',
#   'full_address': '1313 John Q Hammons Dr\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '17:00', 'open': '09:00'}},
#   'open': True,
#   'categories': ['Hotels & Travel', 'Event Planning & Services', 'Hotels'],
#   'city': 'Middleton',
#   'review_count': 35,
#   'name': 'Marriott-Madison West',
#   'neighborhoods': [],
#   'longitude': -89.523172,
#   'state': 'WI',
#   'stars': 2.5,
#   'latitude': 43.087887,
#   'attributes': {'Take-out': False,
#    'Wi-Fi': 'paid',
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': False,
#     'brunch': False,
#     'breakfast': False},
#    'Noise Level': 'very_loud',
#    'Takes Reservations': True,
#    'Has TV': True,
#    'Delivery': False,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Wheelchair Accessible': True,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Alcohol': 'full_bar',
#    'Waiter Service': True,
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'Bznf9AaGgdsLI01H_ifrUA',
#   'full_address': '7625 Lisa Ln\nMiddleton, WI 53562',
#   'hours': {},
#   'open': True,
#   'categories': ['Active Life', 'Amateur Sports Teams'],
#   'city': 'Middleton',
#   'review_count': 3,
#   'name': 'Bowling Green Rec Center',
#   'neighborhoods': [],
#   'longitude': -89.511857,
#   'state': 'WI',
#   'stars': 3.5,
#   'latitude': 43.1083799,
#   'attributes': {'Good for Kids': True},
#   'type': 'business'},
#  {'business_id': 'YaaQx4qt1f36iFT4TWivAw',
#   'full_address': '7610 Donna Dr\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '17:30', 'open': '07:00'},
#    'Tuesday': {'close': '17:30', 'open': '07:00'},
#    'Friday': {'close': '17:30', 'open': '07:00'},
#    'Wednesday': {'close': '17:30', 'open': '07:00'},
#    'Thursday': {'close': '17:30', 'open': '07:00'},
#    'Saturday': {'close': '17:00', 'open': '07:30'}},
#   'open': True,
#   'categories': ['Bakeries', 'Food'],
#   'city': 'Middleton',
#   'review_count': 14,
#   'name': "Clasen's European Bakery",
#   'neighborhoods': [],
#   'longitude': -89.51178,
#   'state': 'WI',
#   'stars': 3.5,
#   'latitude': 43.1060972,
#   'attributes': {'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Accepts Credit Cards': True,
#    'Wheelchair Accessible': True,
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'MBQc_jlZ3nlMOZy7SUM_5Q',
#   'full_address': '1801 Deming Way\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '00:00', 'open': '00:00'},
#    'Tuesday': {'close': '00:00', 'open': '00:00'},
#    'Friday': {'close': '00:00', 'open': '00:00'},
#    'Wednesday': {'close': '00:00', 'open': '00:00'},
#    'Thursday': {'close': '00:00', 'open': '00:00'},
#    'Sunday': {'close': '00:00', 'open': '00:00'},
#    'Saturday': {'close': '00:00', 'open': '00:00'}},
#   'open': True,
#   'categories': ['Hotels & Travel', 'Event Planning & Services', 'Hotels'],
#   'city': 'Middleton',
#   'review_count': 12,
#   'name': 'Hilton Garden Inn Madison West/Middleton',
#   'neighborhoods': [],
#   'longitude': -89.525484,
#   'state': 'WI',
#   'stars': 4.0,
#   'latitude': 43.092882,
#   'attributes': {'Dogs Allowed': False,
#    'Accepts Credit Cards': True,
#    'Wi-Fi': 'free',
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'cruBFtsFaBuhX_I72uU8pA',
#   'full_address': '6615 University Ave\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '22:00', 'open': '10:00'},
#    'Tuesday': {'close': '22:00', 'open': '10:00'},
#    'Friday': {'close': '22:00', 'open': '10:00'},
#    'Wednesday': {'close': '22:00', 'open': '10:00'},
#    'Thursday': {'close': '22:00', 'open': '10:00'},
#    'Sunday': {'close': '22:00', 'open': '10:00'},
#    'Saturday': {'close': '22:00', 'open': '10:00'}},
#   'open': True,
#   'categories': ['Pizza', 'Restaurants'],
#   'city': 'Middleton',
#   'review_count': 3,
#   'name': "Papa John's Pizza",
#   'neighborhoods': [],
#   'longitude': -89.4949208,
#   'state': 'WI',
#   'stars': 1.5,
#   'latitude': 43.0955472,
#   'attributes': {'Take-out': True,
#    'Alcohol': 'none',
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': False,
#     'valet': False},
#    'Price Range': 2,
#    'Good For Groups': True,
#    'Wheelchair Accessible': True},
#   'type': 'business'},
#  {'business_id': 'X47o6R2rWiqGqvBtC7VS3Q',
#   'full_address': '2227 Parmenter St\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '14:00', 'open': '06:30'},
#    'Tuesday': {'close': '14:00', 'open': '06:30'},
#    'Friday': {'close': '13:30', 'open': '06:30'},
#    'Wednesday': {'close': '14:00', 'open': '06:30'},
#    'Thursday': {'close': '14:00', 'open': '06:30'},
#    'Sunday': {'close': '12:00', 'open': '07:00'},
#    'Saturday': {'close': '12:00', 'open': '06:30'}},
#   'open': True,
#   'categories': ['Breakfast & Brunch', 'Restaurants'],
#   'city': 'Middleton',
#   'review_count': 19,
#   'name': 'Three Sisters Old Town Inn',
#   'neighborhoods': [],
#   'longitude': -89.511243,
#   'state': 'WI',
#   'stars': 4.0,
#   'latitude': 43.0999335,
#   'attributes': {'Take-out': True,
#    'Wi-Fi': 'no',
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': False,
#     'brunch': False,
#     'breakfast': True},
#    'Caters': False,
#    'Noise Level': 'average',
#    'Takes Reservations': False,
#    'Delivery': False,
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': True},
#    'Parking': {'garage': False,
#     'street': True,
#     'validated': False,
#     'lot': False,
#     'valet': False},
#    'Has TV': False,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Alcohol': 'none',
#    'Waiter Service': True,
#    'Accepts Credit Cards': False,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': '_tnYCShXuDlXjNVNctTkCA',
#   'full_address': '6323 University Ave\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '17:00', 'open': '08:00'},
#    'Tuesday': {'close': '17:00', 'open': '08:00'},
#    'Friday': {'close': '17:00', 'open': '08:00'},
#    'Wednesday': {'close': '17:00', 'open': '08:00'},
#    'Thursday': {'close': '17:00', 'open': '08:00'},
#    'Saturday': {'close': '14:00', 'open': '09:00'}},
#   'open': True,
#   'categories': ['Barbers', 'Beauty & Spas'],
#   'city': 'Middleton',
#   'review_count': 11,
#   'name': "Dick & Arnie's Barber Shop",
#   'neighborhoods': [],
#   'longitude': -89.4904366,
#   'state': 'WI',
#   'stars': 4.5,
#   'latitude': 43.0926846,
#   'attributes': {'By Appointment Only': False,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Accepts Credit Cards': False,
#    'Wheelchair Accessible': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': 'elBgDynz6UPoSqQgxiggJw',
#   'full_address': '3201 Glacier Ridge Rd\nMiddleton, WI 53562',
#   'hours': {},
#   'open': True,
# ...
#    'Saturday': {'close': '17:30', 'open': '08:30'}},
#   'open': False,
#   'categories': ['Car Wash', 'Automotive'],
#   'city': 'Phoenix',
#   'review_count': 16,
#   'name': 'Arcadia Car Wash',
#   'neighborhoods': [],
#   'longitude': -111.9867688,
#   'state': 'AZ',
#   'stars': 4.0,
#   'latitude': 33.4948739,
#   'attributes': {},
#   'type': 'business'},
#  {'business_id': 'VxnV1uMZURUQMNUaPdB8QA',
#   'full_address': '4515 E Thomas Rd\nPhoenix, AZ 85018',
#   'hours': {'Monday': {'close': '23:00', 'open': '08:00'},
#    'Tuesday': {'close': '23:00', 'open': '08:00'},
#    'Friday': {'close': '23:00', 'open': '08:00'},
#    'Wednesday': {'close': '23:00', 'open': '08:00'},
#    'Thursday': {'close': '23:00', 'open': '08:00'},
#    'Sunday': {'close': '22:00', 'open': '08:00'},
#    'Saturday': {'close': '23:00', 'open': '08:00'}},
#   'open': True,
#   'categories': ['Department Stores', 'Fashion', 'Shopping', 'Drugstores'],
#   'city': 'Phoenix',
#   'review_count': 36,
#   'name': 'Target',
#   'neighborhoods': [],
#   'longitude': -111.9850859,
#   'state': 'AZ',
#   'stars': 4.0,
#   'latitude': 33.4801135,
#   'attributes': {'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Accepts Credit Cards': True,
#    'Wheelchair Accessible': True,
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'JksZiHb_Vj1tYRTpuTg-uQ',
#   'full_address': '4519 E Thomas Rd\nPhoenix, AZ 85018',
#   'hours': {'Monday': {'close': '21:00', 'open': '08:00'},
#    'Tuesday': {'close': '21:00', 'open': '08:00'},
#    'Friday': {'close': '21:00', 'open': '08:00'},
#    'Wednesday': {'close': '21:00', 'open': '08:00'},
#    'Thursday': {'close': '21:00', 'open': '08:00'},
#    'Sunday': {'close': '18:00', 'open': '10:00'},
#    'Saturday': {'close': '19:00', 'open': '09:00'}},
#   'open': True,
#   'categories': ['Shopping', 'Office Equipment'],
#   'city': 'Phoenix',
#   'review_count': 7,
#   'name': 'Office Max',
#   'neighborhoods': [],
#   'longitude': -111.9854985,
#   'state': 'AZ',
#   'stars': 4.0,
#   'latitude': 33.4800765,
#   'attributes': {'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Accepts Credit Cards': True,
#    'Wheelchair Accessible': True,
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'SDwYQ6eSu1htn8vHWv128g',
#   'full_address': '3939 E Campbell Ave\nPhoenix, AZ 85018',
#   'hours': {'Monday': {'close': '23:00', 'open': '11:00'},
#    'Tuesday': {'close': '23:00', 'open': '11:00'},
#    'Friday': {'close': '00:00', 'open': '11:00'},
#    'Wednesday': {'close': '23:00', 'open': '11:00'},
#    'Thursday': {'close': '23:00', 'open': '11:00'},
#    'Sunday': {'close': '22:00', 'open': '09:00'},
#    'Saturday': {'close': '00:00', 'open': '09:00'}},
#   'open': True,
#   'categories': ['Wine Bars', 'Bars', 'Restaurants', 'Nightlife', 'Italian'],
#   'city': 'Phoenix',
#   'review_count': 921,
#   'name': 'Postino Arcadia',
#   'neighborhoods': [],
#   'longitude': -111.996292,
#   'state': 'AZ',
#   'stars': 4.5,
#   'latitude': 33.502191,
#   'attributes': {'Alcohol': 'beer_and_wine',
#    'Open 24 Hours': False,
#    'Noise Level': 'average',
#    'Music': {'dj': False,
#     'background_music': True,
#     'jukebox': False,
#     'live': False,
#     'video': False,
#     'karaoke': False},
#    'Attire': 'casual',
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'classy': False,
#     'hipster': False,
#     'divey': False,
#     'touristy': False,
#     'trendy': True,
#     'upscale': False,
#     'casual': False},
#    'Good for Kids': False,
#    'Wheelchair Accessible': True,
#    'Delivery': False,
#    'Good For Dancing': False,
#    'BYOB': False,
#    'Coat Check': False,
#    'Smoking': 'outdoor',
#    'Accepts Credit Cards': True,
#    'BYOB/Corkage': 'no',
#    'Take-out': True,
#    'Price Range': 2,
#    'Corkage': False,
#    'Happy Hour': True,
#    'Outdoor Seating': True,
#    'Takes Reservations': True,
#    'Waiter Service': True,
#    'Wi-Fi': 'no',
#    'Caters': True,
#    'Dietary Restrictions': {'dairy-free': False,
#     'gluten-free': False,
#     'vegan': True,
#     'kosher': False,
#     'halal': False,
#     'soy-free': False,
#     'vegetarian': True},
#    'Order at Counter': False,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': True,
#     'dinner': True,
#     'brunch': False,
#     'breakfast': False},
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': False,
#     'valet': True},
#    'Has TV': False,
#    'Good For Kids': False,
#    'Good For Groups': True},
#   'type': 'business'},
#  {'business_id': '7UTlEVHU5v2xBLdkGghyzQ',
#   'full_address': '3222 E Indian School Rd\nPhoenix, AZ 85018',
#   'hours': {},
#   'open': False,
#   'categories': ['Mexican', 'Restaurants'],
#   'city': 'Phoenix',
#   'review_count': 21,
#   'name': "Chuy's Mesquite Broiler",
#   'neighborhoods': [],
#   'longitude': -112.0119403,
#   'state': 'AZ',
#   'stars': 3.5,
#   'latitude': 33.4953259,
#   'attributes': {'Take-out': True,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': True,
#     'dinner': False,
#     'brunch': False,
#     'breakfast': False},
#    'Takes Reservations': False,
#    'BYOB/Corkage': 'no',
#    'Delivery': False,
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False},
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Wheelchair Accessible': True,
#    'Outdoor Seating': True,
#    'Attire': 'casual',
#    'Alcohol': 'full_bar',
#    'Waiter Service': False,
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': '5WQhLNpG6xZryVCla4gMRA',
#   'full_address': '4505 E Thomas Rd\nPhoenix, AZ 85018',
#   'hours': {'Monday': {'close': '00:00', 'open': '06:00'},
#    'Tuesday': {'close': '00:00', 'open': '06:00'},
#    'Friday': {'close': '00:00', 'open': '06:00'},
#    'Wednesday': {'close': '00:00', 'open': '06:00'},
#    'Thursday': {'close': '00:00', 'open': '06:00'},
#    'Sunday': {'close': '00:00', 'open': '06:00'},
#    'Saturday': {'close': '00:00', 'open': '06:00'}},
#   'open': True,
#   'categories': ['Grocery',
#    'American (Traditional)',
#    'Shopping',
#    'Drugstores',
#    'Food',
#    'Restaurants'],
#   'city': 'Phoenix',
#   'review_count': 26,
#   'name': "Fry's Food Store",
#   'neighborhoods': [],
#   'longitude': -111.984771,
#   'state': 'AZ',
#   'stars': 2.5,
#   'latitude': 33.479131,
#   'attributes': {'Take-out': False,
#    'Wi-Fi': 'free',
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': False,
#     'brunch': False,
#     'breakfast': False},
#    'Caters': True,
#    'Noise Level': 'quiet',
#    'Takes Reservations': False,
#    'Has TV': True,
#    'BYOB/Corkage': 'yes_corkage',
#    'Delivery': False,
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'classy': False,
#     'hipster': False,
#     'divey': False,
#     'touristy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False},
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Wheelchair Accessible': True,
#    'Corkage': True,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Alcohol': 'full_bar',
#    'Waiter Service': False,
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'r-EVE9HYaJoaaK82Z7o3OQ',
#   'full_address': '5130 E Thomas Rd\nPhoenix, AZ 85018',
#   'hours': {},
#   'open': True,
#   'categories': ['Pet Groomers', 'Pet Services', 'Pets'],
#   'city': 'Phoenix',
#   'review_count': 5,
#   'name': 'Ingleside Grooming',
#   'neighborhoods': [],
#   'longitude': -111.9702112,
#   'state': 'AZ',
#   'stars': 4.0,
#   'latitude': 33.4801284,
#   'attributes': {},
#   'type': 'business'},
#  {'business_id': 'yJr24Yy1K6bt2G9fX3_zPA',
#   'full_address': '4225 E Camelback Rd\nPhoenix, AZ 85018',
#   'hours': {'Monday': {'close': '21:30', 'open': '11:00'},
#    'Tuesday': {'close': '21:30', 'open': '11:00'},
#    'Friday': {'close': '22:00', 'open': '11:00'},
#    'Wednesday': {'close': '21:30', 'open': '11:00'},
#    'Thursday': {'close': '21:30', 'open': '11:00'},
#    'Sunday': {'close': '21:00', 'open': '16:00'},
#    'Saturday': {'close': '22:00', 'open': '11:00'}},
#   'open': False,
#   'categories': ['Cuban', 'Caribbean', 'Restaurants'],
#   'city': 'Phoenix',
#   'review_count': 188,
#   'name': 'Havana Cafe',
#   'neighborhoods': [],
#   'longitude': -111.9885861,
#   'state': 'AZ',
#   'stars': 3.5,
#   'latitude': 33.5092093,
#   'attributes': {'Take-out': True,
#    'Wi-Fi': 'no',
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': True,
#     'brunch': False,
#     'breakfast': False},
#    'Caters': True,
#    'Noise Level': 'average',
#    'Good for Kids': False,
#    'Takes Reservations': True,
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': True},
#    'Has TV': False,
#    'Delivery': False,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Order at Counter': False,
#    'Wheelchair Accessible': True,
#    'Outdoor Seating': True,
#    'Attire': 'casual',
#    'Alcohol': 'full_bar',
#    'Waiter Service': True,
#    'Accepts Credit Cards': True,
#    'Good For Kids': False,
#    'Good For Groups': True,
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'Qj2h9JA59E_J-ogfdjx7Lg',
#   'full_address': '3623 E Indian School Rd\nPhoenix, AZ 85018',
#   'hours': {},
#   'open': True,
#   'categories': [],
#   'city': 'Phoenix',
#   'review_count': 4,
#   'name': 'Famous Wings',
#   'neighborhoods': [],
#   'longitude': -112.0031664,
#   'state': 'AZ',
#   'stars': 2.5,
#   'latitude': 33.495169,
#   'attributes': {},
#   'type': 'business'},
#  {'business_id': 'wdEnI9WTLHiqSCH1RdJ40w',
#   'full_address': '4732 E Thomas Rd\nPhoenix, AZ 85018',
#   'hours': {},
#   'open': True,
#   'categories': ['Mexican', 'Restaurants'],
#   'city': 'Phoenix',
#   'review_count': 16,
#   'name': 'Los Armandos',
#   'neighborhoods': [],
#   'longitude': -111.978627,
#   'state': 'AZ',
#   'stars': 3.0,
#   'latitude': 33.480391,
#   'attributes': {'Take-out': True,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': True,
#     'dinner': False,
#     'breakfast': False,
#     'brunch': False},
#    'Takes Reservations': False,
#    'Delivery': False,
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False},
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Has TV': True,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Alcohol': 'none',
#    'Waiter Service': False,
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': 'qz4ZOcv-840UjfCEYI4qZg',
#   'full_address': '4829 E Indian School Rd\nPhoenix, AZ 85018',
#   'hours': {'Monday': {'close': '00:00', 'open': '15:30'},
#    'Tuesday': {'close': '00:00', 'open': '15:30'},
#    'Friday': {'close': '02:00', 'open': '15:30'},
#    'Wednesday': {'close': '00:00', 'open': '15:30'},
#    'Thursday': {'close': '00:00', 'open': '15:30'},
#    'Sunday': {'close': '17:30', 'open': '11:00'},
#    'Saturday': {'close': '02:00', 'open': '11:00'}},
#   'open': True,
#   'categories': ['Burgers',
#    'Bars',
#    'American (Traditional)',
#    'Nightlife',
#    'Restaurants'],
#   'city': 'Phoenix',
#   'review_count': 62,
#   'name': "Jt's Bar & Grill",
#   'neighborhoods': [],
#   'longitude': -111.976613,
#   'state': 'AZ',
#   'stars': 4.0,
#   'latitude': 33.494204,
#   'attributes': {'Drive-Thru': False,
#    'Alcohol': 'full_bar',
#    'Noise Level': 'average',
#    'Music': {'dj': False,
#     'background_music': False,
#     'jukebox': True,
#     'live': False,
#     'video': False,
#     'karaoke': False},
#    'Attire': 'casual',
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': True,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False},
#    'Good for Kids': False,
#    'Wheelchair Accessible': True,
#    'Good For Dancing': False,
#    'Delivery': False,
#    'Coat Check': False,
#    'Smoking': 'outdoor',
#    'Accepts Credit Cards': True,
#    'BYOB/Corkage': 'no',
#    'Take-out': True,
#    'Price Range': 1,
#    'Happy Hour': False,
#    'Outdoor Seating': True,
#    'Takes Reservations': False,
#    'Waiter Service': True,
#    'Wi-Fi': 'free',
#    'Caters': False,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': True,
#     'breakfast': False,
#     'brunch': False},
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Has TV': True,
#    'Good For Groups': False},
#   'type': 'business'},
#  {'business_id': '015GCpe-tMj1En4NORROzA',
#   'full_address': '4801 E Indian School Rd\nSte 6\nPhoenix, AZ 85018',
#   'hours': {'Monday': {'close': '19:00', 'open': '07:00'},
#    'Tuesday': {'close': '19:00', 'open': '07:00'},
#    'Friday': {'close': '19:00', 'open': '07:00'},
#    'Wednesday': {'close': '19:00', 'open': '07:00'},
#    'Thursday': {'close': '19:00', 'open': '07:00'},
#    'Saturday': {'close': '18:00', 'open': '09:00'}},
#   'open': True,
#   'categories': ['Local Services', 'Dry Cleaning & Laundry'],
#   'city': 'Phoenix',
#   'review_count': 14,
#   'name': 'Elite Cleaners',
#   'neighborhoods': [],
#   'longitude': -111.977756,
#   'state': 'AZ',
#   'stars': 4.5,
#   'latitude': 33.49413,
#   'attributes': {'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Accepts Credit Cards': True,
#    'Wi-Fi': 'no',
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'AJONCMi8dnGWAkD-86FK5A',
#   'full_address': '4280 E Indian School Rd\nSte 107\nPhoenix, AZ 85018',
#   'hours': {'Monday': {'close': '18:00', 'open': '09:00'},
#    'Tuesday': {'close': '18:00', 'open': '09:00'},
#    'Friday': {'close': '18:00', 'open': '09:00'},
#    'Wednesday': {'close': '18:00', 'open': '09:00'},
#    'Thursday': {'close': '18:00', 'open': '09:00'},
#    'Sunday': {'close': '17:00', 'open': '11:00'},
#    'Saturday': {'close': '17:00', 'open': '08:00'}},
#   'open': True,
#   'categories': ['Shopping',
#    'Optometrists',
#    'Health & Medical',
#    'Eyewear & Opticians'],
#   'city': 'Phoenix',
#   'review_count': 11,
#   'name': 'Nationwide Vision Centers',
#   'neighborhoods': [],
#   'longitude': -111.9891177,
#   'state': 'AZ',
#   'stars': 2.5,
#   'latitude': 33.495074,
#   'attributes': {'By Appointment Only': True,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': False,
#     'valet': False},
#    'Accepts Credit Cards': True,
#    'Wheelchair Accessible': True,
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'FRDZ59oRvUSs4gf-itOCBg',
#   'full_address': '4343 E Camelback Rd\nPhoenix, AZ 85018',
#   'hours': {},
#   'open': True,
#   'categories': ['Restaurants'],
#   'city': 'Phoenix',
#   'review_count': 3,
#   'name': 'Jack in the Box',
#   'neighborhoods': [],
#   'longitude': -111.9875851,
#   'state': 'AZ',
#   'stars': 3.5,
#   'latitude': 33.5091326,
#   'attributes': {'Take-out': True,
#    'Takes Reservations': False,
#    'Delivery': False,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'classy': False,
#     'hipster': False,
#     'divey': False,
#     'touristy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False},
#    'Waiter Service': False,
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  ...]

# %%
yelp_df = pd.DataFrame(yelp_data)
yelp_df.head()
# Out:
#                                           attributes             business_id  \
# 0                      {'By Appointment Only': True}  vcNAWiLM4dR7D2nwwJ7nCA
# 1  {'Take-out': True, 'Good For': {'dessert': Fal...  JwUE5GmEO-sH1FuwJgKBlQ
# 2  {'Take-out': True, 'Good For': {'dessert': Fal...  uGykseHzyS5xAMWoN6YUqA
# 3  {'Take-out': True, 'Wi-Fi': 'free', 'Takes Res...  LRKJF43s9-3jG9Lgx4zODg
# 4  {'Take-out': True, 'Has TV': False, 'Outdoor S...  RgDg-k9S5YD_BaxMckifkg
#
#                                           categories       city  \
# 0                        [Doctors, Health & Medical]    Phoenix
# 1                                      [Restaurants]  De Forest
# 2              [American (Traditional), Restaurants]  De Forest
# 3  [Food, Ice Cream & Frozen Yogurt, Fast Food, R...  De Forest
# 4                             [Chinese, Restaurants]  De Forest
#
#                                         full_address  \
# 0  4840 E Indian School Rd\nSte 101\nPhoenix, AZ ...
# 1            6162 US Highway 51\nDe Forest, WI 53532
# 2                505 W North St\nDe Forest, WI 53532
# 3              4910 County Rd V\nDe Forest, WI 53532
# 4                 631 S Main St\nDe Forest, WI 53532
#
#                                                hours   latitude   longitude  \
# 0  {'Tuesday': {'close': '17:00', 'open': '08:00'...  33.499313 -111.983758
# 1                                                 {}  43.238893  -89.335844
# 2  {'Monday': {'close': '22:00', 'open': '06:00'}...  43.252267  -89.353437
# 3  {'Monday': {'close': '22:00', 'open': '10:30'}...  43.251045  -89.374983
# 4  {'Monday': {'close': '22:00', 'open': '11:00'}...  43.240875  -89.343722
#
#                           name neighborhoods  open  review_count  stars state  \
# 0            Eric Goldberg, MD            []  True             7    3.5    AZ
# 1         Pine Cone Restaurant            []  True            26    4.0    WI
# 2   Deforest Family Restaurant            []  True            16    4.0    WI
# 3                     Culver's            []  True             7    4.5    WI
# 4  Chang Jiang Chinese Kitchen            []  True             3    4.0    WI
#
#        type
# 0  business
# 1  business
# 2  business
# 3  business
# 4  business

# %% [markdown]
# ## Pandas DataFrame and Series
#
# The Pandas DataFrame is a highly structured object. Each row corresponds with some physical entity or event. We think of all of the information in a given row as referring to one object (e.g. a business). Each column contains one type of data, both semantically (e.g. names, counts of reviews, star ratings) and syntactically.

# %%
yelp_df.dtypes
# Out:
# attributes        object
# business_id       object
# categories        object
# city              object
# full_address      object
# hours             object
# latitude         float64
# longitude        float64
# name              object
# neighborhoods     object
# open                bool
# review_count       int64
# stars            float64
# state             object
# type              object
# dtype: object

# %%
yelp_df.columns
# Out:
# Index(['attributes', 'business_id', 'categories', 'city', 'full_address',
#        'hours', 'latitude', 'longitude', 'name', 'neighborhoods', 'open',
#        'review_count', 'stars', 'state', 'type'],
#       dtype='object')

# %%
yelp_df.index
# Out:
# RangeIndex(start=0, stop=37938, step=1)

# %% [markdown]
# We can reference the columns by name, like we would with a `dict`.

# %%
yelp_df['city'].head()
# Out:
# 0      Phoenix
# 1    De Forest
# 2    De Forest
# 3    De Forest
# 4    De Forest
# Name: city, dtype: object

# %%
type(yelp_df['city'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# An individual column is a Pandas `Series`. A `Series` has a `name` and a `dtype` (similar to a NumPy array). A `DataFrame` is essentially a `dict` of `Series` objects. The `Series` has an `index` attribute, which label the rows. The index is essentially a set of keys for referencing the rows. We can have an index composed of numbers, strings, timestamps, or any hashable Python object. The index will also have homogeneous type.

# %%
yelp_df['city'].index
# Out:
# RangeIndex(start=0, stop=37938, step=1)

# %% [markdown]
# The `DataFrame` has an `index` given by the union of indices of its constituent `Series` (we'll explore this later in more detail). Since a `DataFrame` is a `dict` of `Series`, we can select a column and then a row using square bracket notation, but not the reverse (however, the `loc` method works around this).

# %%
# this works
yelp_df['city'][100]
# Out:
# 'Madison'

# %%
	yelp_df['longitude'][100]
# Out:
# -89.3083769

# %%
# %%expect_exception KeyError
#
# # this doesn't
# yelp_df[100]['city']
# Out:
# UsageError: Cell magic `%%expect_exception` not found.

# %%
yelp_df.loc[100, 'city']
# Out:
# 'Madison'

# %% [markdown]
# Understanding the underlying structure of the `DataFrame` object as a `dict` of `Series` will help you avoid errors and help you think about how the `DataFrame` should behave when we begin doing more complicated analysis.
#
# We can _aggregate_ data in a `DataFrame` using methods like `mean`, `sum`, `count`, and `std`. To view a collection of summary statistics for each column we can use the `describe` method.

# %%
yelp_df.describe()
# Out:
#            latitude     longitude  review_count         stars
# count  37938.000000  37938.000000  37938.000000  37938.000000
# mean      36.530288   -104.097172     29.300648      3.672914
# std        5.822588     28.365375     92.893064      0.888730
# min       32.876638   -115.369725      3.000000      1.000000
# 25%       33.476739   -115.136389      4.000000      3.000000
# 50%       33.680247   -112.068820      8.000000      3.500000
# 75%       36.141875   -111.883274     21.000000      4.500000
# max       56.033777     -3.050088   4084.000000      5.000000

# %%
yelp_df['latitude'].count()
# Out:
# 37938

# %% [markdown]
# The utility of a DataFrame comes from its ability to split data into groups, using the `groupby` method, and then perform custom aggregations using the `apply` or `aggregate` method. This process of splitting the data into groups, applying an aggregation, and then collecting the results is [discussed in detail in the Pandas documentation](https://pandas.pydata.org/pandas-docs/stable/groupby.html), and is one of the main focuses of this notebook.

# %% [markdown]
# ## DataFrame construction
#
# Since a `DataFrame` is a `dict` of `Series`, the natural way to construct a `DataFrame` is to use a `dict` of `Series`-like objects.

# %%
from string import ascii_letters, digits
import numpy as np
import datetime


usernames = ['alice36', 'bob_smith', 'eve']
passwords = [''.join(np.random.choice(list(ascii_letters + digits), 8)) for x in range(3)]
creation_dates = [datetime.datetime.now().date() - datetime.timedelta(int(x)) for x in np.random.randint(0, 1500, 3)]

df = pd.DataFrame({'username': usernames, 'password': passwords, 'date-created': pd.to_datetime(creation_dates)})
df

# %%
import numpy as np
[np.random.choice([1,2,3],4) for x in range(5)]
# Out:
# [array([3, 2, 3, 1]),
#  array([3, 2, 1, 2]),
#  array([2, 2, 2, 3]),
#  array([3, 1, 1, 3]),
#  array([1, 3, 1, 3])]

# %%
usernames = ['alice36', 'bob_smith', 'eve']

passwords = [''.join(np.random.choice(list(ascii_letters + digits), 8)) for x in range(3)]
creation_dates = [datetime.datetime.now().date() - datetime.timedelta(int(x)) for x in np.random.randint(0, 1500, 3)]

# %%
df = pd.DataFrame({'username': usernames, 'password': passwords, 'date-created': pd.to_datetime(creation_dates)})
df
# Out:
#     username  password date-created
# 0    alice36  GmTmNZNz   2017-12-19
# 1  bob_smith  ZRqLoaHg   2018-11-18
# 2        eve  dIkgecDY   2017-03-29

# %%
df.dtypes
# Out:
# username                object
# password                object
# date-created    datetime64[ns]
# dtype: object

# %% [markdown]
# The `DataFrame` is also closely related to the NumPy `ndarray`.

# %%
random_data = np.random.random((4,3))
random_data
# Out:
# array([[0.71997711, 0.40056877, 0.01842653],
#        [0.07709179, 0.81025248, 0.65503652],
#        [0.21810753, 0.36183569, 0.79199615],
#        [0.00576913, 0.97529577, 0.4741497 ]])

# %%
df_random = pd.DataFrame(random_data, columns=['a', 'b', 'c'])
df_random
# Out:
#           a         b         c
# 0  0.719977  0.400569  0.018427
# 1  0.077092  0.810252  0.655037
# 2  0.218108  0.361836  0.791996
# 3  0.005769  0.975296  0.474150

# %% [markdown]
# To add a new column or row, we simply use `dict`-like assignment.

# %%
emails = ['alice.chan@gmail.com', 'bwsmith1983@gmail.com', 'fakemail123@yahoo.com']
df['email'] = emails
df
# Out:
#     username  password date-created                  email
# 0    alice36  GmTmNZNz   2017-12-19   alice.chan@gmail.com
# 1  bob_smith  ZRqLoaHg   2018-11-18  bwsmith1983@gmail.com
# 2        eve  dIkgecDY   2017-03-29  fakemail123@yahoo.com

# %%
josh = {'date-created':'2019-05-29', 'password' : 'Onom3robot', 'username' : 'onomerobot', 'email' : 'onome_science@yahoo.com'}
df.loc[3] = josh
df
# Out:
#      username    password         date-created                    email
# 0     alice36    GmTmNZNz  2017-12-19 00:00:00     alice.chan@gmail.com
# 1   bob_smith    ZRqLoaHg  2018-11-18 00:00:00    bwsmith1983@gmail.com
# 2         eve    dIkgecDY  2017-03-29 00:00:00    fakemail123@yahoo.com
# 3  onomerobot  Onom3robot           2019-05-29  onome_science@yahoo.com

# %%
# loc references index value, NOT position
# for position use iloc
df.loc[3] = ['2015-01-29', '38uzFJ1n', 'melvintherobot', 'moviesrgood@moviesrgood.com']
df
# Out:
#      username  password         date-created                        email
# 0     alice36  GmTmNZNz  2017-12-19 00:00:00         alice.chan@gmail.com
# 1   bob_smith  ZRqLoaHg  2018-11-18 00:00:00        bwsmith1983@gmail.com
# 2         eve  dIkgecDY  2017-03-29 00:00:00        fakemail123@yahoo.com
# 3  2015-01-29  38uzFJ1n       melvintherobot  moviesrgood@moviesrgood.com

# %% [markdown]
# We can also drop columns and rows.

# %%
df.drop(3)
# Out:
#     username  password         date-created                  email
# 0    alice36  GmTmNZNz  2017-12-19 00:00:00   alice.chan@gmail.com
# 1  bob_smith  ZRqLoaHg  2018-11-18 00:00:00  bwsmith1983@gmail.com
# 2        eve  dIkgecDY  2017-03-29 00:00:00  fakemail123@yahoo.com

# %%
# to drop a column, need axis=1
df.drop('email', axis=1)
# Out:
#      username  password         date-created
# 0     alice36  GmTmNZNz  2017-12-19 00:00:00
# 1   bob_smith  ZRqLoaHg  2018-11-18 00:00:00
# 2         eve  dIkgecDY  2017-03-29 00:00:00
# 3  2015-01-29  38uzFJ1n       melvintherobot

# %% [markdown]
# Notice when we dropped the `'email'` column, the row at index 3 was in the `DataFrame`, even though we just dropped it! Most operations in Pandas return a _copy_ of the `DataFrame`, rather than modifying the `DataFrame` object itself. Therefore, in order to permanently alter the `DataFrame`, we either need to reassign the `df` variable, or use the `inplace` keyword.

# %%
df.drop(3, inplace=True)
df
# Out:
#           date-created  password   username                  email
# 0  2015-07-28 00:00:00  GVzngBQA    alice36   alice.chan@gmail.com
# 1  2019-05-28 00:00:00  GbtjrJje  bob_smith  bwsmith1983@gmail.com
# 2  2017-05-25 00:00:00  se7lTrKZ        eve  fakemail123@yahoo.com

# %% [markdown]
# Since the `index` and column names are important for interacting with data in the DataFrame, we should make sure to set them to useful values. We can do this during construction or after.

# %%
df = pd.DataFrame({'email': emails, 'password': passwords, 'date-created': creation_dates}, index=usernames)
df.index.name = 'users' # it can be helpful to give the index a name
df
# Out:
#           date-created                  email  password
# users
# alice36     2015-07-28   alice.chan@gmail.com  GVzngBQA
# bob_smith   2019-05-28  bwsmith1983@gmail.com  GbtjrJje
# eve         2017-05-25  fakemail123@yahoo.com  se7lTrKZ

# %%
list(zip(usernames, emails, passwords, creation_dates))
# Out:
# [('alice36', 'alice.chan@gmail.com', 'GVzngBQA', datetime.date(2015, 7, 28)),
#  ('bob_smith',
#   'bwsmith1983@gmail.com',
#   'GbtjrJje',
#   datetime.date(2019, 5, 28)),
#  ('eve', 'fakemail123@yahoo.com', 'se7lTrKZ', datetime.date(2017, 5, 25))]

# %%
# alternatively
df = pd.DataFrame(list(zip(usernames, emails, passwords, creation_dates)))
df
# Out:
#            0                      1         2           3
# 0    alice36   alice.chan@gmail.com  GVzngBQA  2015-07-28
# 1  bob_smith  bwsmith1983@gmail.com  GbtjrJje  2019-05-28
# 2        eve  fakemail123@yahoo.com  se7lTrKZ  2017-05-25

# %%
df.columns = ['username', 'email', 'password', 'date-created']
df.set_index('username', inplace=True)
df
# Out:
#                            email  password date-created
# username
# alice36     alice.chan@gmail.com  GVzngBQA   2015-07-28
# bob_smith  bwsmith1983@gmail.com  GbtjrJje   2019-05-28
# eve        fakemail123@yahoo.com  se7lTrKZ   2017-05-25

# %%
# to reset index to a column
df.reset_index(inplace=True)
df
# Out:
#    index    username  password         date-created  \
# 0      0     alice36  GmTmNZNz  2017-12-19 00:00:00
# 1      1   bob_smith  ZRqLoaHg  2018-11-18 00:00:00
# 2      2         eve  dIkgecDY  2017-03-29 00:00:00
# 3      3  2015-01-29  38uzFJ1n       melvintherobot
#
#                          email
# 0         alice.chan@gmail.com
# 1        bwsmith1983@gmail.com
# 2        fakemail123@yahoo.com
# 3  moviesrgood@moviesrgood.com

# %% [markdown]
# We can have multiple levels to an index. We'll discover that for some data sets it is necessary to have multiple levels to the index in order to uniquely identify a row.

# %%
df.set_index(['username', 'email'])
# Out:
#                                         index  password         date-created
# username   email
# alice36    alice.chan@gmail.com             0  GmTmNZNz  2017-12-19 00:00:00
# bob_smith  bwsmith1983@gmail.com            1  ZRqLoaHg  2018-11-18 00:00:00
# eve        fakemail123@yahoo.com            2  dIkgecDY  2017-03-29 00:00:00
# 2015-01-29 moviesrgood@moviesrgood.com      3  38uzFJ1n       melvintherobot

# %%
df.loc['alice36']
# Out:
#    index    username  password         date-created  \
# 0      0     alice36  GmTmNZNz  2017-12-19 00:00:00
# 1      1   bob_smith  ZRqLoaHg  2018-11-18 00:00:00
# 2      2         eve  dIkgecDY  2017-03-29 00:00:00
# 3      3  2015-01-29  38uzFJ1n       melvintherobot
#
#                          email
# 0         alice.chan@gmail.com
# 1        bwsmith1983@gmail.com
# 2        fakemail123@yahoo.com
# 3  moviesrgood@moviesrgood.com

# %% [markdown]
# ### Reading data from file
#
# We can also construct a DataFrame using data stored in a file or received from a website. The data source might be [JSON](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_json.html), [HTML](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_html.html), [CSV](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html#pandas.read_csv), [Excel](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_excel.html), [Python pickle](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_pickle.html), or even a [database connection](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql.html). Each format will have its own methods for reading and writing data that take different arguments. The arguments of these methods usually depend on the particular formatting of the file. For example, the values in a CSV might be separate by commas or semi-colons, it might have a header or it might not.
#
# The `read_csv` method has to deal with the most formatting possibilities, so we will explore that method with a few examples. Try to apply these ideas when working with other file formats, but keep in mind that each format and read method is different. Always check [the Pandas documentation](http://pandas.pydata.org/pandas-docs/stable/io.html) when having trouble with reading or writing data.

# %%
import pandas as pd

# %%
csv = [','.join(map(lambda x: str(x), row)) for row in np.vstack([df.columns, df])]
with open('./data/read_csv_example.csv', 'w') as f:
    [f.write(line + '\n') for line in csv]

# !cat ./data/read_csv_example.csv
# Out:
# 'cat' is not recognized as an internal or external command,
# operable program or batch file.

# %%
pd.read_csv('./data/read_csv_example.csv')
# Out:
#    index    username  password         date-created  \
# 0      0     alice36  GmTmNZNz  2017-12-19 00:00:00
# 1      1   bob_smith  ZRqLoaHg  2018-11-18 00:00:00
# 2      2         eve  dIkgecDY  2017-03-29 00:00:00
# 3      3  2015-01-29  38uzFJ1n       melvintherobot
#
#                          email
# 0         alice.chan@gmail.com
# 1        bwsmith1983@gmail.com
# 2        fakemail123@yahoo.com
# 3  moviesrgood@moviesrgood.com

# %%
# we can also set an index from the data
pd.read_csv('./data/read_csv_example.csv', index_col=0)
# Out:
#          username  password         date-created                        email
# index
# 0         alice36  GmTmNZNz  2017-12-19 00:00:00         alice.chan@gmail.com
# 1       bob_smith  ZRqLoaHg  2018-11-18 00:00:00        bwsmith1983@gmail.com
# 2             eve  dIkgecDY  2017-03-29 00:00:00        fakemail123@yahoo.com
# 3      2015-01-29  38uzFJ1n       melvintherobot  moviesrgood@moviesrgood.com

# %%
# what if our data had no header?
with open('./data/read_csv_noheader_example.csv', 'w') as f:
    [f.write(line + '\n') for i, line in enumerate(csv) if i != 0]
    
# !cat ./data/read_csv_noheader_example.csv
# Out:
# 'cat' is not recognized as an internal or external command,
# operable program or batch file.

# %%
pd.read_csv('./data/read_csv_noheader_example.csv', names=['username', 'email', 'password', 'date-created'], header=None)
# Out:
#      username     email             password                 date-created
# 0     alice36  GmTmNZNz  2017-12-19 00:00:00         alice.chan@gmail.com
# 1   bob_smith  ZRqLoaHg  2018-11-18 00:00:00        bwsmith1983@gmail.com
# 2         eve  dIkgecDY  2017-03-29 00:00:00        fakemail123@yahoo.com
# 3  2015-01-29  38uzFJ1n       melvintherobot  moviesrgood@moviesrgood.com

# %%
# what if our data was tab-delimited?
tsv = ['\t'.join(map(lambda x: str(x), row)) for row in np.vstack([df.columns, df])]
with open('./data/read_csv_example.tsv', 'w') as f:
    [f.write(line + '\n') for line in tsv]

# !cat ./data/read_csv_example.tsv
# Out:
# username	email	password	date-created
# alice36	alice.chan@gmail.com	6dw3i8Em	2018-06-12
# bob_smith	bwsmith1983@gmail.com	gWZmPXXG	2016-05-19
# eve	fakemail123@yahoo.com	GOeUKWhm	2019-05-15

# %%
pd.read_csv('./data/read_csv_example.tsv', delimiter='\t')
# Out:
#     username                  email  password date-created
# 0    alice36   alice.chan@gmail.com  6dw3i8Em   2018-06-12
# 1  bob_smith  bwsmith1983@gmail.com  gWZmPXXG   2016-05-19
# 2        eve  fakemail123@yahoo.com  GOeUKWhm   2019-05-15

# %% [markdown]
# Even within a single file format, data can be arranged and formatted in many ways. These have been just a few examples of the kinds of arguments you might need to use with `read_csv` in order to read data into a DataFrame in an organized way.

# %% [markdown]
# ## Filtering DataFrames
#
# One of the powerful analytical tools of the Pandas DataFrame is its syntax for filtering data. Often we'll only want to work with a certain subset of our data based on some criteria. Let's look at our Yelp data for an example.

# %%
yelp_df.head()
# Out:
#                                           attributes             business_id  \
# 0                      {'By Appointment Only': True}  vcNAWiLM4dR7D2nwwJ7nCA
# 1  {'Take-out': True, 'Good For': {'dessert': Fal...  JwUE5GmEO-sH1FuwJgKBlQ
# 2  {'Take-out': True, 'Good For': {'dessert': Fal...  uGykseHzyS5xAMWoN6YUqA
# 3  {'Take-out': True, 'Wi-Fi': 'free', 'Takes Res...  LRKJF43s9-3jG9Lgx4zODg
# 4  {'Take-out': True, 'Has TV': False, 'Outdoor S...  RgDg-k9S5YD_BaxMckifkg
#
#                                           categories       city  \
# 0                        [Doctors, Health & Medical]    Phoenix
# 1                                      [Restaurants]  De Forest
# 2              [American (Traditional), Restaurants]  De Forest
# 3  [Food, Ice Cream & Frozen Yogurt, Fast Food, R...  De Forest
# 4                             [Chinese, Restaurants]  De Forest
#
#                                         full_address  \
# 0  4840 E Indian School Rd\nSte 101\nPhoenix, AZ ...
# 1            6162 US Highway 51\nDe Forest, WI 53532
# 2                505 W North St\nDe Forest, WI 53532
# 3              4910 County Rd V\nDe Forest, WI 53532
# 4                 631 S Main St\nDe Forest, WI 53532
#
#                                                hours   latitude   longitude  \
# 0  {'Tuesday': {'close': '17:00', 'open': '08:00'...  33.499313 -111.983758
# 1                                                 {}  43.238893  -89.335844
# 2  {'Monday': {'close': '22:00', 'open': '06:00'}...  43.252267  -89.353437
# 3  {'Monday': {'close': '22:00', 'open': '10:30'}...  43.251045  -89.374983
# 4  {'Monday': {'close': '22:00', 'open': '11:00'}...  43.240875  -89.343722
#
#                           name neighborhoods  open  review_count  stars state  \
# 0            Eric Goldberg, MD            []  True             7    3.5    AZ
# 1         Pine Cone Restaurant            []  True            26    4.0    WI
# 2   Deforest Family Restaurant            []  True            16    4.0    WI
# 3                     Culver's            []  True             7    4.5    WI
# 4  Chang Jiang Chinese Kitchen            []  True             3    4.0    WI
#
#        type
# 0  business
# 1  business
# 2  business
# 3  business
# 4  business

# %% [markdown]
# We see the Yelp data set has a `'state'` column. If we are only interested in businesses in Arizona (AZ), we can filter the DataFrame and select only that data.

# %%
az_yelp_df = yelp_df[yelp_df['state'] == 'AZ']
az_yelp_df.head()
# Out:
#                                             attributes  \
# 0                        {'By Appointment Only': True}
# 297  {'Take-out': True, 'Wi-Fi': 'no', 'Alcohol': '...
# 298  {'Take-out': True, 'Noise Level': 'quiet', 'De...
# 299  {'Alcohol': 'full_bar', 'Price Range': 1, 'Noi...
# 300  {'Price Range': 2, 'Alcohol': 'full_bar', 'Goo...
#
#                 business_id  \
# 0    vcNAWiLM4dR7D2nwwJ7nCA
# 297  x5Mv61CnZLohZWxfCVCPTQ
# 298  2ZnCITVa0abGce4gZ6RhIw
# 299  EmzaQR5hQlF0WIl24NxAZA
# 300  SiwN7f0N4bs4ZtPc4yPgiA
#
#                                             categories     city  \
# 0                          [Doctors, Health & Medical]  Phoenix
# 297    [Sandwiches, Pizza, Chicken Wings, Restaurants]  Phoenix
# 298          [American (New), Sandwiches, Restaurants]  Phoenix
# 299  [American (New), Nightlife, Dance Clubs, Resta...  Phoenix
# 300                           [Nightlife, Dance Clubs]  Phoenix
#
#                                           full_address  \
# 0    4840 E Indian School Rd\nSte 101\nPhoenix, AZ ...
# 297              2819 N Central Ave\nPhoenix, AZ 85004
# 298              1850 N Central Ave\nPhoenix, AZ 85004
# 299             132 E Washington St\nPhoenix, AZ 85004
# 300               710 N Central Ave\nPhoenix, AZ 85004
#
#                                                  hours   latitude   longitude  \
# 0    {'Tuesday': {'close': '17:00', 'open': '08:00'...  33.499313 -111.983758
# 297                                                 {}  33.479542 -112.073418
# 298                                                 {}  33.468988 -112.074315
# 299  {'Sunday': {'close': '02:00', 'open': '21:00'}...  33.448399 -112.071702
# 300                                                 {}  33.456068 -112.074225
#
#                        name neighborhoods  open  review_count  stars state  \
# 0         Eric Goldberg, MD            []  True             7    3.5    AZ
# 297          Domino's Pizza            []  True            12    2.5    AZ
# 298  Viad Tower Restaurants            []  True             5    3.5    AZ
# 299              Sky Lounge            []  True            20    2.5    AZ
# 300                 Palazzo            []  True            15    2.5    AZ
#
#          type
# 0    business
# 297  business
# 298  business
# 299  business
# 300  business

# %%
az_yelp_df['state'].count()
# Out:
# 19927

# %%
az_yelp_df['state'].unique()

# %% [markdown]
# We can combine criteria using logic. What if we're only interested in businesses with more than 10 reviews in Arizona?

# %%
yelp_df[(yelp_df['state'] == 'AZ') & (yelp_df['review_count'] > 10)].head()
# Out:
#                                             attributes  \
# 297  {'Take-out': True, 'Wi-Fi': 'no', 'Alcohol': '...
# 299  {'Alcohol': 'full_bar', 'Price Range': 1, 'Noi...
# 300  {'Price Range': 2, 'Alcohol': 'full_bar', 'Goo...
# 301                                                 {}
# 302  {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...
#
#                 business_id  \
# 297  x5Mv61CnZLohZWxfCVCPTQ
# 299  EmzaQR5hQlF0WIl24NxAZA
# 300  SiwN7f0N4bs4ZtPc4yPgiA
# 301  M-MFa0YErVBbFW2IJhGJmw
# 302  KPoTixdjoJxSqRSEApSAGg
#
#                                             categories     city  \
# 297    [Sandwiches, Pizza, Chicken Wings, Restaurants]  Phoenix
# 299  [American (New), Nightlife, Dance Clubs, Resta...  Phoenix
# 300                           [Nightlife, Dance Clubs]  Phoenix
# 301  [Auto Repair, Automotive, Tires, Oil Change St...  Phoenix
# 302                                [Thai, Restaurants]  Phoenix
#
#                                full_address  \
# 297   2819 N Central Ave\nPhoenix, AZ 85004
# 299  132 E Washington St\nPhoenix, AZ 85004
# 300    710 N Central Ave\nPhoenix, AZ 85004
# 301   386 E Virginia Ave\nPhoenix, AZ 85004
# 302   2631 N Central Ave\nPhoenix, AZ 85004
#
#                                                  hours   latitude   longitude  \
# 297                                                 {}  33.479542 -112.073418
# 299  {'Sunday': {'close': '02:00', 'open': '21:00'}...  33.448399 -112.071702
# 300                                                 {}  33.456068 -112.074225
# 301  {'Tuesday': {'close': '18:00', 'open': '07:30'...  33.476784 -112.065806
# 302  {'Monday': {'close': '21:00', 'open': '11:00'}...  33.477934 -112.073524
#
#                       name neighborhoods  open  review_count  stars state  \
# 297         Domino's Pizza            []  True            12    2.5    AZ
# 299             Sky Lounge            []  True            20    2.5    AZ
# 300                Palazzo            []  True            15    2.5    AZ
# 301  Virginia Auto Service            []  True            28    4.0    AZ
# 302           Wild Thaiger            []  True           281    4.0    AZ
#
#          type
# 297  business
# 299  business
# 300  business
# 301  business
# 302  business

# %% [markdown]
# How does this filtering work?
#
# When we write `yelp_df['state'] == 'AZ'`, Pandas selects the `'state'` column and checks whether each row is `'AZ'`. If so, that row is marked `True`, and if not, it is marked `False`. This is how we would normally expect a conditional to work, only now applied to an entire Pandas `Series`. We end up with a Pandas `Series` of Boolean variables.

# %%
(yelp_df['state'] == 'AZ').head()
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# Name: state, dtype: bool

# %% [markdown]
# We can use a `Series` (or any similar object) of Boolean variables to index the DataFrame.

# %%
df[[True, False, True,True]].head()
# Out:
#    index    username  password         date-created  \
# 0      0     alice36  GmTmNZNz  2017-12-19 00:00:00
# 2      2         eve  dIkgecDY  2017-03-29 00:00:00
# 3      3  2015-01-29  38uzFJ1n       melvintherobot
#
#                          email
# 0         alice.chan@gmail.com
# 2        fakemail123@yahoo.com
# 3  moviesrgood@moviesrgood.com

# %% [markdown]
# This let's us filter a DataFrame using idiomatic logical expressions like `yelp_df['review_count'] > 10`.
#
# As another example, let's consider the `'open'` column, which is a `True`/`False` flag for whether a business is open. This is also a Boolean Pandas `Series`, so we can just use it directly.

# %%
# the open businesses
yelp_df[yelp_df['open']].head()
# Out:
#                                           attributes             business_id  \
# 0                      {'By Appointment Only': True}  vcNAWiLM4dR7D2nwwJ7nCA
# 1  {'Take-out': True, 'Good For': {'dessert': Fal...  JwUE5GmEO-sH1FuwJgKBlQ
# 2  {'Take-out': True, 'Good For': {'dessert': Fal...  uGykseHzyS5xAMWoN6YUqA
# 3  {'Take-out': True, 'Wi-Fi': 'free', 'Takes Res...  LRKJF43s9-3jG9Lgx4zODg
# 4  {'Take-out': True, 'Has TV': False, 'Outdoor S...  RgDg-k9S5YD_BaxMckifkg
#
#                                           categories       city  \
# 0                        [Doctors, Health & Medical]    Phoenix
# 1                                      [Restaurants]  De Forest
# 2              [American (Traditional), Restaurants]  De Forest
# 3  [Food, Ice Cream & Frozen Yogurt, Fast Food, R...  De Forest
# 4                             [Chinese, Restaurants]  De Forest
#
#                                         full_address  \
# 0  4840 E Indian School Rd\nSte 101\nPhoenix, AZ ...
# 1            6162 US Highway 51\nDe Forest, WI 53532
# 2                505 W North St\nDe Forest, WI 53532
# 3              4910 County Rd V\nDe Forest, WI 53532
# 4                 631 S Main St\nDe Forest, WI 53532
#
#                                                hours   latitude   longitude  \
# 0  {'Tuesday': {'close': '17:00', 'open': '08:00'...  33.499313 -111.983758
# 1                                                 {}  43.238893  -89.335844
# 2  {'Monday': {'close': '22:00', 'open': '06:00'}...  43.252267  -89.353437
# 3  {'Monday': {'close': '22:00', 'open': '10:30'}...  43.251045  -89.374983
# 4  {'Monday': {'close': '22:00', 'open': '11:00'}...  43.240875  -89.343722
#
#                           name neighborhoods  open  review_count  stars state  \
# 0            Eric Goldberg, MD            []  True             7    3.5    AZ
# 1         Pine Cone Restaurant            []  True            26    4.0    WI
# 2   Deforest Family Restaurant            []  True            16    4.0    WI
# 3                     Culver's            []  True             7    4.5    WI
# 4  Chang Jiang Chinese Kitchen            []  True             3    4.0    WI
#
#        type
# 0  business
# 1  business
# 2  business
# 3  business
# 4  business

# %%
# the closed businesses
yelp_df[~yelp_df['open']].head()
# Out:
#                                            attributes             business_id  \
# 5                                                  {}  oLctHIA1AxmsgOuu4dM6Vw
# 14  {'Take-out': True, 'Caters': True, 'Attire': '...  HxPpZSY6Q1eARuiahhra6A
# 16  {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...  77ESrCo7hQ96VpCWWdvoxg
# 50  {'Alcohol': 'full_bar', 'Attire': 'casual', 'P...  IEmqrFe96NOhU07TA0rZdw
# 62  {'By Appointment Only': True, 'Parking': {'gar...  mbtGl2I2A2To-8jiggN99g
#
#                                            categories        city  \
# 5                   [Television Stations, Mass Media]  Mc Farland
# 14  [Event Planning & Services, Party & Event Plan...   Middleton
# 16                             [Mexican, Restaurants]   Middleton
# 50              [American (Traditional), Restaurants]   Middleton
# 62            [Skin Care, Hair Salons, Beauty & Spas]   Middleton
#
#                                          full_address  \
# 5              4156 County Rd B\nMc Farland, WI 53558
# 14           6401 University Ave\nMiddleton, WI 53562
# 16           6230 University Ave\nMiddleton, WI 53562
# 50              6625 Century Ave\nMiddleton, WI 53562
# 62  6661 University Ave\nSte 103\nMiddleton, WI 53562
#
#                                                 hours   latitude  longitude  \
# 5                                                  {}  42.968507 -89.322920
# 14                                                 {}  43.093265 -89.491800
# 16  {'Monday': {'close': '21:00', 'open': '06:00'}...  43.091061 -89.487487
# 50                                                 {}  43.104535 -89.494422
# 62  {'Tuesday': {'close': '20:00', 'open': '10:00'...  43.096650 -89.497265
#
#                               name neighborhoods   open  review_count  stars  \
# 5           Charter Communications            []  False            10    1.5
# 14   Crandalls Carryout & Catering            []  False             5    4.0
# 16                       Mi Cocina            []  False            17    3.0
# 50  Stamm House At Pheasant Branch            []  False             7    2.0
# 62                         Tangles            []  False             7    2.0
#
#    state      type
# 5     WI  business
# 14    WI  business
# 16    WI  business
# 50    WI  business
# 62    WI  business

# %% [markdown]
# Notice in an earlier expression we wrote `(yelp_df['state'] == 'AZ') & (yelp_df['review_count'] > 10)`. Normally in Python we use the word `and` when we are working with logic. In Pandas we have to use _bit-wise_ logical operators; all that's important to know is the following equivalencies:
#
# `~` = `not`
# `&` = `and`
# `|` = `or`
#
# We can also use Panda's built-in [string operations](https://pandas.pydata.org/pandas-docs/stable/text.html) for doing pattern matching. For example, there are a lot of businesses in Las Vegas in our data set. However, there are also businesses in 'Las Vegas East' and 'South Las Vegas'. To get all of the Las Vegas businesses I might do the following.

# %%
vegas_yelp_df = yelp_df[yelp_df['city'].str.contains('Vegas')]
vegas_yelp_df.head()
# Out:
#                                              attributes  \
# 4348  {'Parking': {'garage': False, 'street': False,...
# 4360  {'Parking': {'garage': True, 'street': False, ...
# 4364  {'By Appointment Only': False, 'Parking': {'ga...
# 4441  {'Alcohol': 'full_bar', 'Music': {'video': Fal...
# 4489                                                 {}
#
#                  business_id  \
# 4348  uzztTCsg3XAKlYqmLO40aw
# 4360  IspFZDcpu9W5NvvJ7QgJZg
# 4364  Dvulg9cc3XHkt5DkBUekhw
# 4441  _SM8UKIwBNbmj1r629ipoQ
# 4489  Zaw0IAXwopKX4MV23MHQRw
#
#                                              categories       city  \
# 4348  [Arts & Entertainment, Shopping, Books, Mags, ...  Las Vegas
# 4360  [Women's Clothing, Men's Clothing, Fashion, Sh...  Las Vegas
# 4364                       [Hair Salons, Beauty & Spas]  Las Vegas
# 4441  [Wine Bars, Bars, Restaurants, Nightlife, Ital...  Las Vegas
# 4489                             [Car Wash, Automotive]  Las Vegas
#
#                                            full_address  \
# 4348  5835 S Eastern Ave\nSoutheast\nLas Vegas, NV 8...
# 4360  The Forum Shops At Caesars\n3500 Las Vegas Blv...
# 4364  467 E Silverado Ranch Blvd\nSte 175\nSoutheast...
# 4441  1916 Village Center Cir\nSummerlin\nLas Vegas,...
# 4489  2718 E Tropicana Avenue\nEastside\nLas Vegas, ...
#
#                                                   hours   latitude  \
# 4348  {'Monday': {'close': '21:00', 'open': '10:00'}...  36.083936
# 4360  {'Monday': {'close': '21:00', 'open': '10:00'}...  36.124423
# 4364                                                 {}  36.012150
# 4441  {'Monday': {'close': '23:00', 'open': '11:00'}...  36.192414
# 4489                                                 {}  36.100507
#
#        longitude                    name          neighborhoods   open  \
# 4348 -115.119422  Psychic Eye Book Shops            [Southeast]   True
# 4360 -115.146372                     Gap             [Eastside]   True
# 4364 -115.153303             Great Clips            [Southeast]   True
# 4441 -115.304396            Chianti Cafe            [Summerlin]  False
# 4489 -115.113492         Terrible Herbst  [Eastside, Southeast]   True
#
#       review_count  stars state      type
# 4348             7    4.5    NV  business
# 4360             6    4.5    NV  business
# 4364            10    2.5    NV  business
# 4441             9    3.5    NV  business
# 4489             3    1.5    NV  business

# %%
vegas_yelp_df['city'].unique()
# Out:
# array(['Las Vegas', 'North Las Vegas', 'N Las Vegas', 'N. Las Vegas',
#        'C Las Vegas', 'Las Vegas ', 'Las Vegas, NV 89147',
#        'Las Vegas East', 'North Las Vegas ', 'N E Las Vegas',
#        'N W Las Vegas', 'Lake Las Vegas', 'South Las Vegas'], dtype=object)

# %% [markdown]
# ## Applying functions and data aggregation
#
# To analyze the data in the dataframe, we'll need to be able to apply functions to it. Pandas has many mathematical functions built in already, and DataFrames and Series can be passed to NumPy functions (since they behave like NumPy arrays).

# %%
log_review_count = np.log(yelp_df['review_count'])
print(log_review_count.head(10))
print(log_review_count.shape)
# Out:
# 0    1.945910
# 1    3.258097
# 2    2.772589
# 3    1.945910
# 4    1.098612
# 5    2.302585
# 6    1.386294
# 7    1.386294
# 8    1.098612
# 9    3.433987
# Name: review_count, dtype: float64
# (37938,)

# %%
type(log_review_count)
# Out:
# pandas.core.series.Series

# %%
s = yelp_df['review_count'].sum()
s
r = s / yelp_df['review_count'].count()
r
# Out:
# 29.300648426379883

# %%
mean_review_count = yelp_df['review_count'].mean()
print(mean_review_count)
# Out:
# 29.300648426379883

# %% [markdown]
# In the first example we took the _logarithm_ of the review count for each business. In the second case, we calculated the mean review count of all businesses. In the first case, we ended up with a number for each business. We _transformed_ the review counts using the logarithm. In the second case, we _summarized_ the review counts of all the businesses in one number. This summary is a form of _data aggregation_, in which we take many data points and combine them into some smaller representation. The functions we apply to our data sets will either be in the category of **transformations** or **aggregations**.
#
# Sometimes we will need to transform our data in order for it to be usable. For instance, in the `'attributes'` column of our DataFrame, we have a `dict` for each business listing all of its properties. If I wanted to find a restaurant that offers delivery service, it would be difficult for me to filter the DataFrame, even though that information is in the `'attributes'` column. First, I need to transform the `dict` into something more useful.

# %%
yelp_df
# Out:
#                                               attributes  \
# 0                          {'By Appointment Only': True}
# 1      {'Take-out': True, 'Good For': {'dessert': Fal...
# 2      {'Take-out': True, 'Good For': {'dessert': Fal...
# 3      {'Take-out': True, 'Wi-Fi': 'free', 'Takes Res...
# 4      {'Take-out': True, 'Has TV': False, 'Outdoor S...
# 5                                                     {}
# 6                                                     {}
# 7                                      {'Wi-Fi': 'free'}
# 8                                                     {}
# 9      {'Alcohol': 'full_bar', 'Noise Level': 'loud',...
# 10     {'Accepts Credit Cards': True, 'Wi-Fi': 'free'...
# 11                               {'Good for Kids': True}
# 12     {'Take-out': True, 'Good For': {'dessert': Fal...
# 13     {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...
# 14     {'Take-out': True, 'Caters': True, 'Attire': '...
# 15     {'Take-out': True, 'Good For': {'dessert': Fal...
# 16     {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...
# 17                               {'Good for Kids': True}
# 18      {'Accepts Credit Cards': True, 'Price Range': 2}
# 19     {'Accepts Credit Cards': True, 'Wi-Fi': 'free'...
# 20     {'By Appointment Only': False, 'Good for Kids'...
# 21     {'Take-out': True, 'Takes Reservations': False...
# 22     {'Parking': {'garage': False, 'street': False,...
# 23     {'Parking': {'garage': False, 'street': True, ...
# 24     {'Parking': {'garage': False, 'street': True, ...
# 25     {'Wi-Fi': 'free', 'Price Range': 1, 'Outdoor S...
# 26     {'Take-out': True, 'Wi-Fi': 'free', 'Good For'...
# 27     {'Good For': {'dessert': False, 'latenight': F...
# 28     {'Take-out': True, 'Good For': {'dessert': Fal...
# 29     {'Take-out': True, 'Takes Reservations': False...
# ...                                                  ...
# 37908                     {'Accepts Credit Cards': True}
# 37909  {'Take-out': False, 'Good For': {'dessert': Fa...
# 37910   {'Accepts Credit Cards': True, 'Price Range': 2}
# 37911  {'Take-out': True, 'Good For': {'dessert': Fal...
# 37912                                                 {}
# 37913  {'Has TV': False, 'Good For Groups': True, 'Ou...
# 37914  {'Take-out': True, 'Good For': {'dessert': Fal...
# 37915  {'Take-out': True, 'Wi-Fi': 'free', 'Good For'...
# 37916  {'Parking': {'garage': False, 'street': False,...
# 37917  {'Take-out': True, 'Wi-Fi': 'free', 'Good For'...
# 37918                     {'Accepts Credit Cards': True}
# 37919  {'Parking': {'garage': False, 'street': False,...
# 37920                     {'Accepts Credit Cards': True}
# 37921  {'Parking': {'garage': False, 'street': False,...
# 37922  {'Parking': {'garage': False, 'street': False,...
# 37923  {'Take-out': True, 'Good For': {'dessert': Fal...
# 37924  {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...
# 37925   {'Accepts Credit Cards': True, 'Price Range': 2}
# 37926  {'Take-out': True, 'Good For': {'dessert': Fal...
# 37927                            {'Good for Kids': True}
# 37928  {'Take-out': False, 'Wi-Fi': 'free', 'Drive-Th...
# 37929  {'Take-out': True, 'Wi-Fi': 'free', 'Good For'...
# 37930  {'Take-out': True, 'Good For': {'dessert': Fal...
# 37931  {'Take-out': True, 'Wi-Fi': 'free', 'Good For'...
# 37932  {'Alcohol': 'full_bar', 'Noise Level': 'quiet'...
# 37933  {'Alcohol': 'none', 'Good For Dancing': True, ...
# 37934                                                 {}
# 37935                           {'Good for Kids': False}
# 37936  {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...
# 37937  {'Parking': {'garage': False, 'street': False,...
#
#                   business_id  \
# 0      vcNAWiLM4dR7D2nwwJ7nCA
# 1      JwUE5GmEO-sH1FuwJgKBlQ
# 2      uGykseHzyS5xAMWoN6YUqA
# 3      LRKJF43s9-3jG9Lgx4zODg
# 4      RgDg-k9S5YD_BaxMckifkg
# 5      oLctHIA1AxmsgOuu4dM6Vw
# 6      ZW2WeP2Hp20tq0RG1NFkoQ
# 7      95p9Xg358BezJyk1wqzzyg
# 8      ZlhAvs_6ryi4_efZ1SpMbg
# 9      _wZTYYL7cutanzAnJUTGMA
# 10     XrzTVrJAjs0yYLvhFI9vkQ
# 11     1tkeiIa-daD8LbM6mHm_9A
# 12     zOc8lbjViUZajbY7M0aUCQ
# 13     UgjVZTSOaYoEvws_lAP_Dw
# 14     HxPpZSY6Q1eARuiahhra6A
# 15     SKLw05kEIlZcpTD5pqma8Q
# 16     77ESrCo7hQ96VpCWWdvoxg
# 17     368m5-RtrrYWf4hPM_bMlg
# 18     YjoSdr8uJslIebsQP6c18w
# 19     rKNtd_M2kWDW8sQKYzetKA
# 20     x7xS2DJvu8klyNzcpN8QHg
# 21     KTqNU4plO23583DYAMGXYg
# 22     cgCqxPhadIAlsqnD1MoWuQ
# 23     YDUB7-NgjKEFn8CERLoKXQ
# 24     x7pStpT09Tdc8d7oRU0Tmw
# 25     1-EIdeHewfEVcpoZm38N8A
# 26     ShEYKerTwb2LSORE5o_s7A
# 27     HaBkx5PwvbBpQ2iNCgHnVQ
# 28     KW6HejC-67KSL9J8Cz1dSw
# 29     wl-7A4jC0f27MOEmW-XTbQ
# ...                       ...
# 37908  uV2EhAuAmPDxZOlIgAGFxw
# 37909  aybLDQRhUwOr7WoQfdofPQ
# 37910  l48YFfpkcTEh0mvSG9wfLA
# 37911  fmfiSDAJtjxbnRBBtYhnNw
# 37912  pOz8fQ1Y8fP3C4ARE9TG_w
# 37913  xT1MO7MLMp3jK4XT1LXiKA
# 37914  51vtDjP79vBjaI5dbkPoPw
# 37915  F8ZrWvngdHYnKrALwZAdBw
# 37916  NRjz0_SjSqNbIoXWGnlp7w
# 37917  0EXVIF07vw-QTTy9V7-ebg
# 37918  jTUe25wOiM0ZtP9Ba7i8VQ
# 37919  pU88U9_yEUVfpox30VBWPg
# 37920  k6CRXdN7GMMNQ4VJUOEzbg
# 37921  0Nwda6h7mRhiQBbxi0xhhw
# 37922  qZkW6s0qxtUTrjWw_0je-g
# 37923  8K4pWvuJmGWXDgCugYKYvw
# 37924  wmm19sGdCiL5IZhViYQY2Q
# 37925  flhtNfzfGiySc3g_U0Zkeg
# 37926  5se9c1ggSm2oMrnWO3ZSgw
# 37927  UH4BReVAqpMVjyVroEJAGA
# 37928  EYpqqsJZ3L2EFAPK-NEOFA
# 37929  KN-3Sg8TZ-y67026TFwmjw
# 37930  ZpB2O-WAbbRHdP0V8GrwXA
# 37931  OEUIE8VBa1BbBfr5EPcTOA
# 37932  yZXEELxi8KMwzXCHP345GQ
# 37933  iyKyJoDcbkGrMCgvyfMHxw
# 37934  tsvWY4o64xiv7K0VA89R8A
# 37935  nYer89hXYAoddMEKTxw7kA
# 37936  BMjggIgOghBMEXPo8q7q3w
# 37937  BVxlrYWgmi-8TPGMe6CTpg
#
#                                               categories         city  \
# 0                            [Doctors, Health & Medical]      Phoenix
# 1                                          [Restaurants]    De Forest
# 2                  [American (Traditional), Restaurants]    De Forest
# 3      [Food, Ice Cream & Frozen Yogurt, Fast Food, R...    De Forest
# 4                                 [Chinese, Restaurants]    De Forest
# 5                      [Television Stations, Mass Media]   Mc Farland
# 6       [Home Services, Heating & Air Conditioning/HVAC]   Mc Farland
# 7              [Libraries, Public Services & Government]   Mc Farland
# 8                                  [Veterinarians, Pets]   Mc Farland
# 9      [Bars, American (Traditional), Nightlife, Loun...   Mc Farland
# 10     [Hotels & Travel, Bed & Breakfast, Event Plann...   Mc Farland
# 11                                [Active Life, Bowling]   Mc Farland
# 12                                  [Pizza, Restaurants]   Mc Farland
# 13                                [Chinese, Restaurants]   Mc Farland
# 14     [Event Planning & Services, Party & Event Plan...    Middleton
# 15     [Party & Event Planning, Asian Fusion, Event P...    Middleton
# 16                                [Mexican, Restaurants]    Middleton
# 17     [Active Life, Arts & Entertainment, Stadiums &...    Middleton
# 18                                  [Pet Services, Pets]    Middleton
# 19     [Hotels & Travel, Event Planning & Services, V...    Middleton
# 20     [Pilates, Yoga, Weight Loss Centers, Health & ...    Middleton
# 21       [Sandwiches, Pizza, Chicken Wings, Restaurants]    Middleton
# 22     [Shopping, Arts & Crafts, Event Planning & Ser...    Middleton
# 23     [Arts & Crafts, Shopping, Knitting Supplies, H...    Middleton
# 24     [Women's Clothing, Shopping Centers, Fashion, ...    Middleton
# 25            [Food, Beer, Wine & Spirits, Coffee & Tea]    Middleton
# 26     [Bakeries, Food, Breakfast & Brunch, Coffee & ...    Middleton
# 27        [Bars, American (New), Nightlife, Restaurants]    Middleton
# 28                                [Chinese, Restaurants]    Middleton
# 29                                [Chinese, Restaurants]    Middleton
# ...                                                  ...          ...
# 37908  [Local Services, Data Recovery, Mobile Phone R...    Las Vegas
# 37909                         [Steakhouses, Restaurants]      Madison
# 37910        [Shopping, Home & Garden, Furniture Stores]      Gilbert
# 37911        [American (New), Comfort Food, Restaurants]  Sun Prairie
# 37912            [Arts & Entertainment, Performing Arts]    Las Vegas
# 37913                          [Tapas Bars, Restaurants]    Edinburgh
# 37914                               [Pizza, Restaurants]      Phoenix
# 37915  [Food, Tea Rooms, Coffee & Tea, Asian Fusion, ...     Waterloo
# 37916   [Used, Vintage & Consignment, Fashion, Shopping]   Scottsdale
# 37917                               [Cafes, Restaurants]  Queen Creek
# 37918                            [Movers, Home Services]      Phoenix
# 37919                                   [Bakeries, Food]    Henderson
# 37920                          [Handyman, Home Services]  Queen Creek
# 37921                                 [Food, Shaved Ice]     Avondale
# 37922                             [Food, Specialty Food]    Las Vegas
# 37923                          [Sushi Bars, Restaurants]   Scottsdale
# 37924                          [Vietnamese, Restaurants]    Las Vegas
# 37925               [Food, Desserts, Cupcakes, Bakeries]    Las Vegas
# 37926                            [Filipino, Restaurants]    Las Vegas
# 37927                     [Active Life, Amusement Parks]    Henderson
# 37928                             [Burgers, Restaurants]    Edinburgh
# 37929                       [Chicken Wings, Restaurants]    Las Vegas
# 37930                      [American (New), Restaurants]    Henderson
# 37931  [Food, Juice Bars & Smoothies, American (New),...    Henderson
# 37932  [Bars, Turkish, Mediterranean, Nightlife, Loun...    Las Vegas
# 37933            [Bars, Hookah Bars, Nightlife, Lounges]     Glendale
# 37934  [Active Life, Barre Classes, Pilates, Fitness ...      Madison
# 37935                        [Yelp Events, Local Flavor]      Phoenix
# 37936              [Kosher, Italian, Pizza, Restaurants]      Phoenix
# 37937       [Food, Ethnic Food, Grocery, Specialty Food]    Edinburgh
#
#                                             full_address  \
# 0      4840 E Indian School Rd\nSte 101\nPhoenix, AZ ...
# 1                6162 US Highway 51\nDe Forest, WI 53532
# 2                    505 W North St\nDe Forest, WI 53532
# 3                  4910 County Rd V\nDe Forest, WI 53532
# 4                     631 S Main St\nDe Forest, WI 53532
# 5                 4156 County Rd B\nMc Farland, WI 53558
# 6                 4709 Triangle St\nMc Farland, WI 53558
# 7                  5114 Farwell St\nMc Farland, WI 53558
# 8             4811 Larson Beach Rd\nMc Farland, WI 53558
# 9             4506 Larson Beach Rd\nMc Farland, WI 53558
# 10               5508 Broadhead St\nMc Farland, WI 53558
# 11                 4711 Farwell St\nMc Farland, WI 53558
# 12                    5813 Main St\nMc Farland, WI 53558
# 13            4850 Larson Beach Rd\nMc Farland, WI 53558
# 14              6401 University Ave\nMiddleton, WI 53562
# 15                  2039 Allen Blvd\nMiddleton, WI 53562
# 16              6230 University Ave\nMiddleton, WI 53562
# 17                8312 Forsythia St\nMiddleton, WI 53562
# 18                 8402 Old Sauk Rd\nMiddleton, WI 53562
# 19                 7790 Elmwood Ave\nMiddleton, WI 53562
# 20                  2529 Allen Blvd\nMiddleton, WI 53562
# 21                  2411 Allen Blvd\nMiddleton, WI 53562
# 22                  1661 Deming Way\nMiddleton, WI 53562
# 23                  1700 Deming Way\nMiddleton, WI 53562
# 24                  1620 Deming Way\nMiddleton, WI 53562
# 25                   1901 Cayuga St\nMiddleton, WI 53562
# 26      6720 Frank Lloyd Wright Ave\nMiddleton, WI 53562
# 27                2401 Parmenter St\nMiddleton, WI 53562
# 28                 8414 Old Sauk Rd\nMiddleton, WI 53562
# 29                  2608 Allen Blvd\nMiddleton, WI 53562
# ...                                                  ...
# 37908  1033 S Rainbow Blvd\nWestside\nLas Vegas, NV 8...
# 37909        14 W Mifflin St\nCapitol\nMadison, WI 53703
# 37910     2757 S San Tan Village Pkwy\nGilbert, AZ 85295
# 37911  2804 Prairie Lakes Dr\nSte 106\nSun Prairie, W...
# 37912  83 Panorama Crest Ave\nSouth Summerlin\nLas Ve...
# 37913           297 Leith Walk\nLeith\nEdinburgh EH6 8SA
# 37914               1031 NW Grand Ave\nPhoenix, AZ 85007
# 37915                255 King Street N\nWaterloo, ON N2J
# 37916         1312 N Scottsdale Rd\nScottsdale, AZ 85257
# 37917  22721 S Ellsworth Rd\nSte 107\nQueen Creek, AZ...
# 37918         1816 E Oak St\nSte 4566\nPhoenix, AZ 85006
# 37919  10251 S Eastern Ave\nSte C\nAnthem\nHenderson,...
# 37920                              Queen Creek, AZ 85142
# 37921  13045 W Rancho Santa Fe Blvd\nA105\nAvondale, ...
# 37922  3700 S Hualapai Way\nSte 108\nSouth Summerlin\...
# 37923             4320 N Miller Rd\nScottsdale, AZ 85251
# 37924  4860 W Desert Inn Rd\nSte 9\nWestside\nLas Veg...
# 37925                     Southeast\nLas Vegas, NV 89120
# 37926     6820 W Flamingo Rd\nSte A\nLas Vegas, NV 89103
# 37927               900 Galleria Dr\nHenderson, NV 89011
# 37928       45 Broughton St\nNew Town\nEdinburgh EH1 3JU
# 37929  6475 W Charleston Blvd\nSte 150\nWestside\nLas...
# 37930  140 S Green Valley Pkwy\nSte 142\nHenderson, N...
# 37931        19 S Stephanie\nSte140\nHenderson, NV 89012
# 37932  2550 S Rainbow Blvd\nSte  W1\nWestside\nLas Ve...
# 37933          4340 W Thunderbird Rd\nGlendale, AZ 85306
# 37934  1 E Main St\nLower Level Suite 5\nCapitol\nMad...
# 37935           FilmBar\n815 N 2nd St\nPhoenix, AZ 85004
# 37936                   6505 N 7th St\nPhoenix, AZ 85014
# 37937     125 Lauriston Pl\nTollcross\nEdinburgh EH3 9JN
#
#                                                    hours   latitude  \
# 0      {'Tuesday': {'close': '17:00', 'open': '08:00'...  33.499313
# 1                                                     {}  43.238893
# 2      {'Monday': {'close': '22:00', 'open': '06:00'}...  43.252267
# 3      {'Monday': {'close': '22:00', 'open': '10:30'}...  43.251045
# 4      {'Monday': {'close': '22:00', 'open': '11:00'}...  43.240875
# 5                                                     {}  42.968507
# 6                                                     {}  43.030356
# 7      {'Monday': {'close': '20:00', 'open': '09:00'}...  43.014093
# 8      {'Monday': {'close': '18:00', 'open': '07:30'}...  43.017124
# 9                                                     {}  43.017701
# 10                                                    {}  43.015931
# 11     {'Monday': {'close': '02:00', 'open': '11:00'}...  43.013156
# 12     {'Tuesday': {'close': '22:00', 'open': '16:30'...  43.014164
# 13                                                    {}  43.017939
# 14                                                    {}  43.093265
# 21                                   []   True             3    3.0    WI
# 22                                   []   True             4    3.0    WI
# 23                                   []   True             3    4.0    WI
# 24                                   []   True             7    3.5    WI
# 25                                   []   True            22    4.0    WI
# 26                                   []   True            38    3.5    WI
# 27                                   []   True            11    3.5    WI
# 28                                   []   True            28    3.0    WI
# 29                                   []   True             6    3.0    WI
# ...                                 ...    ...           ...    ...   ...
# 37908                        [Westside]   True             3    4.5    NV
# 37909                         [Capitol]   True             7    3.5    WI
# 37910                                []   True             4    5.0    AZ
# 37911                                []   True             7    3.5    WI
# 37912                 [South Summerlin]   True             5    5.0    NV
# 37913                           [Leith]   True             4    2.5   MLN
# 37914                                []   True             6    4.0    AZ
# 37915                                []   True             6    4.0    ON
# 37916                                []   True             5    1.5    AZ
# 37917                                []   True             5    5.0    AZ
# 37918                                []   True             8    5.0    AZ
# 37919                          [Anthem]   True            12    3.5    NV
# 37920                                []   True             3    5.0    AZ
# 37921                                []   True             5    5.0    AZ
# 37922  [South Summerlin, Spring Valley]   True             3    4.5    NV
# 37923                                []   True            15    4.5    AZ
# 37924                        [Westside]   True            12    4.5    NV
# 37925                       [Southeast]   True             4    5.0    NV
# 37926                                []   True             9    4.0    NV
# 37927                                []   True            26    3.5    NV
# 37928                        [New Town]   True             6    3.5   MLN
# 37929                        [Westside]   True             9    4.5    NV
# 37930                                []   True            34    3.5    NV
# 37931                                []   True            27    4.5    NV
# 37932                        [Westside]   True            18    4.5    NV
# 37933                                []   True             4    5.0    AZ
# 37934                         [Capitol]   True             3    5.0    WI
# 37935                                []   True            17    5.0    AZ
# 37936                                []   True             5    5.0    AZ
# 37937             [Tollcross, Old Town]   True             7    3.5   EDH
#
#            type
# 0      business
# 1      business
# 2      business
# 3      business
# 4      business
# 5      business
# 6      business
# 7      business
# 8      business
# 9      business
# 10     business
# 11     business
# 12     business
# 13     business
# 14     business
# 15     business
# 16     business
# 17     business
# 18     business
# 19     business
# 20     business
# 21     business
# 22     business
# 23     business
# 24     business
# 25     business
# 26     business
# 27     business
# 28     business
# 29     business
# ...         ...
# 37908  business
# 37909  business
# 37910  business
# 37911  business
# 37912  business
# 37913  business
# 37914  business
# 37915  business
# 37916  business
# 37917  business
# 37918  business
# 37919  business
# 37920  business
# 37921  business
# 37922  business
# 37923  business
# 37924  business
# 37925  business
# 37926  business
# 37927  business
# 37928  business
# 37929  business
# 37930  business
# 37931  business
# 37932  business
# 37933  business
# 37934  business
# 37935  business
# 37936  business
# 37937  business
#
# [37938 rows x 15 columns]

# %%
def get_delivery_attr(attr_dict):
    return attr_dict.get('Delivery')

# %% [markdown]
# If we give this function a `dict` from the `'attributes'` column, it will look for the `'Delivery'` key. If it finds that key, it returns the value. If it doesn't find the key, it will return none.

# %%
yelp_df.loc[2, 'attributes']
# Out:
# {'Take-out': True,
#  'Good For': {'dessert': False,
#   'latenight': False,
#   'lunch': False,
#   'dinner': False,
#   'breakfast': False,
#   'brunch': True},
#  'Caters': False,
#  'Noise Level': 'quiet',
#  'Takes Reservations': False,
#  'Delivery': False,
#  'Parking': {'garage': False,
#   'street': False,
#   'validated': False,
#   'lot': True,
#   'valet': False},
#  'Has TV': True,
#  'Outdoor Seating': False,
#  'Attire': 'casual',
#  'Ambience': {'romantic': False,
#   'intimate': False,
#   'touristy': False,
#   'hipster': False,
#   'divey': False,
#   'classy': False,
#   'trendy': False,
#   'upscale': False,
#   'casual': True},
#  'Waiter Service': True,
#  'Accepts Credit Cards': True,
#  'Good for Kids': True,
#  'Good For Groups': True,
#  'Price Range': 1}

# %%
print(get_delivery_attr(yelp_df.loc[0, 'attributes']))
print(get_delivery_attr(yelp_df.loc[1, 'attributes']))
print(get_delivery_attr(yelp_df.loc[2, 'attributes']))
# Out:
# None
# False
# False

# %% [markdown]
# We could iterate over the rows of `yelp_df['attributes']` to get all of the values, but there is a better way. DataFrames and Series have an `apply` method that allows us to apply our function to the entire data set at once, like we did earlier with `np.log`.

# %%
delivery_attr = yelp_df['attributes'].apply(get_delivery_attr)
delivery_attr.head(10)
# Out:
# 0     None
# 1    False
# 2    False
# 3    False
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9    False
# Name: attributes, dtype: object

# %%
delivery_attr.head()
# Out:
# 0     None
# 1    False
# 2    False
# 3    False
# 4     None
# Name: attributes, dtype: object

# %% [markdown]
# We can make a new column in our DataFrame with this transformed (and useful) information.

# %%
yelp_df['delivery'] = delivery_attr

# %%
yelp_df
# Out:
#                                               attributes  \
# 0                          {'By Appointment Only': True}
# 1      {'Take-out': True, 'Good For': {'dessert': Fal...
# 2      {'Take-out': True, 'Good For': {'dessert': Fal...
# 3      {'Take-out': True, 'Wi-Fi': 'free', 'Takes Res...
# 4      {'Take-out': True, 'Has TV': False, 'Outdoor S...
# 5                                                     {}
# 6                                                     {}
# 7                                      {'Wi-Fi': 'free'}
# 8                                                     {}
# 9      {'Alcohol': 'full_bar', 'Noise Level': 'loud',...
# 10     {'Accepts Credit Cards': True, 'Wi-Fi': 'free'...
# 11                               {'Good for Kids': True}
# 12     {'Take-out': True, 'Good For': {'dessert': Fal...
# 13     {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...
# 14     {'Take-out': True, 'Caters': True, 'Attire': '...
# 15     {'Take-out': True, 'Good For': {'dessert': Fal...
# 16     {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...
# 17                               {'Good for Kids': True}
# 18      {'Accepts Credit Cards': True, 'Price Range': 2}
# 19     {'Accepts Credit Cards': True, 'Wi-Fi': 'free'...
# 20     {'By Appointment Only': False, 'Good for Kids'...
# 21     {'Take-out': True, 'Takes Reservations': False...
# 22     {'Parking': {'garage': False, 'street': False,...
# 23     {'Parking': {'garage': False, 'street': True, ...
# 24     {'Parking': {'garage': False, 'street': True, ...
# 25     {'Wi-Fi': 'free', 'Price Range': 1, 'Outdoor S...
# 26     {'Take-out': True, 'Wi-Fi': 'free', 'Good For'...
# 27     {'Good For': {'dessert': False, 'latenight': F...
# 28     {'Take-out': True, 'Good For': {'dessert': Fal...
# 29     {'Take-out': True, 'Takes Reservations': False...
# ...                                                  ...
# 37908                     {'Accepts Credit Cards': True}
# 37909  {'Take-out': False, 'Good For': {'dessert': Fa...
# 37910   {'Accepts Credit Cards': True, 'Price Range': 2}
# 37911  {'Take-out': True, 'Good For': {'dessert': Fal...
# 37912                                                 {}
# 37913  {'Has TV': False, 'Good For Groups': True, 'Ou...
# 37914  {'Take-out': True, 'Good For': {'dessert': Fal...
# 37915  {'Take-out': True, 'Wi-Fi': 'free', 'Good For'...
# 37916  {'Parking': {'garage': False, 'street': False,...
# 37917  {'Take-out': True, 'Wi-Fi': 'free', 'Good For'...
# 
# 37925  flhtNfzfGiySc3g_U0Zkeg
# 37926  5se9c1ggSm2oMrnWO3ZSgw
# 37927  UH4BReVAqpMVjyVroEJAGA
# 37928  EYpqqsJZ3L2EFAPK-NEOFA
# 37929  KN-3Sg8TZ-y67026TFwmjw
# 37930  ZpB2O-WAbbRHdP0V8GrwXA
# 37931  OEUIE8VBa1BbBfr5EPcTOA
# 37932  yZXEELxi8KMwzXCHP345GQ
# 37933  iyKyJoDcbkGrMCgvyfMHxw
# 37934  tsvWY4o64xiv7K0VA89R8A
# 37935  nYer89hXYAoddMEKTxw7kA
# 37936  BMjggIgOghBMEXPo8q7q3w
# 37937  BVxlrYWgmi-8TPGMe6CTpg
#
#                                               categories         city  \
# 0                            [Doctors, Health & Medical]      Phoenix
# 1                                          [Restaurants]    De Forest
# 2                  [American (Traditional), Restaurants]    De Forest
# 3      [Food, Ice Cream & Frozen Yogurt, Fast Food, R...    De Forest
# 4                                 [Chinese, Restaurants]    De Forest
# 5                      [Television Stations, Mass Media]   Mc Farland
# 6       [Home Services, Heating & Air Conditioning/HVAC]   Mc Farland
# 7              [Libraries, Public Services & Government]   Mc Farland
# 8                                  [Veterinarians, Pets]   Mc Farland
# 9      [Bars, American (Traditional), Nightlife, Loun...   Mc Farland
# 10     [Hotels & Travel, Bed & Breakfast, Event Plann...   Mc Farland
# 11                                [Active Life, Bowling]   Mc Farland
# 12                                  [Pizza, Restaurants]   Mc Farland
# 13                                [Chinese, Restaurants]   Mc Farland
# 14     [Event Planning & Services, Party & Event Plan...    Middleton
# 15     [Party & Event Planning, Asian Fusion, Event P...    Middleton
# 16                                [Mexican, Restaurants]    Middleton
# 17     [Active Life, Arts & Entertainment, Stadiums &...    Middleton
# 18                                  [Pet Services, Pets]    Middleton
# 19     [Hotels & Travel, Event Planning & Services, V...    Middleton
# 20     [Pilates, Yoga, Weight Loss Centers, Health & ...    Middleton
# 21       [Sandwiches, Pizza, Chicken Wings, Restaurants]    Middleton
# 22     [Shopping, Arts & Crafts, Event Planning & Ser...    Middleton
# 23     [Arts & Crafts, Shopping, Knitting Supplies, H...    Middleton
# 24     [Women's Clothing, Shopping Centers, Fashion, ...    Middleton
# 25            [Food, Beer, Wine & Spirits, Coffee & Tea]    Middleton
# 26     [Bakeries, Food, Breakfast & Brunch, Coffee & ...    Middleton
# 27        [Bars, American (New), Nightlife, Restaurants]    Middleton
# 28                                [Chinese, Restaurants]    Middleton
# 29                                [Chinese, Restaurants]    Middleton
# ...                                                  ...          ...
# 37908  [Local Services, Data Recovery, Mobile Phone R...    Las Vegas
# 37909                         [Steakhouses, Restaurants]      Madison
# 37910        [Shopping, Home & Garden, Furniture Stores]      Gilbert
# 37911        [American (New), Comfort Food, Restaurants]  Sun Prairie
# 37912            [Arts & Entertainment, Performing Arts]    Las Vegas
# 37913                          [Tapas Bars, Restaurants]    Edinburgh
# 37914                               [Pizza, Restaurants]      Phoenix
# 37915  [Food, Tea Rooms, Coffee & Tea, Asian Fusion, ...     Waterloo
# 37910     2757 S San Tan Village Pkwy\nGilbert, AZ 85295
# 37911  2804 Prairie Lakes Dr\nSte 106\nSun Prairie, W...
# 37912  83 Panorama Crest Ave\nSouth Summerlin\nLas Ve...
# 37913           297 Leith Walk\nLeith\nEdinburgh EH6 8SA
# 37914               1031 NW Grand Ave\nPhoenix, AZ 85007
# 37915                255 King Street N\nWaterloo, ON N2J
# 37916         1312 N Scottsdale Rd\nScottsdale, AZ 85257
# 37917  22721 S Ellsworth Rd\nSte 107\nQueen Creek, AZ...
# 37918         1816 E Oak St\nSte 4566\nPhoenix, AZ 85006
# 37919  10251 S Eastern Ave\nSte C\nAnthem\nHenderson,...
# 37920                              Queen Creek, AZ 85142
# 37921  13045 W Rancho Santa Fe Blvd\nA105\nAvondale, ...
# 37922  3700 S Hualapai Way\nSte 108\nSouth Summerlin\...
# 37923             4320 N Miller Rd\nScottsdale, AZ 85251
# 37924  4860 W Desert Inn Rd\nSte 9\nWestside\nLas Veg...
# 37925                     Southeast\nLas Vegas, NV 89120
# 37926     6820 W Flamingo Rd\nSte A\nLas Vegas, NV 89103
# 37927               900 Galleria Dr\nHenderson, NV 89011
# 37928       45 Broughton St\nNew Town\nEdinburgh EH1 3JU
# 37929  6475 W Charleston Blvd\nSte 150\nWestside\nLas...
# 37930  140 S Green Valley Pkwy\nSte 142\nHenderson, N...
# 37931        19 S Stephanie\nSte140\nHenderson, NV 89012
# 37932  2550 S Rainbow Blvd\nSte  W1\nWestside\nLas Ve...
# 37933          4340 W Thunderbird Rd\nGlendale, AZ 85306
# 37934  1 E Main St\nLower Level Suite 5\nCapitol\nMad...
# 37935           FilmBar\n815 N 2nd St\nPhoenix, AZ 85004
# 37936                   6505 N 7th St\nPhoenix, AZ 85014
# 37937     125 Lauriston Pl\nTollcross\nEdinburgh EH3 9JN
#
#                                                    hours   latitude  \
# 0      {'Tuesday': {'close': '17:00', 'open': '08:00'...  33.499313
# 1                                                     {}  43.238893
# 2      {'Monday': {'close': '22:00', 'open': '06:00'}...  43.252267
# 3      {'Monday': {'close': '22:00', 'open': '10:30'}...  43.251045
# 4      {'Monday': {'close': '22:00', 'open': '11:00'}...  43.240875
# 5                                                     {}  42.968507
# 6                                                     {}  43.030356
# 7      {'Monday': {'close': '20:00', 'open': '09:00'}...  43.014093
# 8      {'Monday': {'close': '18:00', 'open': '07:30'}...  43.017124
# 9                                                     {}  43.017701
# 10                                                    {}  43.015931
# 11     {'Monday': {'close': '02:00', 'open': '11:00'}...  43.013156
# 12     {'Tuesday': {'close': '22:00', 'open': '16:30'...  43.014164
# 13                                                    {}  43.017939
# 14                                                    {}  43.093265
# 15     {'Monday': {'close': '14:00', 'open': '11:00'}...  43.090642
# 16     {'Monday': {'close': '21:00', 'open': '06:00'}...  43.091061
# 17     {'Monday': {'close': '21:00', 'open': '09:00'}...  43.110157
# 18                                                    {}  43.077415
# 19                                                    {}  43.096271
# 20     {'Monday': {'close': '00:00', 'open': '00:00'}...  43.103072
# 21                                                    {}  43.100384
# 22     {'Monday': {'close': '21:00', 'open': '09:30'}...  43.095498
# 23     {'Monday': {'close': '21:00', 'open': '09:00'}...  43.092903
# 24     {'Monday': {'close': '20:00', 'open': '10:00'}...  43.091816
# 25     -89.513737                           Barriques Wine & Spirits
# 26     -89.496995                              Prairie Cafe & Bakery
# 27     -89.511162                            Paul's Neighborhood Bar
# 28     -89.528480                                  Chin's Asia Fresh
# 29     -89.486491                             Grand China Restaurant
# ...           ...                                                ...
# 37908 -115.245389                                  My Computer Bytes
# 37909  -89.385835                                    Rare Steakhouse
# 37910 -111.746902                                At Home Furnishings
# 37911  -89.270095                                               MACS
# 37912 -115.344752                                     Water Beauties
# 37913   -3.176367                                   Serrano Manchego
# 37914 -112.087116                         Grand Avenue Pizza Company
# 37915  -80.525499                                            Chatime
# 37916 -111.926974                                     Plato's Closet
# 37917 -111.634005                             The Bistro Queen Creek
# 37918 -112.064650                        Movers Phoenix Professional
# 37919 -115.110455                                 Pink Box Doughnuts
# 37920 -111.634299                                  A-1 Hand Handyman
# 37921 -112.336565                                     Zoni Shave Ice
# 37922 -115.314146                        Popped Gourmet Popcorn Spot
# 37923 -111.917816                                            Sushi J
# 37924 -115.207404                                            Pho Lan
# 37925 -115.099975                                           Bakeshop
# 37926 -115.241094                                     D' Pinoy Joint
# 37927 -115.024682                           Cowabunga Bay-Water Park
# 37928   -3.188413                                   Burger Meats Bun
# 37929 -115.236715                                      702 Wing Spot
# 37930 -115.083362                                       LYFE Kitchen
# 37931 -115.048825                                        Presto Cafe
# 37932 -115.241975                  Maza Mediterranean Grill & Lounge
# 37933 -112.152529                                       The V Lounge
# 37934  -89.382842                                    Pilates Central
# 37935 -112.071074              Yelp's Secret Cinema: Made In Arizona
# 37936 -112.064508                    LaBella Pizzeria and Restaurant
# 37937   -3.202529                               Oriental Supermarket
#
#                           neighborhoods   open  review_count  stars state  \
# 0                                    []   True             7    3.5    AZ
# 1                                    []   True            26    4.0    WI
# 2                                    []   True            16    4.0    WI
# 3                                    []   True             7    4.5    WI
# 4                                    []   True             3    4.0    WI
# 5                                    []  False            10    1.5    WI
# 6                                    []   True             4    2.0    WI
# 7                                    []   True             4    2.5    WI
# 8                                    []   True             3    4.5    WI
# 9                                    []   True            31    3.5    WI
# 10                                   []   True             9    5.0    WI
# 11                                   []   True             3    1.5    WI
# 12                                   []   True             4    3.5    WI
# 13                                   []   True             8    3.5    WI
# 14                                   []  False             5    4.0    WI
# 15                                   []   True            41    3.0    WI
# 16                                   []  False            17    3.0    WI
# 17                                   []   True             3    3.5    WI
# 18                                   []   True             3    4.5    WI
# 19                                   []   True             6    4.5    WI
# 20                                   []   True             5    5.0    WI
# 21                                   []   True             3    3.0    WI
# 22                                   []   True             4    3.0    WI
# 23                                   []   True             3    4.0    WI
# 24                                   []   True             7    3.5    WI
# 25                                   []   True            22    4.0    WI
# 26                                   []   True            38    3.5    WI
# 27                                   []   True            11    3.5    WI
# 28                                   []   True            28    3.0    WI
# 29                                   []   True             6    3.0    WI
# ...                                 ...    ...           ...    ...   ...
# 37908                        [Westside]   True             3    4.5    NV
# 37909                         [Capitol]   True             7    3.5    WI
# 37910                                []   True             4    5.0    AZ
# 37911                                []   True             7    3.5    WI
# 37912                 [South Summerlin]   True             5    5.0    NV
# 37913                           [Leith]   True             4    2.5   MLN
# 37914                                []   True             6    4.0    AZ
# 37915                                []   True             6    4.0    ON
# 37916                                []   True             5    1.5    AZ
# 37917                                []   True             5    5.0    AZ
# 37918                                []   True             8    5.0    AZ
# 37919                          [Anthem]   True            12    3.5    NV
# 37920                                []   True             3    5.0    AZ
# 37921                                []   True             5    5.0    AZ
# 37922  [South Summerlin, Spring Valley]   True             3    4.5    NV
# 37923                                []   True            15    4.5    AZ
# 37924                        [Westside]   True            12    4.5    NV
# 37925                       [Southeast]   True             4    5.0    NV
# 37926                                []   True             9    4.0    NV
# 37927                                []   True            26    3.5    NV
# 37928                        [New Town]   True             6    3.5   MLN
# 37929                        [Westside]   True             9    4.5    NV
# 37930                                []   True            34    3.5    NV
# 37931                                []   True            27    4.5    NV
# 37932                        [Westside]   True            18    4.5    NV
# 37933                                []   True             4    5.0    AZ
# 37934                         [Capitol]   True             3    5.0    WI
# 37935                                []   True            17    5.0    AZ
# 37936                                []   True             5    5.0    AZ
# 37937             [Tollcross, Old Town]   True             7    3.5   EDH
#
#            type delivery
# 0      business     None
# 1      business    False
# 2      business    False
# 3      business    False
# 4      business     None
# 5      business     None
# 6      business     None
# 7      business     None
# 8      business     None
# 9      business    False
# 10     business     None
# 11     business     None
# 12     business    False
# 13     business    False
# 14     business     None
# 15     business    False
# 16     business    False
# 17     business     None
# 18     business     None
# 19     business     None
# 20     business     None
# 21     business     True
# 22     business     None
# 23     business     None
# 24     business     None
# 25     business     None
# 26     business    False
# 27     business     None
# 28     business    False
# 29     business     None
# ...         ...      ...
# 37908  business     None
# 37909  business    False
# 37910  business     None
# 37911  business     None
# 37912  business     None
# 37913  business     None
# 37914  business     True
# 37915  business    False
# 37916  business     None
# 37917  business    False
# 37918  business     None
# 37919  business     None
# 37920  business     None
# 37921  business     None
# 37922  business     None
# 37923  business    False
# 37924  business    False
# 37925  business     None
# 37926  business    False
# 37927  business     None
# 37928  business    False
# 37929  business     True
# 37930  business    False
# 37931  business    False
# 37932  business     True
# 37933  business     None
# 37934  business     None
# 37935  business     None
# 37936  business     True
# 37937  business     None
#
# [37938 rows x 16 columns]

# %%
yelp_df[yelp_df['delivery'] == True]
# Out:
#                                               attributes  \
# 21     {'Take-out': True, 'Takes Reservations': False...
# 64     {'Take-out': True, 'Alcohol': 'none', 'Takes R...
# 75     {'Take-out': True, 'Good For': {'dessert': Fal...
# 79     {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...
# 82     {'Delivery': True, 'Waiter Service': True, 'Ta...
# 100    {'Take-out': True, 'Good For': {'dessert': Fal...
# 106    {'BYOB': False, 'Take-out': True, 'Wi-Fi': 'no...
# 113    {'Take-out': True, 'Wi-Fi': 'free', 'Good For'...
# 120    {'Take-out': True, 'Good For': {'dessert': Fal...
# 127    {'Take-out': True, 'Alcohol': 'none', 'Deliver...
# 168    {'Take-out': True, 'Good For': {'dessert': Fal...
# 180    {'Delivery': True, 'Takes Reservations': False...
# 190    {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...
# 211    {'Delivery': True, 'Good For': {'dessert': Fal...
# 231    {'Take-out': True, 'Accepts Credit Cards': Tru...
# 255    {'Take-out': True, 'Good For': {'dessert': Fal...
# 265    {'Take-out': True, 'Alcohol': 'none', 'Parking...
# 273    {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...
# 287    {'Take-out': True, 'Good For': {'dessert': Fal...
# 292    {'Take-out': True, 'Good For': {'dessert': Fal...
# 297    {'Take-out': True, 'Wi-Fi': 'no', 'Alcohol': '...
# 333    {'Take-out': True, 'Wi-Fi': 'free', 'Good For'...
# 334    {'Alcohol': 'full_bar', 'Open 24 Hours': False...
# 364    {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...
# 374    {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...
# 388    {'Take-out': True, 'Good For': {'dessert': Fal...
# 427    {'Alcohol': 'full_bar', 'Noise Level': 'averag...
# 471    {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...
# 502    {'Take-out': True, 'Good For': {'dessert': Fal...
# 517    {'Take-out': True, 'Good For': {'dessert': Fal...
# ...                                                  ...
# 37461  {'Take-out': True, 'Wi-Fi': 'free', 'Alcohol':...
# 37486  {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...
# 37502  {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...
# 37519  {'Take-out': True, 'Takes Reservations': False...
# 37551  {'Coat Check': False, 'Take-out': True, 'Wi-Fi...
# 37560  {'Take-out': True, 'Noise Level': 'loud', 'Tak...
# 37569  {'Take-out': True, 'Wi-Fi': 'free', 'Good For'...
# 37574  {'Take-out': True, 'Wi-Fi': 'free', 'Good For'...
# 37580  {'Take-out': True, 'Wi-Fi': 'free', 'Good For'...
# 37583  {'Take-out': True, 'Good For': {'dessert': Fal...
# 37618  {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...
# 37637  {'Take-out': True, 'Caters': True, 'Delivery':...
# 37655  {'Take-out': True, 'Wi-Fi': 'free', 'Good For'...
# 37657  {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...
# 37689  {'Take-out': True, 'Good For': {'dessert': Fal...
# 37709  {'Take-out': True, 'Wi-Fi': 'no', 'Alcohol': '...
# 37720  {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...
# 37742  {'Take-out': True, 'Wi-Fi': 'free', 'Good For'...
# 37759  {'Take-out': True, 'Wi-Fi': 'free', 'Good For'...
# 37798  {'Take-out': True, 'Good For': {'dessert': Fal...
# 37816  {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...
# 37846  {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...
# 37874  {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...
# 37880  {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...
# 37881  {'Take-out': True, 'Takes Reservations': True,...
# 37889  {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...
# 37914  {'Take-out': True, 'Good For': {'dessert': Fal...
# 37929  {'Take-out': True, 'Wi-Fi': 'free', 'Good For'...
# 37932  {'Alcohol': 'full_bar', 'Noise Level': 'quiet'...
# 37936  {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...
#
#                   business_id  \
# 21     KTqNU4plO23583DYAMGXYg
# 64     oc0rCahXOaJeHLzzDdSfyA
# 75     OC8AUJshLVimn_-P_INvJw
# 79     NDAxF0_RCZBQedVO_d5WnA
# 82     5uxhIGZlJm9g_zfG_83z5Q
# 100    oX6KamASYXnMIe5kpVhezw
# 106    xZwaUcrFMSY1O9dK2dAUpA
# 113    ybkWtM1ZnT2ewuquj3A9KQ
# 120    jo-BEjs7UYovOAupDAN_yw
# 127    pSiRWeCqs7a1xvS9ycLoTQ
# 168    7uoxZ35biPZfl8m5w2_XRA
# 180    jqOPL979k-t_Vc049CnAjg
# 190    xMyTUliefguc3bfetGebJg
# 211    Pa_brCvUaiUPPvm3tJQwgw
# 231    pHBQ-dQRwN3z7Rq7iSog-A
# 255    I8Bx7iuHWz6d2TQDfKfjqA
# 265    unXHmjewHGeWQwJr74Sy9g
# 273    2aai1pIfThxDTTD_WwXHeA
# 287    R825-NTAI2wG2C4mN-dtNA
# 292    r5S_wYdu1vKRW1k-7_yOIA
# 297    x5Mv61CnZLohZWxfCVCPTQ
# 333    Y293fHh5SZ0_9BZm4M6BCg
# 334    IceZ4BtTz76eppjNWm-c6A
# 364    sInUSy63Oh455uWs9p9OqQ
# 374    q1nDSpmV-FdTBNj6UuZvTg
# 388    avPNEqlXgyBvTXjb-ujQFA
# 427    5-X03Zc0nN7U5eoe8uFUdw
# 471    xfk9eY8gmwn8qsbyd-W6lQ
# 502    9tefv6uPxoHhp_OlQQJVXA
# 517    I4L_MJOZsnux3xCU2bLP8Q
# ...                       ...
# 37461  qPweoC5UlERfrZ4EhCS1Nw
# 37486  ONV_6efcOjJBQczeqIqHPQ
# 37502  cl5ZkXAzkitvivng_INUkQ
# 37519  ZlSYvDuXRi_8bv_ggXvpHQ
# 37551  OMjskFVMEpwkYDdUtvFAmQ
# 37560  VWhRZy_PFKYNU8qFxMvSRw
# 37569  aj2FShIkWIm1i1qnTljP6w
# 37574  _UOaoy1lcdIbgaA-d9dqpg
# 37580  fk4VmHeqFOghZOKZo7UVCg
# 37583  WvF3XVedUioBaG_xLgTgNQ
# 37618  0IV5L36XeQShzWiUhom9bQ
# 37637  tFWuvLflDDvTdypS_vdfNA
# 37655  ql12LAdBdaqT3-zuRU6QHA
# 37657  tSNpBgk_uXt6kmtChX39tg
# 37689  hCmarzJoLFQ8VqAP3aUcjg
# 37709  hHfPc13Zn2X33fjLZegl_Q
# 37720  6bBJymP2jh-tenBY8zvL1A
# 37742  MJLe4pP-0ZOFHuFt0CIoRw
# 37759  8T4aPvtpugzUxJc-DVrLHg
# 37798  xXN-jNziqt_6lXzRYhh_2w
# 37816  47bimRPTRW5AipXRwfVA1A
# 37846  epfCLR2XOA7VOsBxLKuSwQ
# 37874  cOPKrTpfmse01coqXiX-CQ
# 37880  6c-_klCWVUwnFlXSRUzaSA
# 37881  wd3nrdoEpikmGcf4NX0ziA
# 37889  nuHftEWNyMIsa4R4OpqlQg
# 37914  51vtDjP79vBjaI5dbkPoPw
# 37929  KN-3Sg8TZ-y67026TFwmjw
# 37932  yZXEELxi8KMwzXCHP345GQ
# 37936  BMjggIgOghBMEXPo8q7q3w
#
#                                               categories            city  \
# 21       [Sandwiches, Pizza, Chicken Wings, Restaurants]       Middleton
# 64                                         [Restaurants]       Middleton
# 75       [Sandwiches, Pizza, Chicken Wings, Restaurants]     Sun Prairie
# 79                                [Chinese, Restaurants]     Sun Prairie
# 82                                [Chinese, Restaurants]     Sun Prairie
# 100                               [Chinese, Restaurants]         Madison
# 106                               [Chinese, Restaurants]         Madison
# 113                               [Restaurants, Italian]         Madison
# 120                                 [Pizza, Restaurants]         Madison
# 127                               [Chinese, Restaurants]         Madison
# 168                                 [Pizza, Restaurants]         Madison
# 180                                 [Pizza, Restaurants]         Madison
# 190    [Caterers, Pizza, Event Planning & Services, R...         Madison
# 211                                 [Greek, Restaurants]         Madison
# 231                                 [Pizza, Restaurants]         Madison
# 255                                 [Pizza, Restaurants]          Monona
# 265                               [Chinese, Restaurants]         Madison
# 273                               [Chinese, Restaurants]          Monona
# 287    [American (Traditional), Pizza, Gluten-Free, R...         Madison
# 292                            [Sandwiches, Restaurants]         Madison
# 297      [Sandwiches, Pizza, Chicken Wings, Restaurants]         Phoenix
# 333                        [Greek, Mexican, Restaurants]         Phoenix
# 334                  [Greek, Mediterranean, Restaurants]         Phoenix
# 364                                 [Cafes, Restaurants]         Phoenix
# 374                              [Barbeque, Restaurants]         Phoenix
# 388                                 [Pizza, Restaurants]         Phoenix
# 427                        [American (New), Restaurants]         Phoenix
# 471                              [Barbeque, Restaurants]         Phoenix
# 297                2819 N Central Ave\nPhoenix, AZ 85004
# 333                    125 E Adams St\nPhoenix, AZ 85004
# 334                 1030 NW Grand Ave\nPhoenix, AZ 85007
# 364                2600 N Central Ave\nPhoenix, AZ 85004
# 374                2824 N Central Ave\nPhoenix, AZ 85004
# 388             2835 N 16th St\nSte 7\nPhoenix, AZ 85006
# 427                     2201 N 7th St\nPhoenix, AZ 85006
# 471               5012 E Van Buren St\nPhoenix, AZ 85008
# 502                    2545 N 32nd St\nPhoenix, AZ 85008
# 517                3003 N Central Ave\nPhoenix, AZ 85012
# ...                                                  ...
# 37461       6922 N 95th Ave\nSte 200\nGlendale, AZ 85305
# 37486  14850 N Frank Lloyd Wright Blvd\nScottsdale, A...
# 37502              3050 Cahill Main\nFitchburg, WI 53711
# 37519      20928 Heritage Loop Rd\nQueen Creek, AZ 85142
# 37551            1420 Nevada Hwy\nBoulder City, NV 89005
# 37560  9010 W Flamingo\nSpring Valley\nLas Vegas, NV ...
# 37569  3225 S Rainbow Blvd\nSte 106\nWestside\nLas Ve...
# 37574     8763 E Bell Rd\nSte C103\nScottsdale, AZ 85260
# 37580        219 E Baseline Rd\nSte H-2\nTempe, AZ 85283
# 37583  10870 W Charleston Blvd\nSte 180\nSummerlin\nL...
# 37618  8150 S Maryland Pkwy\n120\nSoutheast\nLas Vega...
# 37637  5190 S Valley View Blvd\nSte 100\nLas Vegas, N...
# 37655  Arizona Ctr Mall\n455 N 3rd St\nPhoenix, AZ 85004
# 37657    7650 S  McClintock Dr\nSte 112\nTempe, AZ 85284
# 37689   8878 S Eastern Ave\nSte 104\nLas Vegas, NV 89123
# 37709                1859 W Guadalupe Rd\nMesa, AZ 85202
# 37720            604 N Rainbow Blvd\nLas Vegas, NV 89107
# 37742  5600 Spring Mountain Rd\nSte B\nChinatown\nLas...
# 37759  5740 Spring Mountain Rd\nChinatown\nLas Vegas,...
# 37798       734 N McQueen Rd\nSte 102\nGilbert, AZ 85233
# 37816  4631 Spring Mountain Rd\nSte 102\nChinatown\nL...
# 37846  9530 S Eastern Ave\nSte 160\nSoutheast\nLas Ve...
# 37874            3137 Industrail Rd\nLas Vegas, NV 89109
# 37880  12645 Saguaro Blvd\nSte 1\nFountain Hills, AZ ...
# 37881  5625 S Rainbow Blvd\nSte E\nSpring Valley\nLas...
# 37889  1910 Village Center Cir\nSte 3\nSummerlin\nLas...
# 37914               1031 NW Grand Ave\nPhoenix, AZ 85007
# 37929  6475 W Charleston Blvd\nSte 150\nWestside\nLas...
# 37932  2550 S Rainbow Blvd\nSte  W1\nWestside\nLas Ve...
# 37936                   6505 N 7th St\nPhoenix, AZ 85014
#
#                                                    hours   latitude  \
# 21                                                    {}  43.100384
# 64                                                    {}  43.096359
# 75     {'Monday': {'close': '23:00', 'open': '11:00'}...  43.183277
# 79                                                    {}  43.180786
# 82                                                    {}  43.175381
# 100    {'Monday': {'close': '21:30', 'open': '09:00'}...  43.120575
# 106    {'Monday': {'close': '22:00', 'open': '11:00'}...  43.094478
# 120                 [Sherman]  False             3    1.5    WI  business
# 127               [Ridgewood]   True             6    2.0    WI  business
# 168    [Starkweather - Yahar]   True             3    3.5    WI  business
# 180               [Ridgewood]   True             4    4.0    WI  business
# 190            [Emerson East]   True             7    2.5    WI  business
# 211               [Hawthorne]  False             3    3.5    WI  business
# 231         [Rolling Meadows]   True             5    1.5    WI  business
# 255                        []  False             3    4.0    WI  business
# 265         [Rolling Meadows]   True            10    3.0    WI  business
# 273                        []   True             5    3.0    WI  business
# 287           [High Crossing]   True            24    3.0    WI  business
# 292                  [Regent]   True            12    3.5    WI  business
# 297                        []   True            12    2.5    AZ  business
# 333                        []  False            58    3.0    AZ  business
# 334                        []  False            60    3.5    AZ  business
# 364                        []   True             6    4.0    AZ  business
# 374                        []   True           191    3.0    AZ  business
# 388                        []   True             4    2.0    AZ  business
# 427                        []  False           175    4.0    AZ  business
# 471                        []   True           138    3.0    AZ  business
# 502                        []   True            11    2.5    AZ  business
# 517                        []   True            10    3.5    AZ  business
# ...                       ...    ...           ...    ...   ...       ...
# 37461                      []   True            17    4.5    AZ  business
# 37486                      []   True            13    3.0    AZ  business
# 37502                      []   True            13    3.5    WI  business
# 37519                      []   True             4    3.0    AZ  business
# 37551                      []   True            15    4.5    NV  business
# 37560         [Spring Valley]   True             9    2.0    NV  business
# 37569              [Westside]   True            23    4.0    NV  business
# 37574                      []   True             8    4.0    AZ  business
# 37580                      []   True            13    4.0    AZ  business
# 37583             [Summerlin]   True            14    2.5    NV  business
# 37618             [Southeast]   True            18    4.5    NV  business
# 37637                      []   True             4    4.0    NV  business
# 37655                      []   True             3    2.0    AZ  business
# 37657                      []   True            13    3.5    AZ  business
# 37689                      []   True            33    4.5    NV  business
# 37709                      []   True            12    3.5    AZ  business
# 37720                      []   True            11    4.5    NV  business
# 37742             [Chinatown]   True             5    4.0    NV  business
# 37759             [Chinatown]   True             9    4.5    NV  business
# 37798                      []   True             7    3.0    AZ  business
# 37816             [Chinatown]   True            26    4.0    NV  business
# 37846             [Southeast]   True             4    3.5    NV  business
# 37874                      []   True             9    4.0    NV  business
# 37880                      []   True            11    4.0    AZ  business
# 37881         [Spring Valley]   True             7    5.0    NV  business
# 37889             [Summerlin]   True             8    4.0    NV  business
# 37914                      []   True             6    4.0    AZ  business
# 37929              [Westside]   True             9    4.5    NV  business
# 37932              [Westside]   True            18    4.5    NV  business
# 37936                      []   True             5    5.0    AZ  business
#
#       delivery
# 21        True
# 64        True
# 75        True
# 79        True
# 82        True
# 100       True
# 106       True
# 113       True
# 120       True
# 127       True
# 168       True
# 180       True
# 190       True
# 211       True
# 231       True
# 255       True
# 265       True
# 273       True
# 287       True
# 292       True
# 297       True
# 333       True
# 334       True
# 364       True
# 374       True
# 388       True
# 427       True
# 471       True
# 502       True
# 517       True
# ...        ...
# 37461     True
# 37486     True
# 37502     True
# 37519     True
# 37551     True
# 37560     True
# 37569     True
# 37574     True
# 37580     True
# 37583     True
# 37618     True
# 37637     True
# 37655     True
# 37657     True
# 37689     True
# 37709     True
# 37720     True
# 37742     True
# 37759     True
# 37798     True
# 37816     True
# 37846     True
# 37874     True
# 37880     True
# 37881     True
# 37889     True
# 37914     True
# 37929     True
# 37932     True
# 37936     True
#
# [2117 rows x 16 columns]

# %%
# to find businesses that deliver
yelp_df[yelp_df['delivery'].fillna(False)].head()
# Out:
#                                            attributes             business_id  \
# 21  {'Take-out': True, 'Takes Reservations': False...  KTqNU4plO23583DYAMGXYg
# 64  {'Take-out': True, 'Alcohol': 'none', 'Takes R...  oc0rCahXOaJeHLzzDdSfyA
# 75  {'Take-out': True, 'Good For': {'dessert': Fal...  OC8AUJshLVimn_-P_INvJw
# 79  {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...  NDAxF0_RCZBQedVO_d5WnA
# 82  {'Delivery': True, 'Waiter Service': True, 'Ta...  5uxhIGZlJm9g_zfG_83z5Q
#
#                                          categories         city  \
# 21  [Sandwiches, Pizza, Chicken Wings, Restaurants]    Middleton
# 64                                    [Restaurants]    Middleton
# 75  [Sandwiches, Pizza, Chicken Wings, Restaurants]  Sun Prairie
# 79                           [Chinese, Restaurants]  Sun Prairie
# 82                           [Chinese, Restaurants]  Sun Prairie
#
#                             full_address  \
# 21  2411 Allen Blvd\nMiddleton, WI 53562
# 64   1901 Cayuga St\nMiddleton, WI 53562
# 75  330 W Main St\nSun Prairie, WI 53590
# 79  984 W Main St\nSun Prairie, WI 53590
# 82  2091 McCoy Rd\nSun Prairie, WI 53590
#
#                                                 hours   latitude  longitude  \
# 21                                                 {}  43.100384 -89.486219
# 64                                                 {}  43.096359 -89.513737
# 75  {'Monday': {'close': '23:00', 'open': '11:00'}...  43.183277 -89.218527
# 79                                                 {}  43.180786 -89.230477
# 82                                                 {}  43.175381 -89.248245
#
#                          name neighborhoods   open  review_count  stars state  \
# 21             Domino's Pizza            []   True             3    3.0    WI
# 64               Soup Factory            []  False             3    3.0    WI
# 75                  Pizza Pit            []   True             4    2.5    WI
# 79                Chang Jiang            []   True             9    3.0    WI
# 82  Peking Chinese Restaurant            []   True             6    3.0    WI
#
#         type delivery
# 21  business     True
# 64  business     True
# 75  business     True
# 79  business     True
# 82  business     True

# %% [markdown]
# It's less common (though possible) to use `apply` on an entire DataFrame rather than just one column. Since a DataFrame might contain many types of data, we won't usually want to apply the same transformation or aggregation across all of the columns.

# %% [markdown]
# ## Data aggregation with `groupby`
#
# Data aggregation is an [_overloaded_](https://en.wikipedia.org/wiki/Function_overloading) term. It refers to both data summarization (as above) but also to the combining of different data sets.
#
# With our Yelp data, we might be interested in comparing the star ratings of businesses in different cities. We could calculate the mean star rating for each city, and this would allow us to easily compare them. First we would have to split up our data by city, calculate the mean for each city, and then combine it back at the end. This procedure is known as [split-apply-combine](https://pandas.pydata.org/pandas-docs/stable/groupby.html) and is a classic example of data aggregation (in the sense of both summarizing data and also combining different data sets).
#
# We achieve the splitting and recombining using the `groupby` method.

# %%
yelp_df['city'].head()
# Out:
# 0      Phoenix
# 1    De Forest
# 2    De Forest
# 3    De Forest
# 4    De Forest
# Name: city, dtype: object

# %%
stars_by_city = yelp_df.groupby('city')['stars'].mean()
stars_by_city.head()
# Out:
# city
# Ahwatukee          3.687500
# Anthem             3.781818
# Apache Junction    3.637500
# Arcadia            5.000000
# Atlanta            3.500000
# Name: stars, dtype: float64

# %%
    stars_by_city.max()
# Out:
# 5.0

# %% [markdown]
# We can also apply multiple functions at once. It might be helpful to know the standard deviation of star ratings, the total number of reviews, and the count of businesses as well.

# %%
agg_by_city = yelp_df.groupby('city').agg({'stars': {'mean': 'mean', 'std': 'std'}, 'review_count': 'sum', 'business_id': 'count'})
agg_by_city.head()
# Out:
#                     stars           review_count business_id
#                      mean       std          sum       count
# city
# Ahwatukee        3.687500  1.066955          258           8
# Anthem           3.781818  0.756231          727          55
# Apache Junction  3.637500  1.028010          853          80
# Arcadia          5.000000       NaN            4           1
# Atlanta          3.500000       NaN           16           1

# %%
agg_by_city.columns
# Out:
# MultiIndex(levels=[['stars', 'review_count', 'business_id'], ['count', 'mean', 'std', 'sum']],
#            codes=[[0, 0, 1, 2], [1, 2, 3, 0]])

# %%
# unstacking the columns
new_columns = map(lambda x: '_'.join(x),
                  zip(agg_by_city.columns.get_level_values(0),
                      agg_by_city.columns.get_level_values(1)))
agg_by_city.columns = new_columns
agg_by_city.head()
# Out:
#                  stars_mean  stars_std  review_count_sum  business_id_count
# city
# Ahwatukee          3.687500   1.066955               258                  8
# Anthem             3.781818   0.756231               727                 55
# Apache Junction    3.637500   1.028010               853                 80
# Arcadia            5.000000        NaN                 4                  1
# Atlanta            3.500000        NaN                16                  1

# %% [markdown]
# How does this work? What does `groupby` do? Let's start by inspecting the result of `groupby`.

# %%
by_city = yelp_df.groupby('city')
by_city.agg({'business_id': 'count'}).head()
# Out:
#                  business_id
# city
# Ahwatukee                  8
# Anthem                    55
# Apache Junction           80
# Arcadia                    1
# Atlanta                    1

# %%
dir(by_city)
# Out:
# ['__bytes__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_accessors',
#  '_add_numeric_operations',
#  '_agg_examples_doc',
#  '_agg_see_also_doc',
#  '_aggregate',
#  '_aggregate_generic',
#  '_aggregate_item_by_item',
#  '_aggregate_multiple_funcs',
#  '_apply_filter',
#  '_apply_to_column_groupbys',
#  '_apply_whitelist',
#  '_assure_grouper',
#  '_block_agg_axis',
#  '_bool_agg',
#  '_builtin_table',
#  '_choose_path',
#  '_concat_objects',
#  '_constructor',
#  '_cumcount_array',
#  '_cython_agg_blocks',
#  '_cython_agg_general',
#  '_cython_table',
#  '_cython_transform',
#  '_decide_output_index',
#  '_def_str',
#  '_define_paths',
#  '_deprecations',
#  '_dir_additions',
#  '_dir_deletions',
#  '_fill',
#  '_get_cythonized_result',
#  '_get_data_to_aggregate',
#  '_get_index',
#  '_get_indices',
#  '_gotitem',
#  '_group_selection',
#  '_insert_inaxis_grouper_inplace',
#  '_internal_names',
#  '_internal_names_set',
#  '_is_builtin_func',
#  '_is_cython_func',
#  '_iterate_column_groupbys',
#  '_iterate_slices',
#  '_make_wrapper',
#  '_obj_with_exclusions',
#  '_post_process_cython_aggregate',
#  '_python_agg_general',
#  '_python_apply_general',
#  '_reindex_output',
#  '_reset_cache',
#  '_reset_group_selection',
#  '_selected_obj',
#  '_selection',
#  '_selection_list',
#  '_selection_name',
#  '_set_group_selection',
#  '_set_result_index_ordered',
#  '_shallow_copy',
#  '_transform_fast',
#  '_transform_general',
#  '_transform_item_by_item',
#  '_transform_should_cast',
#  '_try_aggregate_string_function',
#  '_try_cast',
#  '_wrap_agged_blocks',
#  '_wrap_aggregated_output',
#  '_wrap_applied_output',
#  '_wrap_generic_output',
#  '_wrap_transformed_output',
#  'agg',
#  'aggregate',
#  'all',
#  'any',
#  'apply',
#  'attributes',
#  'backfill',
#  'bfill',
#  'boxplot',
#  'business_id',
#  'categories',
#  'city',
#  'corr',
#  'corrwith',
#  'count',
#  'cov',
#  'cumcount',
#  'cummax',
#  'cummin',
#  'cumprod',
#  'cumsum',
#  'delivery',
#  'describe',
#  'diff',
#  'dtypes',
#  'expanding',
#  'ffill',
#  'fillna',
#  'filter',
#  'first',
#  'full_address',
#  'get_group',
#  'groups',
#  'head',
#  'hist',
#  'hours',
#  'idxmax',
#  'idxmin',
#  'indices',
#  'last',
#  'latitude',
#  'longitude',
#  'mad',
#  'max',
#  'mean',
#  'median',
#  'min',
#  'name',
#  'ndim',
#  'neighborhoods',
#  'ngroup',
#  'ngroups',
#  'nth',
#  'nunique',
#  'ohlc',
#  'open',
#  'pad',
#  'pct_change',
#  'pipe',
#  'plot',
#  'prod',
#  'quantile',
#  'rank',
#  'resample',
#  'review_count',
#  'rolling',
#  'sem',
#  'shift',
#  'size',
#  'skew',
#  'stars',
#  'state',
#  'std',
#  'sum',
#  'tail',
#  'take',
#  'transform',
#  'tshift',
#  'type',
#  'var']

# %%
print(type(by_city.groups))
list(by_city.groups.items())[:5]
# Out:
# <class 'dict'>
# [('Ahwatukee',
#   Int64Index([1718, 1740, 13572, 17787, 20361, 22856, 28608, 30499], dtype='int64')),
#  ('Anthem',
#   Int64Index([ 1946,  1948,  1949,  1950,  1951,  1952,  1953,  1954,  1955,
#                1956,  1957,  1958,  1961,  1962, 11455, 12008, 12572, 12870,
#               13007, 13069, 13286, 13500, 13636, 13703, 13744, 13827, 13935,
#               15483, 15581, 15756, 19358, 21295, 21303, 21327, 22354, 22428,
#               22654, 22782, 23215, 24937, 25026, 26116, 26300, 26331, 26841,
#               26937, 30039, 30170, 31565, 32525, 33027, 33492, 33983, 34663,
#               35433],
#              dtype='int64')),
#  ('Apache Junction',
#   Int64Index([ 2392,  2393,  2394,  2395,  2396,  2397,  2398,  2399,  2400,
#                2401,  2402,  2403,  2404,  2406,  2407,  2408,  2409,  2410,
#                2412,  2413,  2414,  2415,  2417,  2418,  2419,  7305,  7524,
#                7525,  7528,  7529,  7530,  7531,  7532,  7533,  7534, 10813,
#               11315, 11660, 12662, 12858, 12893, 13021, 13107, 13367, 13534,
#               13871, 15645, 17769, 19447, 19682, 19695, 20030, 20977, 21940,
#               22571, 22750, 22884, 23175, 23226, 23429, 25839, 26064, 26169,
#               26582, 27131, 27594, 27901, 28112, 28124, 29329, 30062, 30753,
#               30810, 30850, 31841, 33347, 33378, 34415, 34558, 36436],
#              dtype='int64')),
#  ('Arcadia', Int64Index([20625], dtype='int64')),
#  ('Atlanta', Int64Index([16976], dtype='int64'))]

# %%
by_city.get_group('Anthem').max()
# Out:
# latitude         33.875410
# longitude      -112.072772
# open              1.000000
# review_count     74.000000
# stars             5.000000
# dtype: float64

# %% [markdown]
# When we use `groupby` on a column, Pandas builds a `dict`, using the unique elements of the column as the keys and the index of the rows in each group as the values. This `dict` is stored in the `groups` attribute. Pandas can then use this `dict` to direct the application of aggregating functions over the different groups.

# %% [markdown]
# ## Sorting
#
# Even though the DataFrame in many ways behaves similarly to a `dict`, it also is ordered. Therefore we can sort the data in it. Pandas provides two sorting methods, `sort_values` and `sort_index`.

# %%
yelp_df.sort_values('stars').tail()
# Out:
#                                              attributes  \
# 31223                    {'Accepts Credit Cards': True}
# 19219                     {'By Appointment Only': True}
# 31218                    {'Accepts Credit Cards': True}
# 30878  {'Accepts Credit Cards': True, 'Price Range': 1}
# 26769                                                {}
#
#                   business_id  \
# 31223  tAdd__IgXQEknDDicEbRgQ
# 19219  Gm4VcVAw2NwqCf94LZQrBw
# 31218  Hs5ucqGY-IzV4wIYYe_f5Q
# 30878  DExGDWV6wZbhB4t-tYoRhQ
# 26769  4kV8BO6FHQTrxf9txJBt-Q
#
#                                               categories        city  \
# 31223                  [Security Systems, Home Services]     Phoenix
# 19219  [Acupuncture, Traditional Chinese Medicine, He...  Scottsdale
# 31218                     [Local Services, Pest Control]     Buckeye
# 30878            [Food, Specialty Food, Seafood Markets]   Henderson
# 26769                          [Auto Repair, Automotive]     Phoenix
#
#                                       full_address  \
# 31223              125 N 2nd St\nPhoenix, AZ 85004
# 19219    7520 E Camelback Rd\nScottsdale, AZ 85251
# 31218        13801 S Tuthill Rd\nBuckeye, AZ 85326
# 30878  1647 W Warm Springs Rd\nHenderson, NV 89014
# 26769          3039 E Thomas Rd\nPhoenix, AZ 85008
#
#                                                    hours   latitude  \
# 31223  {'Monday': {'close': '18:00', 'open': '08:00'}...  33.449608
# 19219  {'Monday': {'close': '15:00', 'open': '08:00'}...  33.502447
# 31218  {'Monday': {'close': '19:00', 'open': '07:00'}...  33.321826
# 30878                                                 {}  36.055821
# 26769  {'Tuesday': {'close': '17:30', 'open': '07:30'...  33.480352
#
#         longitude                              name neighborhoods   open  \
# 31223 -112.071045  JPG Home Security and Consulting            []   True
# 19219 -111.919380         ilumina Healing Sanctuary            []   True
# 31218 -112.487044               Hopper Pest Control            []   True
# 30878 -115.055915               Hawaiian Style Poke            []  False
# 26769 -112.015407                D & W Auto Service            []   True
#
#        review_count  stars state      type delivery
# 31223            63    5.0    AZ  business     None
# 19219            12    5.0    AZ  business     None
# 31218             6    5.0    AZ  business     None
# 30878             3    5.0    NV  business     None
# 26769            20    5.0    AZ  business     None

# %%
yelp_df[yelp_df['stars'] == 5 ]
# Out:
#                                               attributes  \
# 10     {'Accepts Credit Cards': True, 'Wi-Fi': 'free'...
# 20     {'By Appointment Only': False, 'Good for Kids'...
# 30                                                    {}
# 36                                                    {}
# 47                                                    {}
# 51                                                    {}
# 52                                                    {}
# 77                                     {'Wi-Fi': 'free'}
# 87     {'Parking': {'garage': False, 'street': False,...
# 91                                                    {}
# 104    {'Parking': {'garage': False, 'street': False,...
# 110    {'Price Range': 1, 'Hair Types Specialized In'...
# 123                                                   {}
# 173    {'Parking': {'garage': False, 'street': False,...
# 206                                                   {}
# 214                                                   {}
# 219                                                   {}
# 223    {'Parking': {'garage': False, 'street': False,...
# 225                                                   {}
# 232                                                   {}
# 246                                                   {}
# 263    {'By Appointment Only': True, 'Accepts Credit ...
# 280    {'Accepts Credit Cards': True, 'Wheelchair Acc...
# 284    {'Parking': {'garage': False, 'street': False,...
# 310    {'Parking': {'garage': False, 'street': False,...
# 311    {'By Appointment Only': False, 'Parking': {'ga...
# 313                                                   {}
# 318    {'By Appointment Only': False, 'Parking': {'ga...
# 358                                                   {}
# 444    {'Parking': {'garage': False, 'street': False,...
# ...                                                  ...
# 37854                                                 {}
# 37865                     {'Accepts Credit Cards': True}
# 37866  {'Alcohol': 'full_bar', 'Good For Dancing': Fa...
# 37869  {'Accepts Credit Cards': True, 'Good for Kids'...
# 37871  {'By Appointment Only': True, 'Parking': {'gar...
# 37873   {'Accepts Credit Cards': True, 'Price Range': 1}
# 37875  {'By Appointment Only': False, 'Parking': {'ga...
# 37877                            {'Good for Kids': True}
# 37881  {'Take-out': True, 'Takes Reservations': True,...
# 37887  {'Parking': {'garage': False, 'street': False,...
# 37890                     {'Accepts Credit Cards': True}
# 37891                            {'Good for Kids': True}
# 37893                                                 {}
# 37894                            {'Good for Kids': True}
# 37896  {'Alcohol': 'full_bar', 'Caters': True, 'Noise...
# 37899  {'By Appointment Only': False, 'Parking': {'ga...
# 37903  {'Parking': {'garage': False, 'street': False,...
# 37904  {'Coat Check': False, 'Take-out': True, 'Good ...
# 37907                            {'Good for Kids': True}
# 37910   {'Accepts Credit Cards': True, 'Price Range': 2}
# 37912                                                 {}
# 37917  {'Take-out': True, 'Wi-Fi': 'free', 'Good For'...
# 37918                     {'Accepts Credit Cards': True}
# 37920                     {'Accepts Credit Cards': True}
# 37921  {'Parking': {'garage': False, 'street': False,...
# 37925   {'Accepts Credit Cards': True, 'Price Range': 2}
# 37933  {'Alcohol': 'none', 'Good For Dancing': True, ...
# 37934                                                 {}
# 37935                           {'Good for Kids': False}
# 37936  {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...
#
#                   business_id  \
# 10     XrzTVrJAjs0yYLvhFI9vkQ
# 20     x7xS2DJvu8klyNzcpN8QHg
# 30     NGj-_5pkHc_DbH5bKUH2Xw
# 36     9874O-3GjXPotxYKNNAz5Q
# 47     elBgDynz6UPoSqQgxiggJw
# 51     LOp0ciu7XhZwTqZUWG8qCw
# 52     O16EckCLtNoA49hewGht_w
# 77     xLmC8OBxrfPkJCC1HzeNhg
# 87     O9j6UX2LHdszkExzJ-v-BA
# 91     AnNk4SGK3bKtnvrOajhpug
# 104    NxxplxNZnrNEYXHTgv9h8g
# 110    T9l9Z3FKMSCIYvsP2g4efw
# 123    V5S43vHLhHxKCb06Jwa3vw
# 173    FrT0OQFkUZBtfoW3V1Wpfw
# 206    vP7-03_-_NoNfwfeYADDPA
# 214    jm3K37BEkL8-a_aytbCXvA
# 219    UWyW-lyljb_SrCnSEuugUQ
# 223    acnZqXktCu7_x2c4i3tMsw
# 225    IlE4UouTsBEGiJ_bNrb5ug
# 232    BB4Oz3qBqihEvgZAoaTeIA
# 246    xod-YOn69KMhUHBkd6boOQ
# 263    p96EgQMm-31P1FecUtE8TA
# 280    yg-a8RuKe-_uiPyrwmGogA
# 284    zzhSCOVTZ7MUKOAfwT-Bsw
# 310    icFE83PXkjKBma3azYqanw
# 311    M2tiVOrtmsfi89C5WXtYjg
# 313    545sP7uSdCcKDZ-reeVOgQ
# 318    YLyEGXEgh1qh8y4kWEsddw
# 358    lW8-lFQ-mwG-Wl6iUKoT6g
# 280                                 [Food, Coffee & Tea]      Madison
# 284     [Shopping, Nurseries & Gardening, Home & Garden]      Madison
# 310    [Food, Specialty Food, Fruits & Veggies, Ethni...      Phoenix
# 311                         [Shopping, Jewelry, Watches]      Phoenix
# 313                  [Churches, Religious Organizations]      Phoenix
# 318                                  [Shopping, Jewelry]      Phoenix
# 358                         [Mass Media, Radio Stations]      Phoenix
# 444        [Arts & Crafts, Uniforms, Shopping, Costumes]      Phoenix
# ...                                                  ...          ...
# 37854     [Mortgage Brokers, Home Services, Real Estate]     Chandler
# 37865                          [Plumbing, Home Services]    Las Vegas
# 37866      [Pubs, Bars, Sports Bars, Lounges, Nightlife]    Las Vegas
# 37869  [Active Life, Amusement Parks, Playgrounds, Ki...    Henderson
# 37871  [Hair Salons, Hair Extensions, Blow Dry/Out Se...    Las Vegas
# 37873                                [Food, Food Trucks]    Las Vegas
# 37875  [Day Spas, Waxing, Nail Salons, Hair Removal, ...       Peoria
# 37877  [Active Life, Gyms, Trainers, Fitness & Instru...   Scottsdale
# 37881                               [Pizza, Restaurants]    Las Vegas
# 37887                             [Shopping, Vape Shops]    Las Vegas
# 37890  [Web Design, Marketing, Advertising, Professio...   Scottsdale
# 37891                        [Yelp Events, Local Flavor]      Phoenix
# 37893  [Professional Services, Security Services, Pri...        Tempe
# 37894  [Active Life, Martial Arts, Yoga, Kids Activit...    Las Vegas
# 37896                    [Seafood, Restaurants, Italian]    Las Vegas
# 37899  [Shopping, Cosmetics & Beauty Supply, Beauty &...    Las Vegas
# 37903                   [Food, Specialty Food, Desserts]    Las Vegas
# 37904  [Bars, Restaurants, Wine Bars, Nightlife, Amer...      Phoenix
# 37907                        [Yelp Events, Local Flavor]   Scottsdale
# 37910        [Shopping, Home & Garden, Furniture Stores]      Gilbert
# 37912            [Arts & Entertainment, Performing Arts]    Las Vegas
# 37917                               [Cafes, Restaurants]  Queen Creek
# 37918                            [Movers, Home Services]      Phoenix
# 37920                          [Handyman, Home Services]  Queen Creek
# 37921                                 [Food, Shaved Ice]     Avondale
# 37925               [Food, Desserts, Cupcakes, Bakeries]    Las Vegas
# 37933            [Bars, Hookah Bars, Nightlife, Lounges]     Glendale
# 37934  [Active Life, Barre Classes, Pilates, Fitness ...      Madison
# 37935                        [Yelp Events, Local Flavor]      Phoenix
# 37936              [Kosher, Italian, Pizza, Restaurants]      Phoenix
#
#                                             full_address  \
# 10               5508 Broadhead St\nMc Farland, WI 53558
# 20                  2529 Allen Blvd\nMiddleton, WI 53562
# 30                2313 Parmenter St\nMiddleton, WI 53562
# 36                 1009 N Gammon Rd\nMiddleton, WI 53562
# 47            3201 Glacier Ridge Rd\nMiddleton, WI 53562
# 51                    2229 Eagle Dr\nMiddleton, WI 53562
# 52              6516 University Ave\nMiddleton, WI 53562
# 77               1350 Linnerud Dr\nSun Prairie, WI 53590
# 87             351 E Main St Frnt\nSun Prairie, WI 53590
# 91               868 Progress Way\nSun Prairie, WI 53590
# 104         4120 Monona Dr\nLake Edge\nMadison, WI 53716
# 37921 -112.336565                           Zoni Shave Ice
# 37925 -115.099975                                 Bakeshop
# 37933 -112.152529                             The V Lounge
# 37934  -89.382842                          Pilates Central
# 37935 -112.071074    Yelp's Secret Cinema: Made In Arizona
# 37936 -112.064508          LaBella Pizzeria and Restaurant
#
#                     neighborhoods   open  review_count  stars state      type  \
# 10                             []   True             9    5.0    WI  business
# 20                             []   True             5    5.0    WI  business
# 30                             []   True             3    5.0    WI  business
# 36                             []   True             5    5.0    WI  business
# 47                             []   True             3    5.0    WI  business
# 51                             []   True             3    5.0    WI  business
# 52                             []   True             3    5.0    WI  business
# 77                             []   True             5    5.0    WI  business
# 87                             []   True             4    5.0    WI  business
# 91                             []   True             3    5.0    WI  business
# 104                   [Lake Edge]  False             3    5.0    WI  business
# 110        [Starkweather - Yahar]   True             7    5.0    WI  business
# 123          [Carpenter-Ridgeway]   True             5    5.0    WI  business
# 173                            []   True            14    5.0    WI  business
# 206          [Carpenter-Ridgeway]   True             5    5.0    WI  business
# 214                            []   True            14    5.0    WI  business
# 219             [Rolling Meadows]   True             3    5.0    WI  business
# 223                 [Eastmorland]   True             4    5.0    WI  business
# 225            [Worthington Park]   True            10    5.0    WI  business
# 232                 [Eastmorland]   True             3    5.0    WI  business
# 246                            []   True             6    5.0    WI  business
# 263                   [Lake Edge]  False             3    5.0    WI  business
# 280                            []   True             6    5.0    WI  business
# 284                            []   True             4    5.0    WI  business
# 310                            []   True             4    5.0    AZ  business
# 311                            []   True             6    5.0    AZ  business
# 313                            []   True            13    5.0    AZ  business
# 318                            []   True             5    5.0    AZ  business
# 358                            []   True             4    5.0    AZ  business
# 444                            []   True             4    5.0    AZ  business
# ...                           ...    ...           ...    ...   ...       ...
# 37854                          []   True             5    5.0    AZ  business
# 37865  [Southwest, Spring Valley]   True             5    5.0    NV  business
# 37866                  [Westside]   True            16    5.0    NV  business
# 37869                          []   True             9    5.0    NV  business
# 37871  [Southwest, Spring Valley]   True             3    5.0    NV  business
# 37873                  [Westside]   True             3    5.0    NV  business
# 37875                          []   True             3    5.0    AZ  business
# 37877                          []   True             6    5.0    AZ  business
# 37881             [Spring Valley]   True             7    5.0    NV  business
# 37887                 [Chinatown]   True             9    5.0    NV  business
# 37890                          []   True             6    5.0    AZ  business
# 37891                          []   True            29    5.0    AZ  business
# 37893                          []   True             4    5.0    AZ  business
# 37894                  [Westside]   True             9    5.0    NV  business
# 37896     [Northwest, Centennial]   True             5    5.0    NV  business
# 37899                          []   True             3    5.0    NV  business
# 37903                [Centennial]   True            15    5.0    NV  business
# 37904                          []   True            11    5.0    AZ  business
# 37907                          []   True            25    5.0    AZ  business
# 37910                          []   True             4    5.0    AZ  business
# 37912           [South Summerlin]   True             5    5.0    NV  business
# 37917                          []   True             5    5.0    AZ  business
# 37918                          []   True             8    5.0    AZ  business
# 37920                          []   True             3    5.0    AZ  business
# 37921                          []   True             5    5.0    AZ  business
# 37925                 [Southeast]   True             4    5.0    NV  business
# 37933                          []   True             4    5.0    AZ  business
# 37934                   [Capitol]   True             3    5.0    WI  business
# 37935                          []   True            17    5.0    AZ  business
# 37936                          []   True             5    5.0    AZ  business
#
#       delivery
# 10        None
# 20        None
# 30        None
# 36        None
# 47        None
# 51        None
# 52        None
# 77        None
# 87        None
# 91        None
# 104       None
# 110       None
# 123       None
# 173       None
# 206       None
# 214       None
# 219       None
# 223       None
# 225       None
# 232       None
# 246       None
# 263       None
# 280       None
# 284       None
# 310       None
# 311       None
# 313       None
# 318       None
# 358       None
# 444       None
# ...        ...
# 37854     None
# 37865     None
# 37866     None
# 37869     None
# 37871     None
# 37873     None
# 37875     None
# 37877     None
# 37881     True
# 37887     None
# 37890     None
# 37891     None
# 37893     None
# 37894     None
# 37896     None
# 37899     None
# 37903     None
# 37904    False
# 37907     None
# 37910     None
# 37912     None
# 37917    False
# 37918     None
# 37920     None
# 37921     None
# 37925     None
# 37933     None
# 37934     None
# 37935     None
# 37936     True
#
# [4595 rows x 16 columns]

# %%
# sort cities by the nunber of stars, and get the max

city_stars = yelp_df[yelp_df['stars'] == 5 ]
city_stars.groupby('city').agg({'stars' :'max'})[:4]
# Out:
#                  stars
# city
# Ahwatukee          5.0
# Anthem             5.0
# Apache Junction    5.0
# Arcadia            5.0

# %%
yelp_df.set_index('stars').sort_index().head()
# Out:
#       attributes             business_id  \
# stars
# 1.0           {}  2Q2tZ0yQo25cni0PT2j0Zw
# 1.0           {}  cHvL85QIV-L2-YlLOcwlCw
# 1.0           {}  e23Sa3FCTaIOSZzJsT8sIQ
# 1.0           {}  fZO5Fghc6Q07jU8EROzj6Q
# 1.0           {}  JjdjS5n6ILh-d3GeTD6qkA
#
#                                               categories        city  \
# stars
# 1.0    [Real Estate Services, Property Management, Ho...   Las Vegas
# 1.0    [Sporting Goods, Shopping, Golf Equipment, Out...       Tempe
# 1.0    [Professional Services, Internet Service Provi...  Scottsdale
# 1.0                       [Home Services, Pool Cleaners]        Mesa
# 1.0                 [Hotels & Travel, Motorcycle Rental]  Scottsdale
#
#                                             full_address  \
# stars
# 1.0    6420 Spring Mountain Rd\nChinatown\nLas Vegas,...
# 1.0           5235 S Kyrene Rd\nSte 106\nTempe, AZ 85283
# 1.0         3949 N Drinkwater Blvd\nScottsdale, AZ 85251
# 1.0                     2431 E Laurel St\nMesa, AZ 85213
# 1.0        15820 N 84th St\nSte 25\nScottsdale, AZ 85260
#
#                                                    hours   latitude  \
# stars
# 1.0                                                   {}  36.125870
# 1.0    {'Monday': {'close': '18:00', 'open': '10:00'}...  33.376734
# 1.0                                                   {}  33.493469
# 1.0                                                   {}  33.457833
# 1.0    {'Monday': {'close': '17:00', 'open': '09:00'}...  33.629858
#
#         longitude                            name neighborhoods  open  \
# stars
# 1.0   -115.232316     Total Real Eatate of Nevada   [Chinatown]  True
# 1.0   -111.945955              Custom Golf Center            []  True
# 1.0   -111.921620                       Cox Cable            []  True
# 1.0   -111.778212  Foster's Pool Service & Repair            []  True
# 1.0   -111.900187               Top Spoke Rentals            []  True
#
#        review_count state      type delivery
# stars
# 1.0               3    NV  business     None
# 1.0               3    AZ  business     None
# 1.0               3    AZ  business     None
# 1.0               6    AZ  business     None
# 1.0               3    AZ  business     None

# %%
yelp_df['stars'].head()
# Out:
# 0    3.5
# 1    4.0
# 2    4.0
# 3    4.5
# 4    4.0
# Name: stars, dtype: float64

# %% [markdown]
# Don't forget that most Pandas operations return a copy of the DataFrame, and do not update the DataFrame in place (unless we tell it to)!

# %% [markdown]
# ## Joining data sets

# %% [markdown]
# Often we will want to augment one data set with data from another. For instance, businesses in big cities probably get more reviews than those in small cities. It could be useful to scale the review counts by the city's population. To do that, we'll need to add population data to the Yelp data. We can get population data from the US census.

# %%
census = pd.read_csv('./data/PEP_2016_PEPANNRES.csv', skiprows=[1])

census
# Out:
#                     GEO.id     GEO.id2  \
# 0      0610000US0900104720   900104720
# 1      0610000US0900108070   900108070
# 2      0610000US0900108980   900108980
# 3      0610000US0900118500   900118500
# 4      0610000US0900118850   900118850
# 5      0610000US0900123890   900123890
# 6      0610000US0900126620   900126620
# 7      0610000US0900133620   900133620
# 8      0610000US0900148620   900148620
# 9      0610000US0900150580   900150580
# 10     0610000US0900150860   900150860
# 11     0610000US0900152980   900152980
# 12     0610000US0900156060   900156060
# 13     0610000US0900163480   900163480
# 14     0610000US0900163970   900163970
# 15     0610000US0900168170   900168170
# 16     0610000US0900168310   900168310
# 17     0610000US0900173070   900173070
# 18     0610000US0900174190   900174190
# 19     0610000US0900177200   900177200
# 20     0610000US0900183430   900183430
# 21     0610000US0900183500   900183500
# 22     0610000US0900186370   900186370
# 23     0610000US0900302060   900302060
# 24     0610000US0900304300   900304300
# 25     0610000US0900305910   900305910
# 26     0610000US0900308490   900308490
# 27     0610000US0900310100   900310100
# 28     0610000US0900312270   900312270
# 29     0610000US0900322070   900322070
# ...                    ...         ...
# 21113  0610000US5514107650  5514107650
# 21114  0610000US5514112275  5514112275
# 21115  0610000US5514112775  5514112775
# 21116  0610000US5514117525  5514117525
# 21117  0610000US5514120075  5514120075
# 21118  0610000US5514130125  5514130125
# 21119  0610000US5514132575  5514132575
# 21120  0610000US5514134250  5514134250
# 21121  0610000US5514134675  5514134675
# 21122  0610000US5514144550  5514144550
# 21123  0610000US5514149675  5514149675
# 21124  0610000US5514149700  5514149700
# 21125  0610000US5514151875  5514151875
# 21126  0610000US5514151900  5514151900
# 21127  0610000US5514155875  5514155875
# 21128  0610000US5514163100  5514163100
# 21129  0610000US5514164175  5514164175
# 21130  0610000US5514164200  5514164200
# 21131  0610000US5514167000  5514167000
# 21132  0610000US5514167500  5514167500
# 21133  0610000US5514168625  5514168625
# 21134  0610000US5514170000  5514170000
# 21135  0610000US5514170025  5514170025
# 21136  0610000US5514171600  5514171600
# 21137  0610000US5514172575  5514172575
# 21138  0610000US5514173475  5514173475
# 21139  0610000US5514173900  5514173900
# 21140  0610000US5514182650  5514182650
# 21141  0610000US5514188200  5514188200
# 21142  0610000US5514188575  5514188575
#
#                                        GEO.display-label  rescen42010  \
# 0             Bethel town, Fairfield County, Connecticut      18584.0
# 1         Bridgeport town, Fairfield County, Connecticut     144229.0
# 21           27501        27803        27840
# 22           18648        18660        18560
# 23           18400        18373        18364
# 24           20589        20535        20499
# 25           20783        20707        20642
# 26           60490        60396        60147
# 27            9566         9611         9614
# 28           10335        10318        10287
# 29            5207         5193         5170
# ...            ...          ...          ...
# 21113          808          800          792
# 21114          490          485          480
# 21115          413          408          403
# 21116          164          165          163
# 21117          351          347          347
# 21118         7511         7479         7427
# 21119          663          660          653
# 21120          820          813          807
# 21121          166          167          165
# 21122         1563         1558         1548
# 21123        17786        17705        17591
# 21124          792          789          782
# 21125          276          274          272
# 21126          670          668          662
# 21127         2494         2469         2443
# 21128          854          848          839
# 21129         1749         1737         1750
# 21130         1379         1369         1355
# 21131          255          252          249
# 21132         1600         1587         1589
# 21133         1263         1440         1593
# 21134          432          431          430
# 21135          997          994          992
# 21136         5042         5013         4976
# 21137         1094         1083         1072
# 21138          800          798          789
# 21139         1031         1028         1021
# 21140          565          558          554
# 21141        17958        17862        17887
# 21142          769          765          759
#
# [21143 rows x 12 columns]

# %%
# construct city & state fields
census['city'] = census['GEO.display-label'].apply(lambda x: x.split(', ')[0])
census['state'] = census['GEO.display-label'].apply(lambda x: x.split(', ')[2])
census
# Out:
#                     GEO.id     GEO.id2  \
# 0      0610000US0900104720   900104720
# 1      0610000US0900108070   900108070
# 2      0610000US0900108980   900108980
# 3      0610000US0900118500   900118500
# 4      0610000US0900118850   900118850
# 5      0610000US0900123890   900123890
# 6      0610000US0900126620   900126620
# 7      0610000US0900133620   900133620
# 8      0610000US0900148620   900148620
# 9      0610000US0900150580   900150580
# 10     0610000US0900150860   900150860
# 11     0610000US0900152980   900152980
# 12     0610000US0900156060   900156060
# 13     0610000US0900163480   900163480
# 14     0610000US0900163970   900163970
# 15     0610000US0900168170   900168170
# 16     0610000US0900168310   900168310
# 17     0610000US0900173070   900173070
# 18     0610000US0900174190   900174190
# 19     0610000US0900177200   900177200
# 20     0610000US0900183430   900183430
# 21     0610000US0900183500   900183500
# 22     0610000US0900186370   900186370
# 23     0610000US0900302060   900302060
# 24     0610000US0900304300   900304300
# 25     0610000US0900305910   900305910
# 26     0610000US0900308490   900308490
# 27     0610000US0900310100   900310100
# 28     0610000US0900312270   900312270
# 29     0610000US0900322070   900322070
# ...                    ...         ...
# 21113  0610000US5514107650  5514107650
# 21114  0610000US5514112275  5514112275
# 21115  0610000US5514112775  5514112775
# 21116  0610000US5514117525  5514117525
# 21117  0610000US5514120075  5514120075
# 21118  0610000US5514130125  5514130125
# 21119  0610000US5514132575  5514132575
# 21120  0610000US5514134250  5514134250
# 21121  0610000US5514134675  5514134675
# 21122  0610000US5514144550  5514144550
# 21123  0610000US5514149675  5514149675
# 21124  0610000US5514149700  5514149700
# 21125  0610000US5514151875  5514151875
# 21126  0610000US5514151900  5514151900
# 21127  0610000US5514155875  5514155875
# 21128  0610000US5514163100  5514163100
# 21129  0610000US5514164175  5514164175
# 21130  0610000US5514164200  5514164200
# 21131  0610000US5514167000  5514167000
# 21132  0610000US5514167500  5514167500
# 21133  0610000US5514168625  5514168625
# 21120    Wisconsin
# 21121    Wisconsin
# 21122    Wisconsin
# 21123    Wisconsin
# 21124    Wisconsin
# 21125    Wisconsin
# 21126    Wisconsin
# 21127    Wisconsin
# 21128    Wisconsin
# 21129    Wisconsin
# 21130    Wisconsin
# 21131    Wisconsin
# 21132    Wisconsin
# 21133    Wisconsin
# 21134    Wisconsin
# 21135    Wisconsin
# 21136    Wisconsin
# 21137    Wisconsin
# 21138    Wisconsin
# 21139    Wisconsin
# 21140    Wisconsin
# 21141    Wisconsin
# 21142    Wisconsin
#
# [21143 rows x 14 columns]

# %%
# convert state names to abbreviations

print(census['state'].unique())
# Out:
# ['Connecticut' 'Illinois' 'Indiana' 'Kansas' 'Maine' 'Massachusetts'
#  'Michigan' 'Minnesota' 'Missouri' 'Nebraska' 'New Hampshire' 'New Jersey'
#  'New York' 'North Dakota' 'Ohio' 'Pennsylvania' 'Rhode Island'
#  'South Dakota' 'Vermont' 'Wisconsin']

# %%
state_abbr = dict(zip(census['state'].unique(), ['CT', 'IL', 'IN', 'KS', 'ME', 'MA', 'MI', 'MN', 'MO', 'NE', 'NH', 'NJ', 'NY', 'ND', 'OH', 'PA', 'RI', 'SD', 'VT', 'WI']))
state_abbr
# Out:
# {'Connecticut': 'CT',
#  'Illinois': 'IL',
#  'Indiana': 'IN',
#  'Kansas': 'KS',
#  'Maine': 'ME',
#  'Massachusetts': 'MA',
#  'Michigan': 'MI',
#  'Minnesota': 'MN',
#  'Missouri': 'MO',
#  'Nebraska': 'NE',
#  'New Hampshire': 'NH',
#  'New Jersey': 'NJ',
#  'New York': 'NY',
#  'North Dakota': 'ND',
#  'Ohio': 'OH',
#  'Pennsylvania': 'PA',
#  'Rhode Island': 'RI',
#  'South Dakota': 'SD',
#  'Vermont': 'VT',
#  'Wisconsin': 'WI'}

# %%
census['state'] = census['state'].replace(state_abbr)
census
# Out:
#                     GEO.id     GEO.id2  \
# 0      0610000US0900104720   900104720
# 1      0610000US0900108070   900108070
# 2      0610000US0900108980   900108980
# 3      0610000US0900118500   900118500
# 4      0610000US0900118850   900118850
# 5      0610000US0900123890   900123890
# 6      0610000US0900126620   900126620
# 7      0610000US0900133620   900133620
# 8      0610000US0900148620   900148620
# 9      0610000US0900150580   900150580
# 10     0610000US0900150860   900150860
# 11     0610000US0900152980   900152980
# 12     0610000US0900156060   900156060
# 13     0610000US0900163480   900163480
# 14     0610000US0900163970   900163970
# 15     0610000US0900168170   900168170
# 16     0610000US0900168310   900168310
# 17     0610000US0900173070   900173070
# 18     0610000US0900174190   900174190
# 19     0610000US0900177200   900177200
# 20     0610000US0900183430   900183430
# 21     0610000US0900183500   900183500
# 22     0610000US0900186370   900186370
# 23     0610000US0900302060   900302060
# 24     0610000US0900304300   900304300
# 25     0610000US0900305910   900305910
# 26     0610000US0900308490   900308490
# 27     0610000US0900310100   900310100
# 28     0610000US0900312270   900312270
# 29     0610000US0900322070   900322070
# ...                    ...         ...
# 21113  0610000US5514107650  5514107650
# 21114  0610000US5514112275  5514112275
# 21115  0610000US5514112775  5514112775
# 21116  0610000US5514117525  5514117525
# 21117  0610000US5514120075  5514120075
# 21118  0610000US5514130125  5514130125
# 21119  0610000US5514132575  5514132575
# 21120  0610000US5514134250  5514134250
# 21121  0610000US5514134675  5514134675
# 21133           855          884          956         1010         1119
# 21134           439          439          438          436          435
# 21135          1028         1028         1025         1018         1008
# 21136          5142         5143         5120         5103         5091
# 21137          1120         1120         1119         1117         1106
# 21138           803          803          815          817          811
# 21139          1051         1051         1048         1043         1038
# 21140           584          584          580          575          571
# 21141         18385        18376        18315        18201        18037
# 21142           796          796          791          788          779
#
#        respop72014  respop72015  respop72016              city state
# 0            19316        19463        19627            Bethel    CT
# 1           147560       147090       145936        Bridgeport    CT
# 2            17016        17087        17098        Brookfield    CT
# 3            83687        84236        84992           Danbury    CT
# 4            21641        21718        21744            Darien    CT
# 5             7615         7601         7561            Easton    CT
# 6            61280        61318        61160         Fairfield    CT
# 7            62464        62484        62359         Greenwich    CT
# 8            19823        19771        19658            Monroe    CT
# 9            20270        20318        20280        New Canaan    CT
# 10           14107        14071        14005     New Fairfield    CT
# 11           27957        27935        27865           Newtown    CT
# 12           87971        88216        88438           Norwalk    CT
# 13            9283         9269         9216           Redding    CT
# 14           25139        25165        25063        Ridgefield    CT
# 15           41186        41144        41334           Shelton    CT
# 16            3663         3656         3641           Sherman    CT
# 17          127955       128412       129113          Stamford    CT
# 18           52613        52444        52148         Stratford    CT
# 19           36626        36459        36237          Trumbull    CT
# 20           10365        10354        10302            Weston    CT
# 21           27501        27803        27840          Westport    CT
# 22           18648        18660        18560            Wilton    CT
# 23           18400        18373        18364              Avon    CT
# 24           20589        20535        20499            Berlin    CT
# 25           20783        20707        20642        Bloomfield    CT
# 26           60490        60396        60147           Bristol    CT
# 27            9566         9611         9614        Burlington    CT
# 28           10335        10318        10287            Canton    CT
# 29            5207         5193         5170       East Granby    CT
# ...            ...          ...          ...               ...   ...
# 21113          808          800          792             Biron    WI
# 21114          490          485          480           Cameron    WI
# 21115          413          408          403              Cary    WI
# 21116          164          165          163          Cranmoor    WI
# 21117          351          347          347            Dexter    WI
# 21118         7511         7479         7427      Grand Rapids    WI
# 21119          663          660          653            Hansen    WI
# 21120          820          813          807            Hewitt    WI
# 21121          166          167          165             Hiles    WI
# 21122         1563         1558         1548           Lincoln    WI
# 21123        17786        17705        17591        Marshfield    WI
# 21124          792          789          782        Marshfield    WI
# 21125          276          274          272         Milladore    WI
# 21126          670          668          662         Milladore    WI
# 21127         2494         2469         2443           Nekoosa    WI
# 21128          854          848          839        Pittsville    WI
# 21129         1749         1737         1750      Port Edwards    WI
# 21130         1379         1369         1355      Port Edwards    WI
# 21131          255          252          249         Remington    WI
# 21132         1600         1587         1589         Richfield    WI
# 21133         1263         1440         1593              Rock    WI
# 21134          432          431          430           Rudolph    WI
# 21135          997          994          992           Rudolph    WI
# 21136         5042         5013         4976          Saratoga    WI
# 21137         1094         1083         1072            Seneca    WI
# 21138          800          798          789            Sherry    WI
# 21139         1031         1028         1021             Sigel    WI
# 21140          565          558          554            Vesper    WI
# 21141        17958        17862        17887  Wisconsin Rapids    WI
# 21142          769          765          759              Wood    WI
#
# [21143 rows x 14 columns]

# %%
# remove last word (e.g. 'city', 'town', township', 'borough', 'village') from city names

census['city'] = census['city'].apply(lambda x: ' '.join(x.split(' ')[:-1]))

# %%
merged_df = yelp_df.merge(census, on=['state', 'city'])
merged_df.head()
# Out:
#                                           attributes             business_id  \
# 0  {'Take-out': True, 'Caters': True, 'Attire': '...  HxPpZSY6Q1eARuiahhra6A
# 1  {'Take-out': True, 'Caters': True, 'Attire': '...  HxPpZSY6Q1eARuiahhra6A
# 2  {'Take-out': True, 'Good For': {'dessert': Fal...  SKLw05kEIlZcpTD5pqma8Q
# 3  {'Take-out': True, 'Good For': {'dessert': Fal...  SKLw05kEIlZcpTD5pqma8Q
# 4  {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...  77ESrCo7hQ96VpCWWdvoxg
#
#                                           categories       city  \
# 0  [Event Planning & Services, Party & Event Plan...  Middleton
# 1  [Event Planning & Services, Party & Event Plan...  Middleton
# 2  [Party & Event Planning, Asian Fusion, Event P...  Middleton
# 3  [Party & Event Planning, Asian Fusion, Event P...  Middleton
# 4                             [Mexican, Restaurants]  Middleton
#
#                                full_address  \
# 0  6401 University Ave\nMiddleton, WI 53562
# 1  6401 University Ave\nMiddleton, WI 53562
# 2      2039 Allen Blvd\nMiddleton, WI 53562
# 3      2039 Allen Blvd\nMiddleton, WI 53562
# 4  6230 University Ave\nMiddleton, WI 53562
#
#                                                hours   latitude  longitude  \
# 0                                                 {}  43.093265 -89.491800
# 1                                                 {}  43.093265 -89.491800
# 2  {'Monday': {'close': '14:00', 'open': '11:00'}...  43.090642 -89.485169
# 3  {'Monday': {'close': '14:00', 'open': '11:00'}...  43.090642 -89.485169
# 4  {'Monday': {'close': '21:00', 'open': '06:00'}...  43.091061 -89.487487
#
#                                  name neighborhoods  ...  \
# 0       Crandalls Carryout & Catering            []  ...
# 1       Crandalls Carryout & Catering            []  ...
# 2  Imperial Garden Chinese Restaurant            []  ...
# 3  Imperial Garden Chinese Restaurant            []  ...
# 4                           Mi Cocina            []  ...
#
#                         GEO.display-label  rescen42010  resbase42010  \
# 0  Middleton city, Dane County, Wisconsin      17442.0         17558
# 1  Middleton town, Dane County, Wisconsin       5877.0          5831
# 2  Middleton city, Dane County, Wisconsin      17442.0         17558
# 3  Middleton town, Dane County, Wisconsin       5877.0          5831
# 4  Middleton city, Dane County, Wisconsin      17442.0         17558
#
#   respop72010 respop72011 respop72012 respop72013  respop72014 respop72015  \
# 0       17622       17903       18271       18522        18694       18955
# 1        5845        5943        6030        6086         6140        6179
# 2       17622       17903       18271       18522        18694       18955
# 3        5845        5943        6030        6086         6140        6179
# 4       17622       17903       18271       18522        18694       18955
#
#    respop72016
# 0        19109
# 1         6257
# 2        19109
# 3         6257
# 4        19109
#
# [5 rows x 28 columns]

# %% [markdown]
# The `merge` function looks through the `'state'` and `'city'` columns of `yelp_df` and `census` and tries to match up rows that share values. When a match is found, the rows are combined. What happens when a match is not found? We can imagine four scenarios:
#
# 1. We only keep rows from `yelp_df` and `census` if they match. Any rows from either table that have no match are discarded. This is called an _inner join_.
#
# 2. We keep all rows from `yelp_df` and `census`, even if they have no match. In this case, when a row in `yelp_df` has no match in `census`, all the columns from `census` are merged in with null values. When a row in `census` has no match in `yelp_df`, all the columns from `yelp_df` are merged in with null values. This is called an _outer join_.
#
# 3. We privilege the `yelp_df` data. If a row in `yelp_df` has no match in `census`, we keep it and fill in the missing `census` columns as null values. If a row in `census` has no match in `yelp_df`, we discard it. This is called a _left join_.
#
# 4. We privilege the `census` data. This is called a _right join_.
#
# The default behavior for Pandas is case #1, the _inner join_. This means if there are cities in `yelp_df` that we don't have matching `census` data for, they are dropped. Therefore, `merged_df` might be smaller than `yelp_df`.

# %%
print(yelp_df.shape)
print(merged_df.shape)
# Out:
# (37938, 16)
# (3598, 28)

# %% [markdown]
# There are a lot of cities in `yelp_df` that aren't in `census`! We might want to keep these rows, but we don't need any census data where there are no businesses. Then we should use a _left join_.

# %%
merged_df = yelp_df.merge(census, on=['state', 'city'], how='left')
print(yelp_df.shape)
print(merged_df.shape)
# Out:
# (37938, 16)
# (39648, 28)

# %% [markdown]
# Sometimes we don't need to merge together the columns of separate data sets, but just need to add more rows. For example, the New York City subway system [releases data about how many customers enter and exit the station each week](http://web.mta.info/developers/turnstile.html). Each weekly data set has the same columns, so if we want multiple weeks of data, we just have to append one week to another.

# %%
nov18 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_171118.txt')
nov11 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_171111.txt')

# %%
nov18.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  11/11/2017  03:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  11/11/2017  07:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  11/11/2017  11:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  11/11/2017  15:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  11/11/2017  19:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6402636
# 1  REGULAR  6402645
# 2  REGULAR  6402717
# 3  REGULAR  6402857
# 4  REGULAR  6403178
#
#    EXITS
# 0                                            2166100
# 1                                            2166112
# 2                                            2166175
# 3                                            2166230
# 4                                            2166292

# %%
nov11.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  11/04/2017  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  11/04/2017  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  11/04/2017  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  11/04/2017  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  11/04/2017  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6393563
# 1  REGULAR  6393595
# 2  REGULAR  6393616
# 3  REGULAR  6393742
# 4  REGULAR  6394021
#
#    EXITS
# 0                                            2162811
# 1                                            2162822
# 2                                            2162855
# 3                                            2162933
# 4                                            2162992

# %%
nov = pd.concat([nov18, nov11])
nov['DATE'].unique()
# Out:
# array(['11/11/2017', '11/12/2017', '11/13/2017', '11/14/2017',
#        '11/15/2017', '11/16/2017', '11/17/2017', '11/04/2017',
#        '11/05/2017', '11/06/2017', '11/07/2017', '11/08/2017',
#        '11/09/2017', '11/10/2017'], dtype=object)

# %% [markdown]
# We can also use `concat` to perform inner and outer joins based on index. For example, we can perform some data aggregation and then join the results onto the original DataFrame.

# %%
city_counts = yelp_df.groupby('city')['business_id'].count().rename('city_counts')
city_counts.head()
# Out:
# city
# Ahwatukee           8
# Anthem             55
# Apache Junction    80
# Arcadia             1
# Atlanta             1
# Name: city_counts, dtype: int64

# %%
yelp_df.set_index('city')
#yelp_df.reset_index() reset the index
# Out:
#                                                     attributes  \
# city
# Phoenix                          {'By Appointment Only': True}
# De Forest    {'Take-out': True, 'Good For': {'dessert': Fal...
# De Forest    {'Take-out': True, 'Good For': {'dessert': Fal...
# De Forest    {'Take-out': True, 'Wi-Fi': 'free', 'Takes Res...
# De Forest    {'Take-out': True, 'Has TV': False, 'Outdoor S...
# Mc Farland                                                  {}
# Mc Farland                                                  {}
# Mc Farland                                   {'Wi-Fi': 'free'}
# Mc Farland                                                  {}
# Mc Farland   {'Alcohol': 'full_bar', 'Noise Level': 'loud',...
# Mc Farland   {'Accepts Credit Cards': True, 'Wi-Fi': 'free'...
# Mc Farland                             {'Good for Kids': True}
# Mc Farland   {'Take-out': True, 'Good For': {'dessert': Fal...
# Mc Farland   {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...
# Middleton    {'Take-out': True, 'Caters': True, 'Attire': '...
# Middleton    {'Take-out': True, 'Good For': {'dessert': Fal...
# Middleton    {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...
# Middleton                              {'Good for Kids': True}
# Middleton     {'Accepts Credit Cards': True, 'Price Range': 2}
# Middleton    {'Accepts Credit Cards': True, 'Wi-Fi': 'free'...
# Middleton    {'By Appointment Only': False, 'Good for Kids'...
# Middleton    {'Take-out': True, 'Takes Reservations': False...
# Middleton    {'Parking': {'garage': False, 'street': False,...
# Middleton    {'Parking': {'garage': False, 'street': True, ...
# Middleton    {'Parking': {'garage': False, 'street': True, ...
# Middleton    {'Wi-Fi': 'free', 'Price Range': 1, 'Outdoor S...
# Middleton    {'Take-out': True, 'Wi-Fi': 'free', 'Good For'...
# Middleton    {'Good For': {'dessert': False, 'latenight': F...
# Middleton    {'Take-out': True, 'Good For': {'dessert': Fal...
# Middleton    {'Take-out': True, 'Takes Reservations': False...
# ...                                                        ...
# Las Vegas                       {'Accepts Credit Cards': True}
# Madison      {'Take-out': False, 'Good For': {'dessert': Fa...
# Gilbert       {'Accepts Credit Cards': True, 'Price Range': 2}
# Sun Prairie  {'Take-out': True, 'Good For': {'dessert': Fal...
# Las Vegas                                                   {}
# Edinburgh    {'Has TV': False, 'Good For Groups': True, 'Ou...
# Phoenix      {'Take-out': True, 'Good For': {'dessert': Fal...
# Waterloo     {'Take-out': True, 'Wi-Fi': 'free', 'Good For'...
# Scottsdale   {'Parking': {'garage': False, 'street': False,...
# Queen Creek  {'Take-out': True, 'Wi-Fi': 'free', 'Good For'...
# Phoenix                         {'Accepts Credit Cards': True}
# Henderson    {'Parking': {'garage': False, 'street': False,...
# Queen Creek                     {'Accepts Credit Cards': True}
# Avondale     {'Parking': {'garage': False, 'street': False,...
# Las Vegas    {'Parking': {'garage': False, 'street': False,...
# Scottsdale   {'Take-out': True, 'Good For': {'dessert': Fal...
# Las Vegas    {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...
# Las Vegas     {'Accepts Credit Cards': True, 'Price Range': 2}
# Las Vegas    {'Take-out': True, 'Good For': {'dessert': Fal...
# Henderson                              {'Good for Kids': True}
# Edinburgh    {'Take-out': False, 'Wi-Fi': 'free', 'Drive-Th...
# Las Vegas    {'Take-out': True, 'Wi-Fi': 'free', 'Good For'...
# Henderson    {'Take-out': True, 'Good For': {'dessert': Fal...
# Henderson    {'Take-out': True, 'Wi-Fi': 'free', 'Good For'...
# Las Vegas    {'Alcohol': 'full_bar', 'Noise Level': 'quiet'...
# Glendale     {'Alcohol': 'none', 'Good For Dancing': True, ...
# Madison                                                     {}
# Phoenix                               {'Good for Kids': False}
# Phoenix      {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...
# Edinburgh    {'Parking': {'garage': False, 'street': False,...
#
#                         business_id  \
# city
# Phoenix      vcNAWiLM4dR7D2nwwJ7nCA
# De Forest    JwUE5GmEO-sH1FuwJgKBlQ
# De Forest    uGykseHzyS5xAMWoN6YUqA
# De Forest    LRKJF43s9-3jG9Lgx4zODg
# De Forest    RgDg-k9S5YD_BaxMckifkg
# Mc Farland   oLctHIA1AxmsgOuu4dM6Vw
# Phoenix      BMjggIgOghBMEXPo8q7q3w
# Edinburgh    BVxlrYWgmi-8TPGMe6CTpg
#
#                                                     categories  \
# city
# Phoenix                            [Doctors, Health & Medical]
# De Forest                                        [Restaurants]
# De Forest                [American (Traditional), Restaurants]
# De Forest    [Food, Ice Cream & Frozen Yogurt, Fast Food, R...
# De Forest                               [Chinese, Restaurants]
# Mc Farland                   [Television Stations, Mass Media]
# Mc Farland    [Home Services, Heating & Air Conditioning/HVAC]
# Mc Farland           [Libraries, Public Services & Government]
# Mc Farland                               [Veterinarians, Pets]
# Mc Farland   [Bars, American (Traditional), Nightlife, Loun...
# Mc Farland   [Hotels & Travel, Bed & Breakfast, Event Plann...
# Mc Farland                              [Active Life, Bowling]
# Mc Farland                                [Pizza, Restaurants]
# Mc Farland                              [Chinese, Restaurants]
# Middleton    [Event Planning & Services, Party & Event Plan...
# Middleton    [Party & Event Planning, Asian Fusion, Event P...
# Middleton                               [Mexican, Restaurants]
# Middleton    [Active Life, Arts & Entertainment, Stadiums &...
# Middleton                                 [Pet Services, Pets]
# Middleton    [Hotels & Travel, Event Planning & Services, V...
# Middleton    [Pilates, Yoga, Weight Loss Centers, Health & ...
# Middleton      [Sandwiches, Pizza, Chicken Wings, Restaurants]
# Middleton    [Shopping, Arts & Crafts, Event Planning & Ser...
# Middleton    [Arts & Crafts, Shopping, Knitting Supplies, H...
# Middleton    [Women's Clothing, Shopping Centers, Fashion, ...
# Middleton           [Food, Beer, Wine & Spirits, Coffee & Tea]
# Middleton    [Bakeries, Food, Breakfast & Brunch, Coffee & ...
# Middleton       [Bars, American (New), Nightlife, Restaurants]
# Middleton                               [Chinese, Restaurants]
# Middleton                               [Chinese, Restaurants]
# ...                                                        ...
# Las Vegas    [Local Services, Data Recovery, Mobile Phone R...
# Madison                             [Steakhouses, Restaurants]
# Gilbert            [Shopping, Home & Garden, Furniture Stores]
# Sun Prairie        [American (New), Comfort Food, Restaurants]
# Las Vegas              [Arts & Entertainment, Performing Arts]
# Edinburgh                            [Tapas Bars, Restaurants]
# Phoenix                                   [Pizza, Restaurants]
# Waterloo     [Food, Tea Rooms, Coffee & Tea, Asian Fusion, ...
# Scottsdale    [Used, Vintage & Consignment, Fashion, Shopping]
# Queen Creek                               [Cafes, Restaurants]
# Phoenix                                [Movers, Home Services]
# Henderson                                     [Bakeries, Food]
# Queen Creek                          [Handyman, Home Services]
# Avondale                                    [Food, Shaved Ice]
# Las Vegas                               [Food, Specialty Food]
# Scottsdale                           [Sushi Bars, Restaurants]
# Las Vegas                            [Vietnamese, Restaurants]
# Las Vegas                 [Food, Desserts, Cupcakes, Bakeries]
# Las Vegas                              [Filipino, Restaurants]
# Henderson                       [Active Life, Amusement Parks]
# Edinburgh                               [Burgers, Restaurants]
# Las Vegas                         [Chicken Wings, Restaurants]
# Henderson                        [American (New), Restaurants]
# Henderson    [Food, Juice Bars & Smoothies, American (New),...
# Las Vegas    [Bars, Turkish, Mediterranean, Nightlife, Loun...
# Glendale               [Bars, Hookah Bars, Nightlife, Lounges]
# Madison      [Active Life, Barre Classes, Pilates, Fitness ...
# Phoenix                            [Yelp Events, Local Flavor]
# Phoenix                  [Kosher, Italian, Pizza, Restaurants]
# Edinburgh         [Food, Ethnic Food, Grocery, Specialty Food]
#
#                                                   full_address  \
# city
# Phoenix      4840 E Indian School Rd\nSte 101\nPhoenix, AZ ...
# Las Vegas    3700 S Hualapai Way\nSte 108\nSouth Summerlin\...
# Scottsdale              4320 N Miller Rd\nScottsdale, AZ 85251
# Las Vegas    4860 W Desert Inn Rd\nSte 9\nWestside\nLas Veg...
# Las Vegas                       Southeast\nLas Vegas, NV 89120
# Las Vegas       6820 W Flamingo Rd\nSte A\nLas Vegas, NV 89103
# Henderson                 900 Galleria Dr\nHenderson, NV 89011
# Edinburgh         45 Broughton St\nNew Town\nEdinburgh EH1 3JU
# Las Vegas    6475 W Charleston Blvd\nSte 150\nWestside\nLas...
# Henderson    140 S Green Valley Pkwy\nSte 142\nHenderson, N...
# Henderson          19 S Stephanie\nSte140\nHenderson, NV 89012
# Las Vegas    2550 S Rainbow Blvd\nSte  W1\nWestside\nLas Ve...
# Glendale             4340 W Thunderbird Rd\nGlendale, AZ 85306
# Madison      1 E Main St\nLower Level Suite 5\nCapitol\nMad...
# Phoenix               FilmBar\n815 N 2nd St\nPhoenix, AZ 85004
# Phoenix                       6505 N 7th St\nPhoenix, AZ 85014
# Edinburgh       125 Lauriston Pl\nTollcross\nEdinburgh EH3 9JN
#
#                                                          hours   latitude  \
# city
# Phoenix      {'Tuesday': {'close': '17:00', 'open': '08:00'...  33.499313
# De Forest                                                   {}  43.238893
# De Forest    {'Monday': {'close': '22:00', 'open': '06:00'}...  43.252267
# De Forest    {'Monday': {'close': '22:00', 'open': '10:30'}...  43.251045
# De Forest    {'Monday': {'close': '22:00', 'open': '11:00'}...  43.240875
# Mc Farland                                                  {}  42.968507
# Mc Farland                                                  {}  43.030356
# Mc Farland   {'Monday': {'close': '20:00', 'open': '09:00'}...  43.014093
# Mc Farland   {'Monday': {'close': '18:00', 'open': '07:30'}...  43.017124
# Mc Farland                                                  {}  43.017701
# Mc Farland                                                  {}  43.015931
# Mc Farland   {'Monday': {'close': '02:00', 'open': '11:00'}...  43.013156
# Mc Farland   {'Tuesday': {'close': '22:00', 'open': '16:30'...  43.014164
# Mc Farland                                                  {}  43.017939
# Middleton                                                   {}  43.093265
# Middleton    {'Monday': {'close': '14:00', 'open': '11:00'}...  43.090642
# Middleton    {'Monday': {'close': '21:00', 'open': '06:00'}...  43.091061
# Middleton    {'Monday': {'close': '21:00', 'open': '09:00'}...  43.110157
# Middleton                                                   {}  43.077415
# Middleton                                                   {}  43.096271
# Middleton    {'Monday': {'close': '00:00', 'open': '00:00'}...  43.103072
# Middleton                                                   {}  43.100384
# Middleton    {'Monday': {'close': '21:00', 'open': '09:30'}...  43.095498
# Middleton    {'Monday': {'close': '21:00', 'open': '09:00'}...  43.092903
# Middleton    {'Monday': {'close': '20:00', 'open': '10:00'}...  43.091816
# Middleton    {'Monday': {'close': '21:00', 'open': '06:00'}...  43.096359
# Middleton    {'Monday': {'close': '15:00', 'open': '07:00'}...  43.107227
# Middleton    {'Monday': {'close': '11:00', 'open': '07:00'}...  43.101460
# Middleton    {'Monday': {'close': '21:00', 'open': '11:00'}...  43.075345
# Middleton    {'Monday': {'close': '22:00', 'open': '11:00'}...  43.103663
# ...                                                        ...        ...
# Las Vegas    {'Monday': {'close': '19:00', 'open': '10:00'}...  36.159549
# Madison                                                     {}  43.075200
# Gilbert      {'Monday': {'close': '19:00', 'open': '10:00'}...  33.308632
# Sun Prairie                                                 {}  43.166396
# Middleton    -89.511162                            Paul's Neighborhood Bar
# Middleton    -89.528480                                  Chin's Asia Fresh
# Middleton    -89.486491                             Grand China Restaurant
# ...                 ...                                                ...
# Las Vegas   -115.245389                                  My Computer Bytes
# Madison      -89.385835                                    Rare Steakhouse
# Gilbert     -111.746902                                At Home Furnishings
# Sun Prairie  -89.270095                                               MACS
# Las Vegas   -115.344752                                     Water Beauties
# Edinburgh     -3.176367                                   Serrano Manchego
# Phoenix     -112.087116                         Grand Avenue Pizza Company
# Waterloo     -80.525499                                            Chatime
# Scottsdale  -111.926974                                     Plato's Closet
# Queen Creek -111.634005                             The Bistro Queen Creek
# Phoenix     -112.064650                        Movers Phoenix Professional
# Henderson   -115.110455                                 Pink Box Doughnuts
# Queen Creek -111.634299                                  A-1 Hand Handyman
# Avondale    -112.336565                                     Zoni Shave Ice
# Las Vegas   -115.314146                        Popped Gourmet Popcorn Spot
# Scottsdale  -111.917816                                            Sushi J
# Las Vegas   -115.207404                                            Pho Lan
# Las Vegas   -115.099975                                           Bakeshop
# Las Vegas   -115.241094                                     D' Pinoy Joint
# Henderson   -115.024682                           Cowabunga Bay-Water Park
# Edinburgh     -3.188413                                   Burger Meats Bun
# Las Vegas   -115.236715                                      702 Wing Spot
# Henderson   -115.083362                                       LYFE Kitchen
# Henderson   -115.048825                                        Presto Cafe
# Las Vegas   -115.241975                  Maza Mediterranean Grill & Lounge
# Glendale    -112.152529                                       The V Lounge
# Madison      -89.382842                                    Pilates Central
# Phoenix     -112.071074              Yelp's Secret Cinema: Made In Arizona
# Phoenix     -112.064508                    LaBella Pizzeria and Restaurant
# Edinburgh     -3.202529                               Oriental Supermarket
#
#                                 neighborhoods   open  review_count  stars  \
# city
# Phoenix                                    []   True             7    3.5
# De Forest                                  []   True            26    4.0
# De Forest                                  []   True            16    4.0
# De Forest                                  []   True             7    4.5
# De Forest                                  []   True             3    4.0
# Mc Farland                                 []  False            10    1.5
# Mc Farland                                 []   True             4    2.0
# Mc Farland                                 []   True             4    2.5
# Mc Farland                                 []   True             3    4.5
# Mc Farland                                 []   True            31    3.5
# Mc Farland                                 []   True             9    5.0
# Mc Farland                                 []   True             3    1.5
# Mc Farland                                 []   True             4    3.5
# Mc Farland                                 []   True             8    3.5
# Middleton                                  []  False             5    4.0
# Middleton                                  []   True            41    3.0
# Middleton                                  []  False            17    3.0
# Middleton                                  []   True             3    3.5
# Middleton                                  []   True             3    4.5
# Middleton                                  []   True             6    4.5
# Middleton                                  []   True             5    5.0
# Middleton                                  []   True             3    3.0
# Middleton                                  []   True             4    3.0
# Middleton                                  []   True             3    4.0
# Middleton                                  []   True             7    3.5
# Middleton                                  []   True            22    4.0
# Middleton                                  []   True            38    3.5
# Middleton                                  []   True            11    3.5
# Middleton                                  []   True            28    3.0
# Middleton                                  []   True             6    3.0
# ...                                       ...    ...           ...    ...
# Las Vegas                          [Westside]   True             3    4.5
# Madison                             [Capitol]   True             7    3.5
# Gilbert                                    []   True             4    5.0
# Sun Prairie                                []   True             7    3.5
# Las Vegas                   [South Summerlin]   True             5    5.0
# Edinburgh                             [Leith]   True             4    2.5
# Phoenix                                    []   True             6    4.0
# Waterloo                                   []   True             6    4.0
# Scottsdale                                 []   True             5    1.5
# Queen Creek                                []   True             5    5.0
# Phoenix                                    []   True             8    5.0
# Henderson                            [Anthem]   True            12    3.5
# Queen Creek                                []   True             3    5.0
# Avondale                                   []   True             5    5.0
# Las Vegas    [South Summerlin, Spring Valley]   True             3    4.5
# Scottsdale                                 []   True            15    4.5
# Las Vegas                          [Westside]   True            12    4.5
# Las Vegas                         [Southeast]   True             4    5.0
# Las Vegas                                  []   True             9    4.0
# Henderson                                  []   True            26    3.5
# Edinburgh                          [New Town]   True             6    3.5
# Las Vegas                          [Westside]   True             9    4.5
# Henderson                                  []   True            34    3.5
# Henderson                                  []   True            27    4.5
# Las Vegas                          [Westside]   True            18    4.5
# Glendale                                   []   True             4    5.0
# Madison                             [Capitol]   True             3    5.0
# Phoenix                                    []   True            17    5.0
# Phoenix                                    []   True             5    5.0
# Edinburgh               [Tollcross, Old Town]   True             7    3.5
#
#             state      type delivery
# city
# Phoenix        AZ  business     None
# De Forest      WI  business    False
# De Forest      WI  business    False
# De Forest      WI  business    False
# De Forest      WI  business     None
# Mc Farland     WI  business     None
# Mc Farland     WI  business     None
# Mc Farland     WI  business     None
# Mc Farland     WI  business     None
# Mc Farland     WI  business    False
# Mc Farland     WI  business     None
# Mc Farland     WI  business     None
# Mc Farland     WI  business    False
# Mc Farland     WI  business    False
# Middleton      WI  business     None
# Middleton      WI  business    False
# Middleton      WI  business    False
# Middleton      WI  business     None
# Middleton      WI  business     None
# Middleton      WI  business     None
# Middleton      WI  business     None
# Middleton      WI  business     True
# Middleton      WI  business     None
# Middleton      WI  business     None
# Middleton      WI  business     None
# Middleton      WI  business     None
# Middleton      WI  business    False
# Middleton      WI  business     None
# Middleton      WI  business    False
# Middleton      WI  business     None
# ...           ...       ...      ...
# Las Vegas      NV  business     None
# Madison        WI  business    False
# Gilbert        AZ  business     None
# Sun Prairie    WI  business     None
# Las Vegas      NV  business     None
# Edinburgh     MLN  business     None
# Phoenix        AZ  business     True
# Waterloo       ON  business    False
# Scottsdale     AZ  business     None
# Queen Creek    AZ  business    False
# Phoenix        AZ  business     None
# Henderson      NV  business     None
# Queen Creek    AZ  business     None
# Avondale       AZ  business     None
# Las Vegas      NV  business     None
# Scottsdale     AZ  business    False
# Las Vegas      NV  business    False
# Las Vegas      NV  business     None
# Las Vegas      NV  business    False
# Henderson      NV  business     None
# Edinburgh     MLN  business    False
# Las Vegas      NV  business     True
# Henderson      NV  business    False
# Henderson      NV  business    False
# Las Vegas      NV  business     True
# Glendale       AZ  business     None
# Madison        WI  business     None
# Phoenix        AZ  business     None
# Phoenix        AZ  business     True
# Edinburgh     EDH  business     None
#
# [37938 rows x 15 columns]

# %%
pd.concat([yelp_df.set_index('city'), city_counts], axis=1, join='inner').reset_index().head()
# Out:
#         city                                         attributes  \
# 0    Phoenix                      {'By Appointment Only': True}
# 1  De Forest  {'Take-out': True, 'Good For': {'dessert': Fal...
# 2  De Forest  {'Take-out': True, 'Good For': {'dessert': Fal...
# 3  De Forest  {'Take-out': True, 'Wi-Fi': 'free', 'Takes Res...
# 4  De Forest  {'Take-out': True, 'Has TV': False, 'Outdoor S...
#
#               business_id                                         categories  \
# 0  vcNAWiLM4dR7D2nwwJ7nCA                        [Doctors, Health & Medical]
# 1  JwUE5GmEO-sH1FuwJgKBlQ                                      [Restaurants]
# 2  uGykseHzyS5xAMWoN6YUqA              [American (Traditional), Restaurants]
# 3  LRKJF43s9-3jG9Lgx4zODg  [Food, Ice Cream & Frozen Yogurt, Fast Food, R...
# 4  RgDg-k9S5YD_BaxMckifkg                             [Chinese, Restaurants]
#
#                                         full_address  \
# 0  4840 E Indian School Rd\nSte 101\nPhoenix, AZ ...
# 1            6162 US Highway 51\nDe Forest, WI 53532
# 2                505 W North St\nDe Forest, WI 53532
# 3              4910 County Rd V\nDe Forest, WI 53532
# 4                 631 S Main St\nDe Forest, WI 53532
#
#                                                hours   latitude   longitude  \
# 0  {'Tuesday': {'close': '17:00', 'open': '08:00'...  33.499313 -111.983758
# 1                                                 {}  43.238893  -89.335844
# 2  {'Monday': {'close': '22:00', 'open': '06:00'}...  43.252267  -89.353437
# 3  {'Monday': {'close': '22:00', 'open': '10:30'}...  43.251045  -89.374983
# 4  {'Monday': {'close': '22:00', 'open': '11:00'}...  43.240875  -89.343722
#
#                           name neighborhoods  open  review_count  stars state  \
# 0            Eric Goldberg, MD            []  True             7    3.5    AZ
# 1         Pine Cone Restaurant            []  True            26    4.0    WI
# 2   Deforest Family Restaurant            []  True            16    4.0    WI
# 3                     Culver's            []  True             7    4.5    WI
# 4  Chang Jiang Chinese Kitchen            []  True             3    4.0    WI
#
#        type delivery  city_counts
# 0  business     None         6715
# 1  business    False            6
# 2  business    False            6
# 3  business    False            6
# 4  business     None            6

# %% [markdown]
# Pandas provides [extensive documentation](https://pandas.pydata.org/pandas-docs/stable/merging.html) with diagrammed examples on different methods and approaches for joining data.

# %% [markdown]
# ## Working with time series
# Pandas has a well-designed backend for inferring dates and times from strings and doing meaningful computations with them.

# %%
pop_growth = pd.read_html('https://web.archive.org/web/20170127165708/https://www.census.gov/population/international/data/worldpop/table_population.php', attrs={'class': 'query_table'}, parse_dates=[0])[0]
pop_growth.dropna(inplace=True)
pop_growth.head()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-214-baf2802f7c01> in <module>
# ----> 1 pop_growth = pd.read_html('https://web.archive.org/web/20170127165708/https://www.census.gov/population/international/data/worldpop/table_population.php', attrs={'class': 'query_table'}, parse_dates=[0])[0]
#       2 pop_growth.dropna(inplace=True)
#       3 pop_growth.head()
#
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, tupleize_cols, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1092                   decimal=decimal, converters=converters, na_values=na_values,
#    1093                   keep_default_na=keep_default_na,
# -> 1094                   displayed_only=displayed_only)
#
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\pandas\io\html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     892     retained = None
#     893     for flav in flavor:
# --> 894         parser = _parser_dispatch(flav)
#     895         p = parser(io, compiled_match, attrs, encoding, displayed_only)
#     896
#
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\pandas\io\html.py in _parser_dispatch(flavor)
#     849     else:
#     850         if not _HAS_LXML:
# --> 851             raise ImportError("lxml not found, please install it")
#     852     return _valid_parsers[flavor]
#     853
#
# ImportError: lxml not found, please install it

# %% [markdown]
# By setting the `'Year'` column to the index, we can easily aggregate data by date using the `resample` method. The `resample` method allows us to decrease or increase the sampling frequency of our data. For instance, maybe instead of yearly data, we want to see average quantities for each decade.

# %%
pop_growth.set_index('Year', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-215-d57c9d8d890e> in <module>
# ----> 1 pop_growth.set_index('Year', inplace=True)
#
# NameError: name 'pop_growth' is not defined

# %%
pop_growth.resample('10AS').mean()
# Out:
#               Population  Annual Growth Rate (%)  Annual Population Change
# Year
# 1950-01-01  2.765922e+09                  1.7529                48537285.4
# 1960-01-01  3.321900e+09                  2.0094                66969623.4
# 1970-01-01  4.047646e+09                  1.8154                73179902.2
# 1980-01-01  4.813578e+09                  1.7438                83875618.4
# 1990-01-01  5.651506e+09                  1.4220                80123197.0
# 2000-01-01  6.429734e+09                  1.2017                77213097.9
# 2010-01-01  7.206287e+09                  1.0742                77318221.4
# 2020-01-01  7.949758e+09                  0.8687                68934817.8
# 2030-01-01  8.587652e+09                  0.6741                57810604.6
# 2040-01-01  9.120663e+09                  0.5238                47723189.0

# %% [markdown]
# This kind of resampling is called _downsampling_, because we are decreasing the sampling frequency of the data. We can choose how to aggregate the data from each decade (e.g. `mean`). Options for aggregation include `mean`, `median`, `sum`, `last`, and `first`.
#
# We can also _upsample_ data. In this case, we don't have data for each quarter, so we have to tell Pandas has to fill in the missing data.

# %%
pop_growth.resample('1Q').bfill().head()
# Out:
#               Population  Annual Growth Rate (%)  Annual Population Change
# Year
# 1950-03-31  2.594940e+09                   1.612                41832429.0
# 1950-06-30  2.594940e+09                   1.612                41832429.0
# 1950-09-30  2.594940e+09                   1.612                41832429.0
# 1950-12-31  2.594940e+09                   1.612                41832429.0
# 1951-03-31  2.636772e+09                   1.717                45281083.0

# %%
pop_growth.resample('1Q').ffill().head()
# Out:
#               Population  Annual Growth Rate (%)  Annual Population Change
# Year
# 1950-03-31  2.557629e+09                   1.459                37311223.0
# 1950-06-30  2.557629e+09                   1.459                37311223.0
# 1950-09-30  2.557629e+09                   1.459                37311223.0
# 1950-12-31  2.557629e+09                   1.459                37311223.0
# 1951-03-31  2.594940e+09                   1.612                41832429.0

# %% [markdown]
# Pandas' time series capabilities are built on the Pandas `Timestamp` class.

# %%
print(pd.Timestamp('January 8, 2017'))
print(pd.Timestamp('01/08/17 20:13'))
print(pd.Timestamp(1.4839*10**18))
# Out:
# 2017-01-08 00:00:00
# 2017-01-08 20:13:00
# 2017-01-08 18:26:40

# %%
print(pd.Timestamp('Feb. 11 2016 2:30 am') - pd.Timestamp('2015-08-03 5:14 pm'))
# Out:
# 191 days 09:16:00

# %%
from pandas.tseries.offsets import BDay, Day, BMonthEnd

print(pd.Timestamp('January 9, 2017') - Day(4))
print(pd.Timestamp('January 9, 2017') - BDay(4))
print(pd.Timestamp('January 9, 2017') + BMonthEnd(4))
# Out:
# 2017-01-05 00:00:00
# 2017-01-03 00:00:00
# 2017-04-28 00:00:00

# %% [markdown]
# If we're entering time series data into a DataFrame it will often be useful to create a range of dates.

# %%
pd.date_range(start='1/8/2017', end='3/2/2017', freq='B')
# Out:
# DatetimeIndex(['2017-01-09', '2017-01-10', '2017-01-11', '2017-01-12',
#                '2017-01-13', '2017-01-16', '2017-01-17', '2017-01-18',
#                '2017-01-19', '2017-01-20', '2017-01-23', '2017-01-24',
#                '2017-01-25', '2017-01-26', '2017-01-27', '2017-01-30',
#                '2017-01-31', '2017-02-01', '2017-02-02', '2017-02-03',
#                '2017-02-06', '2017-02-07', '2017-02-08', '2017-02-09',
#                '2017-02-10', '2017-02-13', '2017-02-14', '2017-02-15',
#                '2017-02-16', '2017-02-17', '2017-02-20', '2017-02-21',
#                '2017-02-22', '2017-02-23', '2017-02-24', '2017-02-27',
#                '2017-02-28', '2017-03-01', '2017-03-02'],
#               dtype='datetime64[ns]', freq='B')

# %% [markdown]
# The `Timestamp` class is compatible with Python's `datetime` module.

# %%
import datetime

pd.Timestamp('May 1, 2017') - datetime.datetime(2017, 1, 8)
# Out:
# Timedelta('113 days 00:00:00')

# %% [markdown]
# ## Visualizing data with Pandas
#
# Visualizing a data set is an important first step in drawing insights. We can easily pass data from Pandas to Matplotlib for visualizations, but Pandas also plugs into Matplotlib directly through methods like `plot` and `hist`.

# %%
yelp_df['review_count'].apply(np.log).hist(bins=30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-a7278e737f94> in <module>()
# ----> 1 yelp_df['review_count'].apply(np.log).hist(bins=30)
#
# NameError: name 'yelp_df' is not defined

# %%
pop_growth['Annual Growth Rate (%)'].plot()

# %% [markdown]
# The [plotting functions take many parameters](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.plot.html) for customizing the appearance of the output. Since they are essentially a wrapper around the Matplotlib functions, they also accept many of the Matplotlib parameters, not all of which are listed in the Pandas documentation. Pandas provides [a guide](https://pandas.pydata.org/pandas-docs/stable/visualization.html) to making various plots from DataFrames.

# %% [markdown]
# *Copyright &copy; 2017 The Data Incubator.  All rights reserved.*
